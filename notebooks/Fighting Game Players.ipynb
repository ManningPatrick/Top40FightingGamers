# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Sonic Fox

# %%
sonicfox_url = 'https://www.esportsearnings.com/players/4603-sonicfox-dominique-mclean'
response = requests.get(sonicfox_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
sonic_fox = pd.read_html(str(tables), skiprows=1)
len(sonic_fox)
# Out:
# 6

# %%
sonic_fox = sonic_fox[0]
sonic_fox
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $18,694.21              9          2.67%    |       $1,826.37
# 2  2020.0     $40,800.00              2          5.82%    |           $0.00
# 3  2019.0     $64,925.00             22          9.27%    |         $200.00
# 4  2018.0     $84,201.28             23         12.02%    |           $0.00
# 5  2017.0    $184,820.53             19         26.38%    |           $0.00
# 6  2016.0    $192,326.50             18         27.46%    |           $0.00
# 7  2015.0    $112,174.00             20         16.01%    |           $0.00
# 8  2014.0      $2,537.20             13          0.36%    |           $0.00
# 9  2013.0          $0.00              2          0.00%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# ...

# %%
sonic_fox.columns = sonic_fox.iloc[0]
sonic_fox
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $18,694.21              9          2.67%    |       $1,826.37
# 2  2020.0     $40,800.00              2          5.82%    |           $0.00
# 3  2019.0     $64,925.00             22          9.27%    |         $200.00
# 4  2018.0     $84,201.28             23         12.02%    |           $0.00
# 5  2017.0    $184,820.53             19         26.38%    |           $0.00
# 6  2016.0    $192,326.50             18         27.46%    |           $0.00
# 7  2015.0    $112,174.00             20         16.01%    |           $0.00
# 8  2014.0      $2,537.20             13          0.36%    |           $0.00
# 9  2013.0          $0.00              2          0.00%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# ...

# %%
sonic_fox = sonic_fox.drop([0])
sonic_fox
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $18,694.21             9         2.67%   |      $1,826.37
# 2  2020.0    $40,800.00             2         5.82%   |          $0.00
# 3  2019.0    $64,925.00            22         9.27%   |        $200.00
# 4  2018.0    $84,201.28            23        12.02%   |          $0.00
# 5  2017.0   $184,820.53            19        26.38%   |          $0.00
# 6  2016.0   $192,326.50            18        27.46%   |          $0.00
# 7  2015.0   $112,174.00            20        16.01%   |          $0.00
# 8  2014.0     $2,537.20            13         0.36%   |          $0.00
# 9  2013.0         $0.00             2         0.00%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          0.26%   |          $16,867.84                   7
# 2              0          0.00%   |          $40,800.00                   2
# ...

# %%
sonic_fox['Player ID'] = 'SonicFox'
sonic_fox
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $18,694.21             9         2.67%   |      $1,826.37
# 2  2020.0    $40,800.00             2         5.82%   |          $0.00
# 3  2019.0    $64,925.00            22         9.27%   |        $200.00
# 4  2018.0    $84,201.28            23        12.02%   |          $0.00
# 5  2017.0   $184,820.53            19        26.38%   |          $0.00
# 6  2016.0   $192,326.50            18        27.46%   |          $0.00
# 7  2015.0   $112,174.00            20        16.01%   |          $0.00
# 8  2014.0     $2,537.20            13         0.36%   |          $0.00
# 9  2013.0         $0.00             2         0.00%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          0.26%   |          $16,867.84                   7
# 2              0          0.00%   |          $40,800.00                   2
# ...

# %%
sonic_fox.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
sonic_fox
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $18,694.21            9         2.67%     |     $1,826.37
# 2  2020.0   $40,800.00            2         5.82%     |         $0.00
# 3  2019.0   $64,925.00           22         9.27%     |       $200.00
# 4  2018.0   $84,201.28           23        12.02%     |         $0.00
# 5  2017.0  $184,820.53           19        26.38%     |         $0.00
# 6  2016.0  $192,326.50           18        27.46%     |         $0.00
# 7  2015.0  $112,174.00           20        16.01%     |         $0.00
# 8  2014.0    $2,537.20           13         0.36%     |         $0.00
# 9  2013.0        $0.00            2         0.00%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             2          0.26%      |     $16,867.84              7
# 2             0          0.00%      |     $40,800.00              2
# ...

# %%
sonic_fox = sonic_fox.drop(columns=['blank', 'blank1'])
sonic_fox
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021.0   $18,694.21            9         2.67%     $1,826.37             2
# 2  2020.0   $40,800.00            2         5.82%         $0.00             0
# 3  2019.0   $64,925.00           22         9.27%       $200.00             1
# 4  2018.0   $84,201.28           23        12.02%         $0.00             0
# 5  2017.0  $184,820.53           19        26.38%         $0.00             0
# 6  2016.0  $192,326.50           18        27.46%         $0.00             0
# 7  2015.0  $112,174.00           20        16.01%         $0.00             0
# 8  2014.0    $2,537.20           13         0.36%         $0.00             0
# 9  2013.0        $0.00            2         0.00%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.26%     $16,867.84              7           2.41%  SonicFox
# ...

# %%
sonic_fox['Year'] = sonic_fox['Year'].round().astype(int)
sonic_fox
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $18,694.21            9         2.67%     $1,826.37             2
# 2  2020   $40,800.00            2         5.82%         $0.00             0
# 3  2019   $64,925.00           22         9.27%       $200.00             1
# 4  2018   $84,201.28           23        12.02%         $0.00             0
# 5  2017  $184,820.53           19        26.38%         $0.00             0
# 6  2016  $192,326.50           18        27.46%         $0.00             0
# 7  2015  $112,174.00           20        16.01%         $0.00             0
# 8  2014    $2,537.20           13         0.36%         $0.00             0
# 9  2013        $0.00            2         0.00%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.26%     $16,867.84              7           2.41%  SonicFox
# ...

# %% [markdown]
# ### made a separate table for games

# %%
sonic_fox_games = pd.read_html(str(tables), skiprows=1)

# %%
sonic_fox_games = sonic_fox_games[2]
sonic_fox_games
# Out:
#                                     0              1              2   \
# 0                                  NaN  Total Results  Total Results
# 1             Dead or Alive 5 Ultimate          $0.00              4
# 2          Dead or Alive 5: Last Round        $504.00              6
# 3                 Dragon Ball FighterZ     $43,872.21             22
# 4                 Guilty Gear -STRIVE-      $2,647.10              4
# 5                          Injustice 2    $223,245.53             16
# 6             Injustice: Gods Among Us      $3,414.20             11
# 7          Marvel vs. Capcom: Infinite      $2,081.00              3
# 8             Melty Blood: Type Lumina        $400.92              1
# 9                     Mortal Kombat 11    $106,479.30             11
# 10                     Mortal Kombat 9        $785.00              4
# 11                     Mortal Kombat X    $253,343.60             14
# 12                    Mortal Kombat XL     $50,511.90              6
# ...

# %%
sonic_fox_games.columns = sonic_fox_games.iloc[0]

# %%
sonic_fox_games = sonic_fox_games.drop([0])
sonic_fox_games
# Out:
# 0                                  NaN Total Results Total Results  \
# 1             Dead or Alive 5 Ultimate         $0.00             4
# 2          Dead or Alive 5: Last Round       $504.00             6
# 3                 Dragon Ball FighterZ    $43,872.21            22
# 4                 Guilty Gear -STRIVE-     $2,647.10             4
# 5                          Injustice 2   $223,245.53            16
# 6             Injustice: Gods Among Us     $3,414.20            11
# 7          Marvel vs. Capcom: Infinite     $2,081.00             3
# 8             Melty Blood: Type Lumina       $400.92             1
# 9                     Mortal Kombat 11   $106,479.30            11
# 10                     Mortal Kombat 9       $785.00             4
# 11                     Mortal Kombat X   $253,343.60            14
# 12                    Mortal Kombat XL    $50,511.90             6
# 13             Persona 4 Arena Ultimax         $0.00             1
# ...

# %%
sonic_fox_games['Player ID'] = 'SonicFox'
sonic_fox_games.head()
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1     Dead or Alive 5 Ultimate         $0.00             4         0.00%   |
# 2  Dead or Alive 5: Last Round       $504.00             6         0.07%   |
# 3         Dragon Ball FighterZ    $43,872.21            22         6.26%   |
# 4         Guilty Gear -STRIVE-     $2,647.10             4         0.38%   |
# 5                  Injustice 2   $223,245.53            16        31.87%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |               $0.00
# 2          $0.00              0          0.00%   |             $504.00
# 3          $0.00              0          0.00%   |          $43,872.21
# 4      $1,826.37              2          0.26%   |             $820.73
# 5          $0.00              0          0.00%   |         $223,245.53
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
sonic_fox_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes',
'Online Placed', 'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
sonic_fox_games.head()
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1     Dead or Alive 5 Ultimate        $0.00            4         0.00%     |
# 2  Dead or Alive 5: Last Round      $504.00            6         0.07%     |
# 3         Dragon Ball FighterZ   $43,872.21           22         6.26%     |
# 4         Guilty Gear -STRIVE-    $2,647.10            4         0.38%     |
# 5                  Injustice 2  $223,245.53           16        31.87%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |          $0.00
# 2         $0.00             0          0.00%      |        $504.00
# 3         $0.00             0          0.00%      |     $43,872.21
# 4     $1,826.37             2          0.26%      |        $820.73
# 5         $0.00             0          0.00%      |    $223,245.53
#
#   Offline Placed Offline Percent Player ID
# 1              4           0.00%  SonicFox
# ...

# %%
sonic_fox_games = sonic_fox_games.drop(columns=['blank', 'blank1'])
sonic_fox_games.head
# Out:
# <bound method NDFrame.head of                                   Game Total Prizes Total Placed  \
# 1             Dead or Alive 5 Ultimate        $0.00            4
# 2          Dead or Alive 5: Last Round      $504.00            6
# 3                 Dragon Ball FighterZ   $43,872.21           22
# 4                 Guilty Gear -STRIVE-    $2,647.10            4
# 5                          Injustice 2  $223,245.53           16
# 6             Injustice: Gods Among Us    $3,414.20           11
# 7          Marvel vs. Capcom: Infinite    $2,081.00            3
# 8             Melty Blood: Type Lumina      $400.92            1
# 9                     Mortal Kombat 11  $106,479.30           11
# 10                     Mortal Kombat 9      $785.00            4
# 11                     Mortal Kombat X  $253,343.60           14
# 12                    Mortal Kombat XL   $50,511.90            6
# 13             Persona 4 Arena Ultimax        $0.00            1
# ...

# %% [markdown]
# ## Punk

# %%
punk_url = 'https://www.esportsearnings.com/players/33471-punk-victor-woodley'
response = requests.get(punk_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
punk = pd.read_html(str(tables), skiprows=1)
len(punk)
# Out:
# 5

# %%
punk = punk[0]
punk
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $19,042.98             33          5.39%    |      $13,577.67
# 2  2020.0        $760.58              2          0.22%    |         $760.58
# 3  2019.0    $103,193.88             17         29.19%    |           $0.00
# 4  2018.0     $23,561.80             12          6.67%    |           $0.00
# 5  2017.0    $205,451.00             25         58.12%    |           $0.00
# 6  2016.0      $1,500.00              1          0.42%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1              27           3.84%    |            $5,465.31
# 2               2           0.22%    |                $0.00
# 3               0           0.00%    |          $103,193.88
# ...

# %%
punk.columns = punk.iloc[0]

# %%
punk = punk.drop([0])

# %%
punk
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $19,042.98            33         5.39%   |     $13,577.67
# 2  2020.0       $760.58             2         0.22%   |        $760.58
# 3  2019.0   $103,193.88            17        29.19%   |          $0.00
# 4  2018.0    $23,561.80            12         6.67%   |          $0.00
# 5  2017.0   $205,451.00            25        58.12%   |          $0.00
# 6  2016.0     $1,500.00             1         0.42%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1             27          3.84%   |           $5,465.31                   6
# 2              2          0.22%   |               $0.00                   0
# 3              0          0.00%   |         $103,193.88                  17
# 4              0          0.00%   |          $23,561.80                  12
# 5              0          0.00%   |         $205,451.00                  25
# ...

# %%
punk['Player ID'] = 'Punk'

# %%
punk
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $19,042.98            33         5.39%   |     $13,577.67
# 2  2020.0       $760.58             2         0.22%   |        $760.58
# 3  2019.0   $103,193.88            17        29.19%   |          $0.00
# 4  2018.0    $23,561.80            12         6.67%   |          $0.00
# 5  2017.0   $205,451.00            25        58.12%   |          $0.00
# 6  2016.0     $1,500.00             1         0.42%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1             27          3.84%   |           $5,465.31                   6
# 2              2          0.22%   |               $0.00                   0
# 3              0          0.00%   |         $103,193.88                  17
# 4              0          0.00%   |          $23,561.80                  12
# 5              0          0.00%   |         $205,451.00                  25
# ...

# %%
punk.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
punk
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $19,042.98           33         5.39%     |    $13,577.67
# 2  2020.0      $760.58            2         0.22%     |       $760.58
# 3  2019.0  $103,193.88           17        29.19%     |         $0.00
# 4  2018.0   $23,561.80           12         6.67%     |         $0.00
# 5  2017.0  $205,451.00           25        58.12%     |         $0.00
# 6  2016.0    $1,500.00            1         0.42%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1            27          3.84%      |      $5,465.31              6
# 2             2          0.22%      |          $0.00              0
# 3             0          0.00%      |    $103,193.88             17
# 4             0          0.00%      |     $23,561.80             12
# 5             0          0.00%      |    $205,451.00             25
# ...

# %%
punk = punk.drop(columns=['blank1', 'blank'])
punk
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021.0   $19,042.98           33         5.39%    $13,577.67            27
# 2  2020.0      $760.58            2         0.22%       $760.58             2
# 3  2019.0  $103,193.88           17        29.19%         $0.00             0
# 4  2018.0   $23,561.80           12         6.67%         $0.00             0
# 5  2017.0  $205,451.00           25        58.12%         $0.00             0
# 6  2016.0    $1,500.00            1         0.42%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          3.84%      $5,465.31              6           1.55%      Punk
# 2          0.22%          $0.00              0           0.00%      Punk
# 3          0.00%    $103,193.88             17          29.19%      Punk
# 4          0.00%     $23,561.80             12           6.67%      Punk
# ...

# %%
punk['Year'] = punk['Year'].round().astype(int)

# %%
punk
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $19,042.98           33         5.39%    $13,577.67            27
# 2  2020      $760.58            2         0.22%       $760.58             2
# 3  2019  $103,193.88           17        29.19%         $0.00             0
# 4  2018   $23,561.80           12         6.67%         $0.00             0
# 5  2017  $205,451.00           25        58.12%         $0.00             0
# 6  2016    $1,500.00            1         0.42%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          3.84%      $5,465.31              6           1.55%      Punk
# 2          0.22%          $0.00              0           0.00%      Punk
# 3          0.00%    $103,193.88             17          29.19%      Punk
# 4          0.00%     $23,561.80             12           6.67%      Punk
# ...

# %%
punk_games = pd.read_html(str(tables), skiprows=1)

# %%
punk_games = punk_games[1]
punk_games
# Out:
#                                    0              1              2   \
# 0                                 NaN  Total Results  Total Results
# 1          BlazBlue: Cross Tag Battle         $56.00              1
# 2                Guilty Gear -STRIVE-      $2,966.54              9
# 3                         Injustice 2        $533.00              6
# 4         Marvel vs. Capcom: Infinite        $178.00              2
# 5                    Street Fighter V    $206,310.00             19
# 6    Street Fighter V: Arcade Edition    $126,497.68             25
# 7  Street Fighter V: Champion Edition     $16,756.84             25
# 8        Ultimate Marvel vs. Capcom 3         $86.18              2
# 9  Under Night In-Birth EXE: Late[st]        $126.00              1
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# ...

# %%
punk_games.columns = punk_games.iloc[0]

# %%
punk_games = punk_games.drop([0])
punk_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1          BlazBlue: Cross Tag Battle        $56.00             1
# 2                Guilty Gear -STRIVE-     $2,966.54             9
# 3                         Injustice 2       $533.00             6
# 4         Marvel vs. Capcom: Infinite       $178.00             2
# 5                    Street Fighter V   $206,310.00            19
# 6    Street Fighter V: Arcade Edition   $126,497.68            25
# 7  Street Fighter V: Champion Edition    $16,756.84            25
# 8        Ultimate Marvel vs. Capcom 3        $86.18             2
# 9  Under Night In-Birth EXE: Late[st]       $126.00             1
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.02%   |          $0.00              0          0.00%   |
# 2         0.84%   |      $2,448.54              8          0.69%   |
# 3         0.15%   |          $0.00              0          0.00%   |
# ...

# %%
punk_games['Player ID'] = 'Punk'
punk_games.head()
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1   BlazBlue: Cross Tag Battle        $56.00             1         0.02%   |
# 2         Guilty Gear -STRIVE-     $2,966.54             9         0.84%   |
# 3                  Injustice 2       $533.00             6         0.15%   |
# 4  Marvel vs. Capcom: Infinite       $178.00             2         0.05%   |
# 5             Street Fighter V   $206,310.00            19        58.36%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |              $56.00
# 2      $2,448.54              8          0.69%   |             $518.00
# 3          $0.00              0          0.00%   |             $533.00
# 4          $0.00              0          0.00%   |             $178.00
# 5          $0.00              0          0.00%   |         $206,310.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
punk_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
punk_games.head()
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1   BlazBlue: Cross Tag Battle       $56.00            1         0.02%     |
# 2         Guilty Gear -STRIVE-    $2,966.54            9         0.84%     |
# 3                  Injustice 2      $533.00            6         0.15%     |
# 4  Marvel vs. Capcom: Infinite      $178.00            2         0.05%     |
# 5             Street Fighter V  $206,310.00           19        58.36%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |         $56.00
# 2     $2,448.54             8          0.69%      |        $518.00
# 3         $0.00             0          0.00%      |        $533.00
# 4         $0.00             0          0.00%      |        $178.00
# 5         $0.00             0          0.00%      |    $206,310.00
#
#   Offline Placed Offline Percent Player ID
# 1              1           0.02%      Punk
# ...

# %%
punk_games = punk_games.drop(columns=['blank', 'blank1'])
punk_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1          BlazBlue: Cross Tag Battle       $56.00            1         0.02%
# 2                Guilty Gear -STRIVE-    $2,966.54            9         0.84%
# 3                         Injustice 2      $533.00            6         0.15%
# 4         Marvel vs. Capcom: Infinite      $178.00            2         0.05%
# 5                    Street Fighter V  $206,310.00           19        58.36%
# 6    Street Fighter V: Arcade Edition  $126,497.68           25        35.78%
# 7  Street Fighter V: Champion Edition   $16,756.84           25         4.74%
# 8        Ultimate Marvel vs. Capcom 3       $86.18            2         0.02%
# 9  Under Night In-Birth EXE: Late[st]      $126.00            1         0.04%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%         $56.00              1
# ...

# %%
#pd.concat([sonic_fox, punk])

# %% [markdown]
# ## Tokido

# %%
tokido_url = 'https://www.esportsearnings.com/players/1705-tokido-hajime-taniguchi'
response = requests.get(tokido_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
tokido = pd.read_html(str(tables), skiprows=1)
len(tokido)
# Out:
# 6

# %%
tokido = tokido[0]
tokido
# Out:
#         0              1              2              3    4               5   \
# 0      NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1   2021.0     $23,708.95              4          4.44%    |      $14,000.00
# 2   2020.0     $23,394.95              2          4.39%    |           $0.00
# 3   2019.0     $28,184.95              7          5.28%    |           $0.00
# 4   2018.0    $225,598.00             14         42.29%    |           $0.00
# 5   2017.0    $122,000.00              9         22.87%    |           $0.00
# 6   2016.0     $44,274.50              9          8.30%    |           $0.00
# 7   2015.0     $18,080.22              6          3.39%    |           $0.00
# 8   2014.0     $12,735.00              7          2.39%    |           $0.00
# 9   2013.0      $5,883.52              7          1.10%    |           $0.00
# 10  2012.0     $15,200.00             11          2.85%    |           $0.00
# ...

# %%
tokido.columns = tokido.iloc[0]

# %%
tokido = tokido.drop([0])

# %%
tokido
# Out:
# 0      NaN Total Results Total Results Total Results NaN Online Results  \
# 1   2021.0    $23,708.95             4         4.44%   |     $14,000.00
# 2   2020.0    $23,394.95             2         4.39%   |          $0.00
# 3   2019.0    $28,184.95             7         5.28%   |          $0.00
# 4   2018.0   $225,598.00            14        42.29%   |          $0.00
# 5   2017.0   $122,000.00             9        22.87%   |          $0.00
# 6   2016.0    $44,274.50             9         8.30%   |          $0.00
# 7   2015.0    $18,080.22             6         3.39%   |          $0.00
# 8   2014.0    $12,735.00             7         2.39%   |          $0.00
# 9   2013.0     $5,883.52             7         1.10%   |          $0.00
# 10  2012.0    $15,200.00            11         2.85%   |          $0.00
# 11  2011.0     $3,508.00             4         0.66%   |          $0.00
# 12  2010.0     $1,106.88             1         0.21%   |          $0.00
# ...

# %%
tokido['Player ID'] = 'Tokido'

# %%
tokido
# Out:
# 0      NaN Total Results Total Results Total Results NaN Online Results  \
# 1   2021.0    $23,708.95             4         4.44%   |     $14,000.00
# 2   2020.0    $23,394.95             2         4.39%   |          $0.00
# 3   2019.0    $28,184.95             7         5.28%   |          $0.00
# 4   2018.0   $225,598.00            14        42.29%   |          $0.00
# 5   2017.0   $122,000.00             9        22.87%   |          $0.00
# 6   2016.0    $44,274.50             9         8.30%   |          $0.00
# 7   2015.0    $18,080.22             6         3.39%   |          $0.00
# 8   2014.0    $12,735.00             7         2.39%   |          $0.00
# 9   2013.0     $5,883.52             7         1.10%   |          $0.00
# 10  2012.0    $15,200.00            11         2.85%   |          $0.00
# 11  2011.0     $3,508.00             4         0.66%   |          $0.00
# 12  2010.0     $1,106.88             1         0.21%   |          $0.00
# ...

# %%
tokido.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
tokido
# Out:
#       Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1   2021.0   $23,708.95            4         4.44%     |    $14,000.00
# 2   2020.0   $23,394.95            2         4.39%     |         $0.00
# 3   2019.0   $28,184.95            7         5.28%     |         $0.00
# 4   2018.0  $225,598.00           14        42.29%     |         $0.00
# 5   2017.0  $122,000.00            9        22.87%     |         $0.00
# 6   2016.0   $44,274.50            9         8.30%     |         $0.00
# 7   2015.0   $18,080.22            6         3.39%     |         $0.00
# 8   2014.0   $12,735.00            7         2.39%     |         $0.00
# 9   2013.0    $5,883.52            7         1.10%     |         $0.00
# 10  2012.0   $15,200.00           11         2.85%     |         $0.00
# 11  2011.0    $3,508.00            4         0.66%     |         $0.00
# 12  2010.0    $1,106.88            1         0.21%     |         $0.00
# ...

# %%
tokido = tokido.drop(columns=['blank1', 'blank'])
tokido
# Out:
#       Year Total Prizes Total Placed Total Percent Online Prizes  \
# 1   2021.0   $23,708.95            4         4.44%    $14,000.00
# 2   2020.0   $23,394.95            2         4.39%         $0.00
# 3   2019.0   $28,184.95            7         5.28%         $0.00
# 4   2018.0  $225,598.00           14        42.29%         $0.00
# 5   2017.0  $122,000.00            9        22.87%         $0.00
# 6   2016.0   $44,274.50            9         8.30%         $0.00
# 7   2015.0   $18,080.22            6         3.39%         $0.00
# 8   2014.0   $12,735.00            7         2.39%         $0.00
# 9   2013.0    $5,883.52            7         1.10%         $0.00
# 10  2012.0   $15,200.00           11         2.85%         $0.00
# 11  2011.0    $3,508.00            4         0.66%         $0.00
# 12  2010.0    $1,106.88            1         0.21%         $0.00
# 13  2007.0    $8,333.33            5         1.56%         $0.00
# ...

# %%
tokido['Year'] = tokido['Year'].round().astype(int)

# %%
tokido
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021   $23,708.95            4         4.44%    $14,000.00             2
# 2   2020   $23,394.95            2         4.39%         $0.00             0
# 3   2019   $28,184.95            7         5.28%         $0.00             0
# 4   2018  $225,598.00           14        42.29%         $0.00             0
# 5   2017  $122,000.00            9        22.87%         $0.00             0
# 6   2016   $44,274.50            9         8.30%         $0.00             0
# 7   2015   $18,080.22            6         3.39%         $0.00             0
# 8   2014   $12,735.00            7         2.39%         $0.00             0
# 9   2013    $5,883.52            7         1.10%         $0.00             0
# 10  2012   $15,200.00           11         2.85%         $0.00             0
# 11  2011    $3,508.00            4         0.66%         $0.00             0
# ...

# %%
tokido_games = pd.read_html(str(tables), skiprows=1)

# %%
tokido_games = tokido_games[2]
tokido_games
# Out:
#                                         0              1              2   \
# 0                                      NaN  Total Results  Total Results
# 1             BlazBlue: Continuum Shift II        $208.00              1
# 2                         Capcom vs. SNK 2        $500.00              2
# 3                          Dead or Alive 5          $0.00              1
# 4               Guilty Gear XX Accent Core         $83.33              1
# 5                  Hyper Street Fighter II      $1,000.00              1
# 6                    King of Fighters XIII     $11,780.60              7
# 7                      Marvel vs. Capcom 3      $1,600.00              1
# 8                          Persona 4 Arena          $0.00              1
# 9           Street Fighter III: 3rd Strike      $4,700.00              3
# 10                       Street Fighter IV      $1,106.88              1
# 11                        Street Fighter V    $166,774.50             19
# ...

# %%
tokido_games.columns = tokido_games.iloc[0]
tokido_games.head()
# Out:
# 0                           NaN  Total Results  Total Results  Total Results  \
# 0                           NaN  Total Results  Total Results  Total Results
# 1  BlazBlue: Continuum Shift II        $208.00              1          0.04%
# 2              Capcom vs. SNK 2        $500.00              2          0.09%
# 3               Dead or Alive 5          $0.00              1          0.00%
# 4    Guilty Gear XX Accent Core         $83.33              1          0.02%
#
# 0  NaN  Online Results  Online Results  Online Results  NaN  \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# 4    |           $0.00               0           0.00%    |
#
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
tokido_games = tokido_games.drop([0])
tokido_games.head()
# Out:
# 0                           NaN Total Results Total Results Total Results NaN  \
# 1  BlazBlue: Continuum Shift II       $208.00             1         0.04%   |
# 2              Capcom vs. SNK 2       $500.00             2         0.09%   |
# 3               Dead or Alive 5         $0.00             1         0.00%   |
# 4    Guilty Gear XX Accent Core        $83.33             1         0.02%   |
# 5       Hyper Street Fighter II     $1,000.00             1         0.19%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |             $208.00
# 2          $0.00              0          0.00%   |             $500.00
# 3          $0.00              0          0.00%   |               $0.00
# 4          $0.00              0          0.00%   |              $83.33
# 5          $0.00              0          0.00%   |           $1,000.00
#
# 0 Offline/LAN Results Offline/LAN Results
# ...

# %%
tokido_games['Player ID'] = 'Tokido'
tokido_games.head()
# Out:
# 0                           NaN Total Results Total Results Total Results NaN  \
# 1  BlazBlue: Continuum Shift II       $208.00             1         0.04%   |
# 2              Capcom vs. SNK 2       $500.00             2         0.09%   |
# 3               Dead or Alive 5         $0.00             1         0.00%   |
# 4    Guilty Gear XX Accent Core        $83.33             1         0.02%   |
# 5       Hyper Street Fighter II     $1,000.00             1         0.19%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |             $208.00
# 2          $0.00              0          0.00%   |             $500.00
# 3          $0.00              0          0.00%   |               $0.00
# 4          $0.00              0          0.00%   |              $83.33
# 5          $0.00              0          0.00%   |           $1,000.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
tokido_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
tokido_games.head()
# Out:
#                            Game Total Prizes Total Placed Total Percent blank  \
# 1  BlazBlue: Continuum Shift II      $208.00            1         0.04%     |
# 2              Capcom vs. SNK 2      $500.00            2         0.09%     |
# 3               Dead or Alive 5        $0.00            1         0.00%     |
# 4    Guilty Gear XX Accent Core       $83.33            1         0.02%     |
# 5       Hyper Street Fighter II    $1,000.00            1         0.19%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |        $208.00
# 2         $0.00             0          0.00%      |        $500.00
# 3         $0.00             0          0.00%      |          $0.00
# 4         $0.00             0          0.00%      |         $83.33
# 5         $0.00             0          0.00%      |      $1,000.00
#
#   Offline Placed Offline Percent Player ID
# 1              1           0.04%    Tokido
# ...

# %%
tokido_games = tokido_games.drop(columns=['blank', 'blank1'])
tokido_games
# Out:
#                                       Game Total Prizes Total Placed  \
# 1             BlazBlue: Continuum Shift II      $208.00            1
# 2                         Capcom vs. SNK 2      $500.00            2
# 3                          Dead or Alive 5        $0.00            1
# 4               Guilty Gear XX Accent Core       $83.33            1
# 5                  Hyper Street Fighter II    $1,000.00            1
# 6                    King of Fighters XIII   $11,780.60            7
# 7                      Marvel vs. Capcom 3    $1,600.00            1
# 8                          Persona 4 Arena        $0.00            1
# 9           Street Fighter III: 3rd Strike    $4,700.00            3
# 10                       Street Fighter IV    $1,106.88            1
# 11                        Street Fighter V  $166,774.50           19
# 12        Street Fighter V: Arcade Edition  $253,282.95           20
# 13      Street Fighter V: Champion Edition   $47,103.90            6
# ...

# %%
#three_games = 
#pd.concat([punk_games, sonic_fox_games, tokido_games])

# %%
#three_games.to_csv('../data/three_games.csv')

# %% [markdown]
# ## Hungrybox

# %%
hungrybox_url = 'https://www.esportsearnings.com/players/3918-hungrybox-juan-debiedma'
response = requests.get(hungrybox_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
hungrybox = pd.read_html(str(tables), skiprows=1)
len(hungrybox)
# Out:
# 6

# %%
hungrybox = hungrybox[0]
hungrybox
# Out:
#         0              1              2              3    4               5   \
# 0      NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1   2021.0     $19,420.28              5          4.98%    |         $740.00
# 2   2020.0     $23,697.99             10          6.07%    |       $1,311.05
# 3   2019.0     $26,886.95             20          6.89%    |           $0.00
# 4   2018.0     $65,321.48             29         16.73%    |           $0.00
# 5   2017.0     $99,194.41             47         25.41%    |           $0.00
# 6   2016.0     $85,465.61             57         21.90%    |           $0.00
# 7   2015.0     $41,507.22             42         10.63%    |           $0.00
# 8   2014.0     $11,810.20             28          3.03%    |           $0.00
# 9   2013.0      $4,300.75             16          1.10%    |           $0.00
# 10  2012.0      $3,231.24             13          0.83%    |           $0.00
# ...

# %%
hungrybox.columns = hungrybox.iloc[0]
hungrybox.head()
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $19,420.28              5          4.98%    |         $740.00
# 2  2020.0     $23,697.99             10          6.07%    |       $1,311.05
# 3  2019.0     $26,886.95             20          6.89%    |           $0.00
# 4  2018.0     $65,321.48             29         16.73%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               4           0.19%    |           $18,680.28
# 2               5           0.34%    |           $22,386.94
# 3               0           0.00%    |           $26,886.95
# 4               0           0.00%    |           $65,321.48
#
# 0  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                4.79%
# ...

# %%
hungrybox = hungrybox.drop([0])
hungrybox.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $19,420.28             5         4.98%   |        $740.00
# 2  2020.0    $23,697.99            10         6.07%   |      $1,311.05
# 3  2019.0    $26,886.95            20         6.89%   |          $0.00
# 4  2018.0    $65,321.48            29        16.73%   |          $0.00
# 5  2017.0    $99,194.41            47        25.41%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              4          0.19%   |          $18,680.28                   1
# 2              5          0.34%   |          $22,386.94                   5
# 3              0          0.00%   |          $26,886.95                  20
# 4              0          0.00%   |          $65,321.48                  29
# 5              0          0.00%   |          $99,194.41                  47
#
# 0 Offline/LAN Results
# 1               4.79%
# 2               5.74%
# ...

# %%
hungrybox['Player ID'] = 'Hungrybox'
hungrybox.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $19,420.28             5         4.98%   |        $740.00
# 2  2020.0    $23,697.99            10         6.07%   |      $1,311.05
# 3  2019.0    $26,886.95            20         6.89%   |          $0.00
# 4  2018.0    $65,321.48            29        16.73%   |          $0.00
# 5  2017.0    $99,194.41            47        25.41%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              4          0.19%   |          $18,680.28                   1
# 2              5          0.34%   |          $22,386.94                   5
# 3              0          0.00%   |          $26,886.95                  20
# 4              0          0.00%   |          $65,321.48                  29
# 5              0          0.00%   |          $99,194.41                  47
#
# 0 Offline/LAN Results  Player ID
# 1               4.79%  Hungrybox
# ...

# %%
hungrybox.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
hungrybox.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $19,420.28            5         4.98%     |       $740.00
# 2  2020.0   $23,697.99           10         6.07%     |     $1,311.05
# 3  2019.0   $26,886.95           20         6.89%     |         $0.00
# 4  2018.0   $65,321.48           29        16.73%     |         $0.00
# 5  2017.0   $99,194.41           47        25.41%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             4          0.19%      |     $18,680.28              1
# 2             5          0.34%      |     $22,386.94              5
# 3             0          0.00%      |     $26,886.95             20
# 4             0          0.00%      |     $65,321.48             29
# 5             0          0.00%      |     $99,194.41             47
#
#   Offline Percent  Player ID
# 1           4.79%  Hungrybox
# 2           5.74%  Hungrybox
# 3           6.89%  Hungrybox
# ...

# %%
hungrybox['Year'] = hungrybox['Year'].round().astype(int)
hungrybox.head()
# Out:
#    Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021   $19,420.28            5         4.98%     |       $740.00
# 2  2020   $23,697.99           10         6.07%     |     $1,311.05
# 3  2019   $26,886.95           20         6.89%     |         $0.00
# 4  2018   $65,321.48           29        16.73%     |         $0.00
# 5  2017   $99,194.41           47        25.41%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             4          0.19%      |     $18,680.28              1
# 2             5          0.34%      |     $22,386.94              5
# 3             0          0.00%      |     $26,886.95             20
# 4             0          0.00%      |     $65,321.48             29
# 5             0          0.00%      |     $99,194.41             47
#
#   Offline Percent  Player ID
# 1           4.79%  Hungrybox
# 2           5.74%  Hungrybox
# 3           6.89%  Hungrybox
# ...

# %%
hungrybox = hungrybox.drop(columns=['blank', 'blank1'])
hungrybox
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021   $19,420.28            5         4.98%       $740.00             4
# 2   2020   $23,697.99           10         6.07%     $1,311.05             5
# 3   2019   $26,886.95           20         6.89%         $0.00             0
# 4   2018   $65,321.48           29        16.73%         $0.00             0
# 5   2017   $99,194.41           47        25.41%         $0.00             0
# 6   2016   $85,465.61           57        21.90%         $0.00             0
# 7   2015   $41,507.22           42        10.63%         $0.00             0
# 8   2014   $11,810.20           28         3.03%         $0.00             0
# 9   2013    $4,300.75           16         1.10%         $0.00             0
# 10  2012    $3,231.24           13         0.83%         $0.00             0
# 11  2011    $2,859.30           12         0.73%         $0.00             0
# ...

# %%
hungrybox_games = pd.read_html(str(tables), skiprows=1)

# %%
hungrybox_games = hungrybox_games[2]
hungrybox_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $3,757.20             21          0.96%
# 2      Super Smash Bros. Melee    $385,802.48            274         98.84%
# 3   Super Smash Bros. Ultimate        $716.43              6          0.18%
# 4  Super Smash Bros. for Wii U         $66.00              1          0.02%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |       $1,476.05               4           0.38%    |
# 3    |         $575.00               5           0.15%    |
# 4    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
hungrybox_games.columns = hungrybox_games.iloc[0]

# %%
hungrybox_games = hungrybox_games.drop([0])
hungrybox_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $3,757.20            21         0.96%   |
# 2      Super Smash Bros. Melee   $385,802.48           274        98.84%   |
# 3   Super Smash Bros. Ultimate       $716.43             6         0.18%   |
# 4  Super Smash Bros. for Wii U        $66.00             1         0.02%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $3,757.20
# 2      $1,476.05              4          0.38%   |         $384,326.43
# 3        $575.00              5          0.15%   |             $141.43
# 4          $0.00              0          0.00%   |              $66.00
#
# 0 Offline/LAN Results Offline/LAN Results
# 1                  21               0.96%
# 2                 270              98.46%
# 3                   1               0.04%
# 4                   1               0.02%

# %%
hungrybox_games['Player ID'] = 'Hungrybox'
hungrybox_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $3,757.20            21         0.96%   |
# 2      Super Smash Bros. Melee   $385,802.48           274        98.84%   |
# 3   Super Smash Bros. Ultimate       $716.43             6         0.18%   |
# 4  Super Smash Bros. for Wii U        $66.00             1         0.02%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $3,757.20
# 2      $1,476.05              4          0.38%   |         $384,326.43
# 3        $575.00              5          0.15%   |             $141.43
# 4          $0.00              0          0.00%   |              $66.00
#
# 0 Offline/LAN Results Offline/LAN Results  Player ID
# 1                  21               0.96%  Hungrybox
# 2                 270              98.46%  Hungrybox
# 3                   1               0.04%  Hungrybox
# ...

# %%
hungrybox_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed'
, 'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
hungrybox_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1                    Project M    $3,757.20           21         0.96%     |
# 2      Super Smash Bros. Melee  $385,802.48          274        98.84%     |
# 3   Super Smash Bros. Ultimate      $716.43            6         0.18%     |
# 4  Super Smash Bros. for Wii U       $66.00            1         0.02%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $3,757.20
# 2     $1,476.05             4          0.38%      |    $384,326.43
# 3       $575.00             5          0.15%      |        $141.43
# 4         $0.00             0          0.00%      |         $66.00
#
#   Offline Placed Offline Percent  Player ID
# 1             21           0.96%  Hungrybox
# 2            270          98.46%  Hungrybox
# 3              1           0.04%  Hungrybox
# 4              1           0.02%  Hungrybox

# %%
hungrybox_games = hungrybox_games.drop(columns=['blank', 'blank1'])
hungrybox_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M    $3,757.20           21         0.96%
# 2      Super Smash Bros. Melee  $385,802.48          274        98.84%
# 3   Super Smash Bros. Ultimate      $716.43            6         0.18%
# 4  Super Smash Bros. for Wii U       $66.00            1         0.02%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $3,757.20             21
# 2     $1,476.05             4          0.38%    $384,326.43            270
# 3       $575.00             5          0.15%        $141.43              1
# 4         $0.00             0          0.00%         $66.00              1
#
#   Offline Percent  Player ID
# 1           0.96%  Hungrybox
# 2          98.46%  Hungrybox
# 3           0.04%  Hungrybox
# 4           0.02%  Hungrybox

# %% [markdown]
# ## NuckleDu

# %%
nuckledu_url = 'https://www.esportsearnings.com/players/3605-nuckledu-du-cong-dang'
response = requests.get(nuckledu_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
nuckledu = pd.read_html(str(tables), skiprows=1)
len(nuckledu)
# Out:
# 6

# %%
nuckledu = nuckledu[0]
nuckledu
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2020.0      $3,100.70              8          0.93%    |       $2,005.29
# 2  2019.0      $6,662.33              8          1.99%    |           $0.00
# 3  2018.0     $13,010.03             14          3.89%    |           $0.00
# 4  2017.0     $44,924.86             16         13.44%    |           $0.00
# 5  2016.0    $254,711.15             16         76.18%    |           $0.00
# 6  2015.0     $11,194.20              8          3.35%    |           $0.00
# 7  2014.0        $374.70              9          0.11%    |           $0.00
# 8  2013.0         $63.00              3          0.02%    |           $0.00
# 9  2012.0        $300.00              1          0.09%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# ...

# %%
nuckledu.columns = nuckledu.iloc[0]

# %%
nuckledu = nuckledu.drop([0])

# %%
nuckledu
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0     $3,100.70             8         0.93%   |      $2,005.29
# 2  2019.0     $6,662.33             8         1.99%   |          $0.00
# 3  2018.0    $13,010.03            14         3.89%   |          $0.00
# 4  2017.0    $44,924.86            16        13.44%   |          $0.00
# 5  2016.0   $254,711.15            16        76.18%   |          $0.00
# 6  2015.0    $11,194.20             8         3.35%   |          $0.00
# 7  2014.0       $374.70             9         0.11%   |          $0.00
# 8  2013.0        $63.00             3         0.02%   |          $0.00
# 9  2012.0       $300.00             1         0.09%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              7          0.60%   |           $1,095.41                   1
# 2              0          0.00%   |           $6,662.33                   8
# ...

# %%
nuckledu['Player ID'] = 'NuckleDu'
nuckledu
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0     $3,100.70             8         0.93%   |      $2,005.29
# 2  2019.0     $6,662.33             8         1.99%   |          $0.00
# 3  2018.0    $13,010.03            14         3.89%   |          $0.00
# 4  2017.0    $44,924.86            16        13.44%   |          $0.00
# 5  2016.0   $254,711.15            16        76.18%   |          $0.00
# 6  2015.0    $11,194.20             8         3.35%   |          $0.00
# 7  2014.0       $374.70             9         0.11%   |          $0.00
# 8  2013.0        $63.00             3         0.02%   |          $0.00
# 9  2012.0       $300.00             1         0.09%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              7          0.60%   |           $1,095.41                   1
# 2              0          0.00%   |           $6,662.33                   8
# ...

# %%
nuckledu.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
nuckledu
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2020.0    $3,100.70            8         0.93%     |     $2,005.29
# 2  2019.0    $6,662.33            8         1.99%     |         $0.00
# 3  2018.0   $13,010.03           14         3.89%     |         $0.00
# 4  2017.0   $44,924.86           16        13.44%     |         $0.00
# 5  2016.0  $254,711.15           16        76.18%     |         $0.00
# 6  2015.0   $11,194.20            8         3.35%     |         $0.00
# 7  2014.0      $374.70            9         0.11%     |         $0.00
# 8  2013.0       $63.00            3         0.02%     |         $0.00
# 9  2012.0      $300.00            1         0.09%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             7          0.60%      |      $1,095.41              1
# 2             0          0.00%      |      $6,662.33              8
# ...

# %%
nuckledu = nuckledu.drop(columns=['blank', 'blank1'])

# %%
nuckledu['Year'] = nuckledu['Year'].round().astype(int)
nuckledu
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2020    $3,100.70            8         0.93%     $2,005.29             7
# 2  2019    $6,662.33            8         1.99%         $0.00             0
# 3  2018   $13,010.03           14         3.89%         $0.00             0
# 4  2017   $44,924.86           16        13.44%         $0.00             0
# 5  2016  $254,711.15           16        76.18%         $0.00             0
# 6  2015   $11,194.20            8         3.35%         $0.00             0
# 7  2014      $374.70            9         0.11%         $0.00             0
# 8  2013       $63.00            3         0.02%         $0.00             0
# 9  2012      $300.00            1         0.09%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.60%      $1,095.41              1           0.33%  NuckleDu
# ...

# %%
nuckledu_games = pd.read_html(str(tables), skiprows=1)

# %%
nuckledu_games = nuckledu_games[2]
nuckledu_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                        Street Fighter V    $297,423.71             26
# 2        Street Fighter V: Arcade Edition     $20,752.42             22
# 3      Street Fighter V: Champion Edition      $2,005.29              7
# 4                 Street Fighter X Tekken        $363.00              7
# 5  Super Street Fighter IV Arcade Edition         $53.20              3
# 6                 Ultra Street Fighter IV     $13,743.35             18
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1         88.96%    |           $0.00               0           0.00%    |
# 2          6.21%    |           $0.00               0           0.00%    |
# 3          0.60%    |       $2,005.29               7           0.60%    |
# ...

# %%
nuckledu_games.columns = nuckledu_games.iloc[0]

# %%
nuckledu_games = nuckledu_games.drop([0])

# %%
nuckledu_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                        Street Fighter V   $297,423.71            26
# 2        Street Fighter V: Arcade Edition    $20,752.42            22
# 3      Street Fighter V: Champion Edition     $2,005.29             7
# 4                 Street Fighter X Tekken       $363.00             7
# 5  Super Street Fighter IV Arcade Edition        $53.20             3
# 6                 Ultra Street Fighter IV    $13,743.35            18
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        88.96%   |          $0.00              0          0.00%   |
# 2         6.21%   |          $0.00              0          0.00%   |
# 3         0.60%   |      $2,005.29              7          0.60%   |
# 4         0.11%   |          $0.00              0          0.00%   |
# 5         0.02%   |          $0.00              0          0.00%   |
# ...

# %%
nuckledu_games['Player ID'] = 'NuckleDu'
nuckledu_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                        Street Fighter V   $297,423.71            26
# 2        Street Fighter V: Arcade Edition    $20,752.42            22
# 3      Street Fighter V: Champion Edition     $2,005.29             7
# 4                 Street Fighter X Tekken       $363.00             7
# 5  Super Street Fighter IV Arcade Edition        $53.20             3
# 6                 Ultra Street Fighter IV    $13,743.35            18
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        88.96%   |          $0.00              0          0.00%   |
# 2         6.21%   |          $0.00              0          0.00%   |
# 3         0.60%   |      $2,005.29              7          0.60%   |
# 4         0.11%   |          $0.00              0          0.00%   |
# 5         0.02%   |          $0.00              0          0.00%   |
# ...

# %%
nuckledu_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
nuckledu_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                        Street Fighter V  $297,423.71           26
# 2        Street Fighter V: Arcade Edition   $20,752.42           22
# 3      Street Fighter V: Champion Edition    $2,005.29            7
# 4                 Street Fighter X Tekken      $363.00            7
# 5  Super Street Fighter IV Arcade Edition       $53.20            3
# 6                 Ultra Street Fighter IV   $13,743.35           18
#
#   Total Percent blank Online Prizes Online Placed Online Percent blank1  \
# 1        88.96%     |         $0.00             0          0.00%      |
# 2         6.21%     |         $0.00             0          0.00%      |
# 3         0.60%     |     $2,005.29             7          0.60%      |
# 4         0.11%     |         $0.00             0          0.00%      |
# 5         0.02%     |         $0.00             0          0.00%      |
# ...

# %%
nuckledu_games = nuckledu_games.drop(columns=['blank', 'blank1'])
nuckledu_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                        Street Fighter V  $297,423.71           26
# 2        Street Fighter V: Arcade Edition   $20,752.42           22
# 3      Street Fighter V: Champion Edition    $2,005.29            7
# 4                 Street Fighter X Tekken      $363.00            7
# 5  Super Street Fighter IV Arcade Edition       $53.20            3
# 6                 Ultra Street Fighter IV   $13,743.35           18
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1        88.96%         $0.00             0          0.00%    $297,423.71
# 2         6.21%         $0.00             0          0.00%     $20,752.42
# 3         0.60%     $2,005.29             7          0.60%          $0.00
# 4         0.11%         $0.00             0          0.00%        $363.00
# 5         0.02%         $0.00             0          0.00%         $53.20
# ...

# %% [markdown]
# ## Gachikun

# %%
gachikun_url = 'https://www.esportsearnings.com/players/16031-gachikun-kanamori-tsunehiro'
response = requests.get(gachikun_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
gachikun = pd.read_html(str(tables), skiprows=1)

# %%
gachikun = gachikun[0]
gachikun
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $21,000.95              4          6.57%    |      $19,300.00
# 2  2019.0      $4,996.67              5          1.56%    |           $0.00
# 3  2018.0    $284,614.10              8         89.02%    |           $0.00
# 4  2017.0      $8,609.60              5          2.69%    |           $0.00
# 5  2016.0        $500.00              1          0.16%    |           $0.00
# 6  2015.0          $0.00              1          0.00%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               2           6.04%    |            $1,700.95
# 2               0           0.00%    |            $4,996.67
# 3               0           0.00%    |          $284,614.10
# ...

# %%
gachikun.columns = gachikun.iloc[0]

# %%
gachikun = gachikun.drop([0])

# %%
gachikun
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $21,000.95             4         6.57%   |     $19,300.00
# 2  2019.0     $4,996.67             5         1.56%   |          $0.00
# 3  2018.0   $284,614.10             8        89.02%   |          $0.00
# 4  2017.0     $8,609.60             5         2.69%   |          $0.00
# 5  2016.0       $500.00             1         0.16%   |          $0.00
# 6  2015.0         $0.00             1         0.00%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          6.04%   |           $1,700.95                   2
# 2              0          0.00%   |           $4,996.67                   5
# 3              0          0.00%   |         $284,614.10                   8
# 4              0          0.00%   |           $8,609.60                   5
# 5              0          0.00%   |             $500.00                   1
# ...

# %%
gachikun['Player ID'] = 'Gachikun'

# %%
gachikun.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
gachikun
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $21,000.95            4         6.57%     |    $19,300.00
# 2  2019.0    $4,996.67            5         1.56%     |         $0.00
# 3  2018.0  $284,614.10            8        89.02%     |         $0.00
# 4  2017.0    $8,609.60            5         2.69%     |         $0.00
# 5  2016.0      $500.00            1         0.16%     |         $0.00
# 6  2015.0        $0.00            1         0.00%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             2          6.04%      |      $1,700.95              2
# 2             0          0.00%      |      $4,996.67              5
# 3             0          0.00%      |    $284,614.10              8
# 4             0          0.00%      |      $8,609.60              5
# 5             0          0.00%      |        $500.00              1
# ...

# %%
gachikun = gachikun.drop(columns=['blank', 'blank1'])
gachikun
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021.0   $21,000.95            4         6.57%    $19,300.00             2
# 2  2019.0    $4,996.67            5         1.56%         $0.00             0
# 3  2018.0  $284,614.10            8        89.02%         $0.00             0
# 4  2017.0    $8,609.60            5         2.69%         $0.00             0
# 5  2016.0      $500.00            1         0.16%         $0.00             0
# 6  2015.0        $0.00            1         0.00%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          6.04%      $1,700.95              2           0.53%  Gachikun
# 2          0.00%      $4,996.67              5           1.56%  Gachikun
# 3          0.00%    $284,614.10              8          89.02%  Gachikun
# 4          0.00%      $8,609.60              5           2.69%  Gachikun
# ...

# %%
gachikun['Year'] = gachikun['Year'].round().astype(int)
gachikun
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $21,000.95            4         6.57%    $19,300.00             2
# 2  2019    $4,996.67            5         1.56%         $0.00             0
# 3  2018  $284,614.10            8        89.02%         $0.00             0
# 4  2017    $8,609.60            5         2.69%         $0.00             0
# 5  2016      $500.00            1         0.16%         $0.00             0
# 6  2015        $0.00            1         0.00%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          6.04%      $1,700.95              2           0.53%  Gachikun
# 2          0.00%      $4,996.67              5           1.56%  Gachikun
# 3          0.00%    $284,614.10              8          89.02%  Gachikun
# 4          0.00%      $8,609.60              5           2.69%  Gachikun
# ...

# %%
gachikun_games = pd.read_html(str(tables), skiprows=1)

# %%
gachikun_games = gachikun_games[2]
gachikun_games
# Out:
#                                    0              1              2   \
# 0                                 NaN  Total Results  Total Results
# 1                    Street Fighter V      $9,109.60              6
# 2    Street Fighter V: Arcade Edition    $289,610.77             13
# 3  Street Fighter V: Champion Edition     $21,000.95              4
# 4             Ultra Street Fighter IV          $0.00              1
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          2.85%    |           $0.00               0           0.00%    |
# 2         90.58%    |           $0.00               0           0.00%    |
# 3          6.57%    |      $19,300.00               2           6.04%    |
# 4          0.00%    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# ...

# %%
gachikun_games.columns = gachikun_games.iloc[0]
gachikun_games
# Out:
# 0                                 NaN  Total Results  Total Results  \
# 0                                 NaN  Total Results  Total Results
# 1                    Street Fighter V      $9,109.60              6
# 2    Street Fighter V: Arcade Edition    $289,610.77             13
# 3  Street Fighter V: Champion Edition     $21,000.95              4
# 4             Ultra Street Fighter IV          $0.00              1
#
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN  \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          2.85%    |           $0.00               0           0.00%    |
# 2         90.58%    |           $0.00               0           0.00%    |
# 3          6.57%    |      $19,300.00               2           6.04%    |
# 4          0.00%    |           $0.00               0           0.00%    |
#
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
gachikun_games = gachikun_games.drop([0])
gachikun_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                    Street Fighter V     $9,109.60             6
# 2    Street Fighter V: Arcade Edition   $289,610.77            13
# 3  Street Fighter V: Champion Edition    $21,000.95             4
# 4             Ultra Street Fighter IV         $0.00             1
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         2.85%   |          $0.00              0          0.00%   |
# 2        90.58%   |          $0.00              0          0.00%   |
# 3         6.57%   |     $19,300.00              2          6.04%   |
# 4         0.00%   |          $0.00              0          0.00%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results
# 1           $9,109.60                   6               2.85%
# 2         $289,610.77                  13              90.58%
# 3           $1,700.95                   2               0.53%
# ...

# %%
gachikun_games['Player ID'] = 'Gachikun'
gachikun_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                    Street Fighter V     $9,109.60             6
# 2    Street Fighter V: Arcade Edition   $289,610.77            13
# 3  Street Fighter V: Champion Edition    $21,000.95             4
# 4             Ultra Street Fighter IV         $0.00             1
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         2.85%   |          $0.00              0          0.00%   |
# 2        90.58%   |          $0.00              0          0.00%   |
# 3         6.57%   |     $19,300.00              2          6.04%   |
# 4         0.00%   |          $0.00              0          0.00%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1           $9,109.60                   6               2.85%  Gachikun
# 2         $289,610.77                  13              90.58%  Gachikun
# ...

# %%
gachikun_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
gachikun_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V    $9,109.60            6         2.85%
# 2    Street Fighter V: Arcade Edition  $289,610.77           13        90.58%
# 3  Street Fighter V: Champion Edition   $21,000.95            4         6.57%
# 4             Ultra Street Fighter IV        $0.00            1         0.00%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |      $9,109.60
# 2     |         $0.00             0          0.00%      |    $289,610.77
# 3     |    $19,300.00             2          6.04%      |      $1,700.95
# 4     |         $0.00             0          0.00%      |          $0.00
#
#   Offline Placed Offline Percent Player ID
# 1              6           2.85%  Gachikun
# 2             13          90.58%  Gachikun
# 3              2           0.53%  Gachikun
# ...

# %%
gachikun_games = gachikun_games.drop(columns=['blank', 'blank1'])
gachikun_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V    $9,109.60            6         2.85%
# 2    Street Fighter V: Arcade Edition  $289,610.77           13        90.58%
# 3  Street Fighter V: Champion Edition   $21,000.95            4         6.57%
# 4             Ultra Street Fighter IV        $0.00            1         0.00%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $9,109.60              6
# 2         $0.00             0          0.00%    $289,610.77             13
# 3    $19,300.00             2          6.04%      $1,700.95              2
# 4         $0.00             0          0.00%          $0.00              1
#
#   Offline Percent Player ID
# 1           2.85%  Gachikun
# 2          90.58%  Gachikun
# 3           0.53%  Gachikun
# 4           0.00%  Gachikun

# %% [markdown]
# ## Armada

# %%
armada_url = 'https://www.esportsearnings.com/players/3919-armada-adam-lindgren'
response = requests.get(armada_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
armada = pd.read_html(str(tables), skiprows=1)

# %%
armada = armada[0]
armada
# Out:
#         0              1              2              3    4               5   \
# 0      NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1   2019.0      $1,307.26              4          0.42%    |           $0.00
# 2   2018.0     $25,422.03             15          8.12%    |           $0.00
# 3   2017.0     $90,356.67             33         28.85%    |           $0.00
# 4   2016.0     $83,003.77             35         26.51%    |           $0.00
# 5   2015.0     $72,934.52             45         23.29%    |           $0.00
# 6   2014.0     $16,434.72             37          5.25%    |           $0.00
# 7   2013.0      $4,374.30              3          1.40%    |           $0.00
# 8   2012.0      $5,663.00              6          1.81%    |           $0.00
# 9   2011.0      $7,646.34             10          2.44%    |           $0.00
# 10  2010.0      $1,827.66              5          0.58%    |           $0.00
# ...

# %%
armada.columns = armada.iloc[0]
armada.head()
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2019.0      $1,307.26              4          0.42%    |           $0.00
# 2  2018.0     $25,422.03             15          8.12%    |           $0.00
# 3  2017.0     $90,356.67             33         28.85%    |           $0.00
# 4  2016.0     $83,003.77             35         26.51%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |            $1,307.26
# 2               0           0.00%    |           $25,422.03
# 3               0           0.00%    |           $90,356.67
# 4               0           0.00%    |           $83,003.77
#
# 0  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    4                0.42%
# ...

# %%
armada = armada.drop([0])
armada.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0     $1,307.26             4         0.42%   |          $0.00
# 2  2018.0    $25,422.03            15         8.12%   |          $0.00
# 3  2017.0    $90,356.67            33        28.85%   |          $0.00
# 4  2016.0    $83,003.77            35        26.51%   |          $0.00
# 5  2015.0    $72,934.52            45        23.29%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,307.26                   4
# 2              0          0.00%   |          $25,422.03                  15
# 3              0          0.00%   |          $90,356.67                  33
# 4              0          0.00%   |          $83,003.77                  35
# 5              0          0.00%   |          $72,934.52                  45
#
# 0 Offline/LAN Results
# 1               0.42%
# 2               8.12%
# ...

# %%
armada['Player ID'] = 'Armada'
armada.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0     $1,307.26             4         0.42%   |          $0.00
# 2  2018.0    $25,422.03            15         8.12%   |          $0.00
# 3  2017.0    $90,356.67            33        28.85%   |          $0.00
# 4  2016.0    $83,003.77            35        26.51%   |          $0.00
# 5  2015.0    $72,934.52            45        23.29%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,307.26                   4
# 2              0          0.00%   |          $25,422.03                  15
# 3              0          0.00%   |          $90,356.67                  33
# 4              0          0.00%   |          $83,003.77                  35
# 5              0          0.00%   |          $72,934.52                  45
#
# 0 Offline/LAN Results Player ID
# 1               0.42%    Armada
# ...

# %%
armada.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
armada.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2019.0    $1,307.26            4         0.42%     |         $0.00
# 2  2018.0   $25,422.03           15         8.12%     |         $0.00
# 3  2017.0   $90,356.67           33        28.85%     |         $0.00
# 4  2016.0   $83,003.77           35        26.51%     |         $0.00
# 5  2015.0   $72,934.52           45        23.29%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $1,307.26              4
# 2             0          0.00%      |     $25,422.03             15
# 3             0          0.00%      |     $90,356.67             33
# 4             0          0.00%      |     $83,003.77             35
# 5             0          0.00%      |     $72,934.52             45
#
#   Offline Percent Player ID
# 1           0.42%    Armada
# 2           8.12%    Armada
# 3          28.85%    Armada
# ...

# %%
armada = armada.drop(columns=['blank', 'blank1'])
armada.head()
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2019.0    $1,307.26            4         0.42%         $0.00             0
# 2  2018.0   $25,422.03           15         8.12%         $0.00             0
# 3  2017.0   $90,356.67           33        28.85%         $0.00             0
# 4  2016.0   $83,003.77           35        26.51%         $0.00             0
# 5  2015.0   $72,934.52           45        23.29%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%      $1,307.26              4           0.42%    Armada
# 2          0.00%     $25,422.03             15           8.12%    Armada
# 3          0.00%     $90,356.67             33          28.85%    Armada
# 4          0.00%     $83,003.77             35          26.51%    Armada
# 5          0.00%     $72,934.52             45          23.29%    Armada

# %%
armada['Year'] = armada['Year'].round().astype(int)
armada
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2019    $1,307.26            4         0.42%         $0.00             0
# 2   2018   $25,422.03           15         8.12%         $0.00             0
# 3   2017   $90,356.67           33        28.85%         $0.00             0
# 4   2016   $83,003.77           35        26.51%         $0.00             0
# 5   2015   $72,934.52           45        23.29%         $0.00             0
# 6   2014   $16,434.72           37         5.25%         $0.00             0
# 7   2013    $4,374.30            3         1.40%         $0.00             0
# 8   2012    $5,663.00            6         1.81%         $0.00             0
# 9   2011    $7,646.34           10         2.44%         $0.00             0
# 10  2010    $1,827.66            5         0.58%         $0.00             0
# 11  2009    $3,388.52            3         1.08%         $0.00             0
# ...

# %%
armada_games = pd.read_html(str(tables), skiprows=1)

# %%
armada_games = armada_games[2]
armada_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $4,922.53             16          1.57%
# 2      Super Smash Bros. Melee    $306,902.46            179         98.00%
# 3   Super Smash Bros. Ultimate      $1,250.06              3          0.40%
# 4  Super Smash Bros. for Wii U         $80.53              1          0.03%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# 4    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
armada_games.columns = armada_games.iloc[0]

# %%
armada_games = armada_games.drop([0])
armada_games.head()
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $4,922.53            16         1.57%   |
# 2      Super Smash Bros. Melee   $306,902.46           179        98.00%   |
# 3   Super Smash Bros. Ultimate     $1,250.06             3         0.40%   |
# 4  Super Smash Bros. for Wii U        $80.53             1         0.03%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $4,922.53
# 2          $0.00              0          0.00%   |         $306,902.46
# 3          $0.00              0          0.00%   |           $1,250.06
# 4          $0.00              0          0.00%   |              $80.53
#
# 0 Offline/LAN Results Offline/LAN Results
# 1                  16               1.57%
# 2                 179              98.00%
# 3                   3               0.40%
# 4                   1               0.03%

# %%
armada_games['Player ID'] = 'Armada'
armada_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $4,922.53            16         1.57%   |
# 2      Super Smash Bros. Melee   $306,902.46           179        98.00%   |
# 3   Super Smash Bros. Ultimate     $1,250.06             3         0.40%   |
# 4  Super Smash Bros. for Wii U        $80.53             1         0.03%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $4,922.53
# 2          $0.00              0          0.00%   |         $306,902.46
# 3          $0.00              0          0.00%   |           $1,250.06
# 4          $0.00              0          0.00%   |              $80.53
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                  16               1.57%    Armada
# 2                 179              98.00%    Armada
# 3                   3               0.40%    Armada
# ...

# %%
armada_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
armada_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1                    Project M    $4,922.53           16         1.57%     |
# 2      Super Smash Bros. Melee  $306,902.46          179        98.00%     |
# 3   Super Smash Bros. Ultimate    $1,250.06            3         0.40%     |
# 4  Super Smash Bros. for Wii U       $80.53            1         0.03%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $4,922.53
# 2         $0.00             0          0.00%      |    $306,902.46
# 3         $0.00             0          0.00%      |      $1,250.06
# 4         $0.00             0          0.00%      |         $80.53
#
#   Offline Placed Offline Percent Player ID
# 1             16           1.57%    Armada
# 2            179          98.00%    Armada
# 3              3           0.40%    Armada
# 4              1           0.03%    Armada

# %%
armada_games = armada_games.drop(columns=['blank', 'blank1'])
armada_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M    $4,922.53           16         1.57%
# 2      Super Smash Bros. Melee  $306,902.46          179        98.00%
# 3   Super Smash Bros. Ultimate    $1,250.06            3         0.40%
# 4  Super Smash Bros. for Wii U       $80.53            1         0.03%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $4,922.53             16
# 2         $0.00             0          0.00%    $306,902.46            179
# 3         $0.00             0          0.00%      $1,250.06              3
# 4         $0.00             0          0.00%         $80.53              1
#
#   Offline Percent Player ID
# 1           1.57%    Armada
# 2          98.00%    Armada
# 3           0.40%    Armada
# 4           0.03%    Armada

# %% [markdown]
# ## iDom

# %%
idom_url = 'https://www.esportsearnings.com/players/51250-idom-derek-ruffin'
response = requests.get(idom_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
idom = pd.read_html(str(tables), skiprows=1)

# %%
idom = idom[0]
idom
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $18,869.08             28          6.45%    |      $13,465.38
# 2  2020.0      $9,044.13             33          3.09%    |       $9,044.13
# 3  2019.0    $255,730.80              5         87.43%    |           $0.00
# 4  2018.0      $2,714.00              4          0.93%    |           $0.00
# 5  2017.0      $6,154.00              2          2.10%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1              26           4.60%    |            $5,403.70
# 2              33           3.09%    |                $0.00
# 3               0           0.00%    |          $255,730.80
# 4               0           0.00%    |            $2,714.00
# 5               0           0.00%    |            $6,154.00
#
# ...

# %%
idom.columns = idom.iloc[0]

# %%
idom = idom.drop([0])
idom
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $18,869.08            28         6.45%   |     $13,465.38
# 2  2020.0     $9,044.13            33         3.09%   |      $9,044.13
# 3  2019.0   $255,730.80             5        87.43%   |          $0.00
# 4  2018.0     $2,714.00             4         0.93%   |          $0.00
# 5  2017.0     $6,154.00             2         2.10%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1             26          4.60%   |           $5,403.70                   2
# 2             33          3.09%   |               $0.00                   0
# 3              0          0.00%   |         $255,730.80                   5
# 4              0          0.00%   |           $2,714.00                   4
# 5              0          0.00%   |           $6,154.00                   2
#
# 0 Offline/LAN Results
# 1               1.85%
# 2               0.00%
# ...

# %%
idom['Player ID'] = 'iDom'
idom
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $18,869.08            28         6.45%   |     $13,465.38
# 2  2020.0     $9,044.13            33         3.09%   |      $9,044.13
# 3  2019.0   $255,730.80             5        87.43%   |          $0.00
# 4  2018.0     $2,714.00             4         0.93%   |          $0.00
# 5  2017.0     $6,154.00             2         2.10%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1             26          4.60%   |           $5,403.70                   2
# 2             33          3.09%   |               $0.00                   0
# 3              0          0.00%   |         $255,730.80                   5
# 4              0          0.00%   |           $2,714.00                   4
# 5              0          0.00%   |           $6,154.00                   2
#
# 0 Offline/LAN Results Player ID
# 1               1.85%      iDom
# ...

# %%
idom.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
idom
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $18,869.08           28         6.45%     |    $13,465.38
# 2  2020.0    $9,044.13           33         3.09%     |     $9,044.13
# 3  2019.0  $255,730.80            5        87.43%     |         $0.00
# 4  2018.0    $2,714.00            4         0.93%     |         $0.00
# 5  2017.0    $6,154.00            2         2.10%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1            26          4.60%      |      $5,403.70              2
# 2            33          3.09%      |          $0.00              0
# 3             0          0.00%      |    $255,730.80              5
# 4             0          0.00%      |      $2,714.00              4
# 5             0          0.00%      |      $6,154.00              2
#
#   Offline Percent Player ID
# 1           1.85%      iDom
# 2           0.00%      iDom
# 3          87.43%      iDom
# ...

# %%
idom['Year'] = idom['Year'].round().astype(int)

# %%
idom = idom.drop(columns=['blank', 'blank1'])
idom
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $18,869.08           28         6.45%    $13,465.38            26
# 2  2020    $9,044.13           33         3.09%     $9,044.13            33
# 3  2019  $255,730.80            5        87.43%         $0.00             0
# 4  2018    $2,714.00            4         0.93%         $0.00             0
# 5  2017    $6,154.00            2         2.10%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          4.60%      $5,403.70              2           1.85%      iDom
# 2          3.09%          $0.00              0           0.00%      iDom
# 3          0.00%    $255,730.80              5          87.43%      iDom
# 4          0.00%      $2,714.00              4           0.93%      iDom
# 5          0.00%      $6,154.00              2           2.10%      iDom

# %%
idom_games = pd.read_html(str(tables), skiprows=1)

# %%
idom_games = idom_games[1]
idom_games
# Out:
#                                    0              1              2   \
# 0                                 NaN  Total Results  Total Results
# 1                    Street Fighter V      $6,154.00              2
# 2    Street Fighter V: Arcade Edition    $258,444.80              9
# 3  Street Fighter V: Champion Edition     $27,913.21             61
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          2.10%    |           $0.00               0           0.00%    |
# 2         88.35%    |           $0.00               0           0.00%    |
# 3          9.54%    |      $22,509.51              59           7.70%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# 1            $6,154.00                    2                2.10%
# ...

# %%
idom_games.columns = idom_games.iloc[0]

# %%
idom_games = idom_games.drop([0])
idom_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                    Street Fighter V     $6,154.00             2
# 2    Street Fighter V: Arcade Edition   $258,444.80             9
# 3  Street Fighter V: Champion Edition    $27,913.21            61
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         2.10%   |          $0.00              0          0.00%   |
# 2        88.35%   |          $0.00              0          0.00%   |
# 3         9.54%   |     $22,509.51             59          7.70%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results
# 1           $6,154.00                   2               2.10%
# 2         $258,444.80                   9              88.35%
# 3           $5,403.70                   2               1.85%

# %%
idom_games['Player ID'] = 'iDom'
idom_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                    Street Fighter V     $6,154.00             2
# 2    Street Fighter V: Arcade Edition   $258,444.80             9
# 3  Street Fighter V: Champion Edition    $27,913.21            61
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         2.10%   |          $0.00              0          0.00%   |
# 2        88.35%   |          $0.00              0          0.00%   |
# 3         9.54%   |     $22,509.51             59          7.70%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1           $6,154.00                   2               2.10%      iDom
# 2         $258,444.80                   9              88.35%      iDom
# 3           $5,403.70                   2               1.85%      iDom

# %%
idom_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
idom_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V    $6,154.00            2         2.10%
# 2    Street Fighter V: Arcade Edition  $258,444.80            9        88.35%
# 3  Street Fighter V: Champion Edition   $27,913.21           61         9.54%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |      $6,154.00
# 2     |         $0.00             0          0.00%      |    $258,444.80
# 3     |    $22,509.51            59          7.70%      |      $5,403.70
#
#   Offline Placed Offline Percent Player ID
# 1              2           2.10%      iDom
# 2              9          88.35%      iDom
# 3              2           1.85%      iDom

# %%
idom_games = idom_games.drop(columns=['blank', 'blank1'])
idom_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V    $6,154.00            2         2.10%
# 2    Street Fighter V: Arcade Edition  $258,444.80            9        88.35%
# 3  Street Fighter V: Champion Edition   $27,913.21           61         9.54%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $6,154.00              2
# 2         $0.00             0          0.00%    $258,444.80              9
# 3    $22,509.51            59          7.70%      $5,403.70              2
#
#   Offline Percent Player ID
# 1           2.10%      iDom
# 2          88.35%      iDom
# 3           1.85%      iDom

# %% [markdown]
# ## Mew2King

# %%
mew_url = 'https://www.esportsearnings.com/players/3920-mew2king-jason-zimmerman'
response = requests.get(mew_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
mew2king = pd.read_html(str(tables), skiprows=1)

# %%
mew2king = mew2king[0]
mew2king
# Out:
#         0              1              2              3    4               5   \
# 0      NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1   2020.0      $1,027.29              2          0.37%    |           $0.00
# 2   2019.0      $7,250.36             16          2.58%    |           $0.00
# 3   2018.0     $21,444.86             18          7.64%    |           $0.00
# 4   2017.0     $41,541.12             58         14.80%    |           $0.00
# 5   2016.0     $53,852.18             87         19.19%    |           $0.00
# 6   2015.0     $42,227.22             77         15.05%    |           $0.00
# 7   2014.0     $32,623.81            107         11.62%    |           $0.00
# 8   2013.0     $15,589.03             75          5.55%    |           $0.00
# 9   2012.0      $2,454.01             17          0.87%    |           $0.00
# 10  2011.0     $10,174.18             39          3.62%    |           $0.00
# ...

# %%
mew2king.columns = mew2king.iloc[0]

# %%
mew2king = mew2king.drop([0])
mew2king.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0     $1,027.29             2         0.37%   |          $0.00
# 2  2019.0     $7,250.36            16         2.58%   |          $0.00
# 3  2018.0    $21,444.86            18         7.64%   |          $0.00
# 4  2017.0    $41,541.12            58        14.80%   |          $0.00
# 5  2016.0    $53,852.18            87        19.19%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,027.29                   2
# 2              0          0.00%   |           $7,250.36                  16
# 3              0          0.00%   |          $21,444.86                  18
# 4              0          0.00%   |          $41,541.12                  58
# 5              0          0.00%   |          $53,852.18                  87
#
# 0 Offline/LAN Results
# 1               0.37%
# 2               2.58%
# ...

# %%
mew2king['Player ID'] = 'Mew2King'
mew2king.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0     $1,027.29             2         0.37%   |          $0.00
# 2  2019.0     $7,250.36            16         2.58%   |          $0.00
# 3  2018.0    $21,444.86            18         7.64%   |          $0.00
# 4  2017.0    $41,541.12            58        14.80%   |          $0.00
# 5  2016.0    $53,852.18            87        19.19%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,027.29                   2
# 2              0          0.00%   |           $7,250.36                  16
# 3              0          0.00%   |          $21,444.86                  18
# 4              0          0.00%   |          $41,541.12                  58
# 5              0          0.00%   |          $53,852.18                  87
#
# 0 Offline/LAN Results Player ID
# 1               0.37%  Mew2King
# ...

# %%
mew2king.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mew2king.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2020.0    $1,027.29            2         0.37%     |         $0.00
# 2  2019.0    $7,250.36           16         2.58%     |         $0.00
# 3  2018.0   $21,444.86           18         7.64%     |         $0.00
# 4  2017.0   $41,541.12           58        14.80%     |         $0.00
# 5  2016.0   $53,852.18           87        19.19%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $1,027.29              2
# 2             0          0.00%      |      $7,250.36             16
# 3             0          0.00%      |     $21,444.86             18
# 4             0          0.00%      |     $41,541.12             58
# 5             0          0.00%      |     $53,852.18             87
#
#   Offline Percent Player ID
# 1           0.37%  Mew2King
# 2           2.58%  Mew2King
# 3           7.64%  Mew2King
# ...

# %%
mew2king = mew2king.drop(columns=['blank', 'blank1'])
mew2king.head()
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2020.0    $1,027.29            2         0.37%         $0.00             0
# 2  2019.0    $7,250.36           16         2.58%         $0.00             0
# 3  2018.0   $21,444.86           18         7.64%         $0.00             0
# 4  2017.0   $41,541.12           58        14.80%         $0.00             0
# 5  2016.0   $53,852.18           87        19.19%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%      $1,027.29              2           0.37%  Mew2King
# 2          0.00%      $7,250.36             16           2.58%  Mew2King
# 3          0.00%     $21,444.86             18           7.64%  Mew2King
# 4          0.00%     $41,541.12             58          14.80%  Mew2King
# 5          0.00%     $53,852.18             87          19.19%  Mew2King

# %%
mew2king['Year'] = mew2king['Year'].round().astype(int)
mew2king
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2020    $1,027.29            2         0.37%         $0.00             0
# 2   2019    $7,250.36           16         2.58%         $0.00             0
# 3   2018   $21,444.86           18         7.64%         $0.00             0
# 4   2017   $41,541.12           58        14.80%         $0.00             0
# 5   2016   $53,852.18           87        19.19%         $0.00             0
# 6   2015   $42,227.22           77        15.05%         $0.00             0
# 7   2014   $32,623.81          107        11.62%         $0.00             0
# 8   2013   $15,589.03           75         5.55%         $0.00             0
# 9   2012    $2,454.01           17         0.87%         $0.00             0
# 10  2011   $10,174.18           39         3.62%         $0.00             0
# 11  2010   $12,543.80           22         4.47%         $0.00             0
# ...

# %%
mew2king_games = pd.read_html(str(tables), skiprows=1)

# %%
mew2king_games = mew2king_games[2]
mew2king_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M     $17,132.48             74          6.10%
# 2            Super Smash Bros.        $251.50              6          0.09%
# 3      Super Smash Bros. Brawl     $36,870.75             98         13.14%
# 4      Super Smash Bros. Melee    $205,016.80            353         73.05%
# 5   Super Smash Bros. Ultimate      $1,487.88              6          0.53%
# 6  Super Smash Bros. for Wii U     $19,908.34             71          7.09%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# ...

# %%
mew2king_games.columns = mew2king_games.iloc[0]
mew2king_games.head()
# Out:
# 0                      NaN  Total Results  Total Results  Total Results  NaN  \
# 0                      NaN  Total Results  Total Results  Total Results  NaN
# 1                Project M     $17,132.48             74          6.10%    |
# 2        Super Smash Bros.        $251.50              6          0.09%    |
# 3  Super Smash Bros. Brawl     $36,870.75             98         13.14%    |
# 4  Super Smash Bros. Melee    $205,016.80            353         73.05%    |
#
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |           $17,132.48
# 2           $0.00               0           0.00%    |              $251.50
# 3           $0.00               0           0.00%    |           $36,870.75
# 4           $0.00               0           0.00%    |          $205,016.80
#
# 0  Offline/LAN Results  Offline/LAN Results
# ...

# %%
mew2king_games = mew2king_games.drop([0])
mew2king_games.head()
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1                   Project M    $17,132.48            74         6.10%   |
# 2           Super Smash Bros.       $251.50             6         0.09%   |
# 3     Super Smash Bros. Brawl    $36,870.75            98        13.14%   |
# 4     Super Smash Bros. Melee   $205,016.80           353        73.05%   |
# 5  Super Smash Bros. Ultimate     $1,487.88             6         0.53%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |          $17,132.48
# 2          $0.00              0          0.00%   |             $251.50
# 3          $0.00              0          0.00%   |          $36,870.75
# 4          $0.00              0          0.00%   |         $205,016.80
# 5          $0.00              0          0.00%   |           $1,487.88
#
# 0 Offline/LAN Results Offline/LAN Results
# ...

# %%
mew2king_games['Player ID'] = 'Mew2King'
mew2king_games.head()
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1                   Project M    $17,132.48            74         6.10%   |
# 2           Super Smash Bros.       $251.50             6         0.09%   |
# 3     Super Smash Bros. Brawl    $36,870.75            98        13.14%   |
# 4     Super Smash Bros. Melee   $205,016.80           353        73.05%   |
# 5  Super Smash Bros. Ultimate     $1,487.88             6         0.53%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |          $17,132.48
# 2          $0.00              0          0.00%   |             $251.50
# 3          $0.00              0          0.00%   |          $36,870.75
# 4          $0.00              0          0.00%   |         $205,016.80
# 5          $0.00              0          0.00%   |           $1,487.88
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
mew2king_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mew2king_games.head()
# Out:
#                          Game Total Prizes Total Placed Total Percent blank  \
# 1                   Project M   $17,132.48           74         6.10%     |
# 2           Super Smash Bros.      $251.50            6         0.09%     |
# 3     Super Smash Bros. Brawl   $36,870.75           98        13.14%     |
# 4     Super Smash Bros. Melee  $205,016.80          353        73.05%     |
# 5  Super Smash Bros. Ultimate    $1,487.88            6         0.53%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |     $17,132.48
# 2         $0.00             0          0.00%      |        $251.50
# 3         $0.00             0          0.00%      |     $36,870.75
# 4         $0.00             0          0.00%      |    $205,016.80
# 5         $0.00             0          0.00%      |      $1,487.88
#
#   Offline Placed Offline Percent Player ID
# 1             74           6.10%  Mew2King
# ...

# %%
mew2king_games = mew2king_games.drop(columns=['blank', 'blank1'])
mew2king_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M   $17,132.48           74         6.10%
# 2            Super Smash Bros.      $251.50            6         0.09%
# 3      Super Smash Bros. Brawl   $36,870.75           98        13.14%
# 4      Super Smash Bros. Melee  $205,016.80          353        73.05%
# 5   Super Smash Bros. Ultimate    $1,487.88            6         0.53%
# 6  Super Smash Bros. for Wii U   $19,908.34           71         7.09%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%     $17,132.48             74
# 2         $0.00             0          0.00%        $251.50              6
# 3         $0.00             0          0.00%     $36,870.75             98
# 4         $0.00             0          0.00%    $205,016.80            353
# 5         $0.00             0          0.00%      $1,487.88              6
# ...

# %% [markdown]
# ## Dragon

# %%
dragon_url = 'https://www.esportsearnings.com/players/28330-dragon-ryan-walker'
response = requests.get(dragon_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
dragon = pd.read_html(str(tables), skiprows=1)

# %%
dragon = dragon[0]
dragon.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $3,500.00              1          1.27%    |           $0.00
# 2  2020.0     $11,725.00              3          4.25%    |       $1,725.00
# 3  2019.0     $24,450.24             10          8.87%    |         $150.00
# 4  2018.0        $300.00              1          0.11%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |            $3,500.00
# 2               2           0.63%    |           $10,000.00
# 3               1           0.05%    |           $24,300.24
# 4               0           0.00%    |              $300.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                1.27%
# ...

# %%
dragon.columns = dragon.iloc[0]

# %%
dragon = dragon.drop([0])
dragon.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $3,500.00             1         1.27%   |          $0.00
# 2  2020.0    $11,725.00             3         4.25%   |      $1,725.00
# 3  2019.0    $24,450.24            10         8.87%   |        $150.00
# 4  2018.0       $300.00             1         0.11%   |          $0.00
# 5  2017.0   $203,954.73            12        73.96%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $3,500.00                   1
# 2              2          0.63%   |          $10,000.00                   1
# 3              1          0.05%   |          $24,300.24                   9
# 4              0          0.00%   |             $300.00                   1
# 5              0          0.00%   |         $203,954.73                  12
#
# 0 Offline/LAN Results
# 1               1.27%
# 2               3.63%
# ...

# %%
dragon['Player ID'] = 'Dragon'
dragon.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $3,500.00             1         1.27%   |          $0.00
# 2  2020.0    $11,725.00             3         4.25%   |      $1,725.00
# 3  2019.0    $24,450.24            10         8.87%   |        $150.00
# 4  2018.0       $300.00             1         0.11%   |          $0.00
# 5  2017.0   $203,954.73            12        73.96%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $3,500.00                   1
# 2              2          0.63%   |          $10,000.00                   1
# 3              1          0.05%   |          $24,300.24                   9
# 4              0          0.00%   |             $300.00                   1
# 5              0          0.00%   |         $203,954.73                  12
#
# 0 Offline/LAN Results Player ID
# 1               1.27%    Dragon
# ...

# %%
dragon.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
dragon.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $3,500.00            1         1.27%     |         $0.00
# 2  2020.0   $11,725.00            3         4.25%     |     $1,725.00
# 3  2019.0   $24,450.24           10         8.87%     |       $150.00
# 4  2018.0      $300.00            1         0.11%     |         $0.00
# 5  2017.0  $203,954.73           12        73.96%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $3,500.00              1
# 2             2          0.63%      |     $10,000.00              1
# 3             1          0.05%      |     $24,300.24              9
# 4             0          0.00%      |        $300.00              1
# 5             0          0.00%      |    $203,954.73             12
#
#   Offline Percent Player ID
# 1           1.27%    Dragon
# 2           3.63%    Dragon
# 3           8.81%    Dragon
# ...

# %%
dragon = dragon.drop(columns=['blank', 'blank1'])
dragon.head()
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021.0    $3,500.00            1         1.27%         $0.00             0
# 2  2020.0   $11,725.00            3         4.25%     $1,725.00             2
# 3  2019.0   $24,450.24           10         8.87%       $150.00             1
# 4  2018.0      $300.00            1         0.11%         $0.00             0
# 5  2017.0  $203,954.73           12        73.96%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%      $3,500.00              1           1.27%    Dragon
# 2          0.63%     $10,000.00              1           3.63%    Dragon
# 3          0.05%     $24,300.24              9           8.81%    Dragon
# 4          0.00%        $300.00              1           0.11%    Dragon
# 5          0.00%    $203,954.73             12          73.96%    Dragon

# %%
dragon['Year'] = dragon['Year'].round().astype(int)
dragon
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $3,500.00            1         1.27%         $0.00             0
# 2  2020   $11,725.00            3         4.25%     $1,725.00             2
# 3  2019   $24,450.24           10         8.87%       $150.00             1
# 4  2018      $300.00            1         0.11%         $0.00             0
# 5  2017  $203,954.73           12        73.96%         $0.00             0
# 6  2016   $31,840.00            6        11.55%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%      $3,500.00              1           1.27%    Dragon
# 2          0.63%     $10,000.00              1           3.63%    Dragon
# 3          0.05%     $24,300.24              9           8.81%    Dragon
# 4          0.00%        $300.00              1           0.11%    Dragon
# ...

# %%
dragon_games = pd.read_html(str(tables), skiprows=1)

# %%
dragon_games = dragon_games[1]
dragon_games
# Out:
#                  0              1              2              3    4   \
# 0               NaN  Total Results  Total Results  Total Results  NaN
# 1       Injustice 2    $200,645.73             11         72.76%    |
# 2  Mortal Kombat 11     $39,675.24             14         14.39%    |
# 3   Mortal Kombat X     $30,874.40              3         11.20%    |
# 4  Mortal Kombat XL      $4,274.60              4          1.55%    |
# 5   Soul Calibur VI        $300.00              1          0.11%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |          $200,645.73
# 2       $1,875.00               3           0.68%    |           $37,800.24
# 3           $0.00               0           0.00%    |           $30,874.40
# 4           $0.00               0           0.00%    |            $4,274.60
# ...

# %%
dragon_games.columns = dragon_games.iloc[0]

# %%
dragon_games = dragon_games.drop([0])
dragon_games.head()
# Out:
# 0               NaN Total Results Total Results Total Results NaN  \
# 1       Injustice 2   $200,645.73            11        72.76%   |
# 2  Mortal Kombat 11    $39,675.24            14        14.39%   |
# 3   Mortal Kombat X    $30,874.40             3        11.20%   |
# 4  Mortal Kombat XL     $4,274.60             4         1.55%   |
# 5   Soul Calibur VI       $300.00             1         0.11%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |         $200,645.73
# 2      $1,875.00              3          0.68%   |          $37,800.24
# 3          $0.00              0          0.00%   |          $30,874.40
# 4          $0.00              0          0.00%   |           $4,274.60
# 5          $0.00              0          0.00%   |             $300.00
#
# 0 Offline/LAN Results Offline/LAN Results
# 1                  11              72.76%
# 2                  11              13.71%
# ...

# %%
dragon_games['Player ID'] = 'Dragon'
dragon_games
# Out:
# 0               NaN Total Results Total Results Total Results NaN  \
# 1       Injustice 2   $200,645.73            11        72.76%   |
# 2  Mortal Kombat 11    $39,675.24            14        14.39%   |
# 3   Mortal Kombat X    $30,874.40             3        11.20%   |
# 4  Mortal Kombat XL     $4,274.60             4         1.55%   |
# 5   Soul Calibur VI       $300.00             1         0.11%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |         $200,645.73
# 2      $1,875.00              3          0.68%   |          $37,800.24
# 3          $0.00              0          0.00%   |          $30,874.40
# 4          $0.00              0          0.00%   |           $4,274.60
# 5          $0.00              0          0.00%   |             $300.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                  11              72.76%    Dragon
# ...

# %%
dragon_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
dragon_games
# Out:
#                Game Total Prizes Total Placed Total Percent blank  \
# 1       Injustice 2  $200,645.73           11        72.76%     |
# 2  Mortal Kombat 11   $39,675.24           14        14.39%     |
# 3   Mortal Kombat X   $30,874.40            3        11.20%     |
# 4  Mortal Kombat XL    $4,274.60            4         1.55%     |
# 5   Soul Calibur VI      $300.00            1         0.11%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |    $200,645.73
# 2     $1,875.00             3          0.68%      |     $37,800.24
# 3         $0.00             0          0.00%      |     $30,874.40
# 4         $0.00             0          0.00%      |      $4,274.60
# 5         $0.00             0          0.00%      |        $300.00
#
#   Offline Placed Offline Percent Player ID
# 1             11          72.76%    Dragon
# 2             11          13.71%    Dragon
# ...

# %%
dragon_games = dragon_games.drop(columns=['blank', 'blank1'])
dragon_games
# Out:
#                Game Total Prizes Total Placed Total Percent Online Prizes  \
# 1       Injustice 2  $200,645.73           11        72.76%         $0.00
# 2  Mortal Kombat 11   $39,675.24           14        14.39%     $1,875.00
# 3   Mortal Kombat X   $30,874.40            3        11.20%         $0.00
# 4  Mortal Kombat XL    $4,274.60            4         1.55%         $0.00
# 5   Soul Calibur VI      $300.00            1         0.11%         $0.00
#
#   Online Placed Online Percent Offline Prizes Offline Placed Offline Percent  \
# 1             0          0.00%    $200,645.73             11          72.76%
# 2             3          0.68%     $37,800.24             11          13.71%
# 3             0          0.00%     $30,874.40              3          11.20%
# 4             0          0.00%      $4,274.60              4           1.55%
# 5             0          0.00%        $300.00              1           0.11%
#
#   Player ID
# 1    Dragon
# 2    Dragon
# 3    Dragon
# ...

# %% [markdown]
# ## MenaRD

# %%
mena_url = 'https://www.esportsearnings.com/players/41926-menard-saul-leonardo-mena-segundo'
response = requests.get(mena_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
mena = pd.read_html(str(tables), skiprows=1)

# %%
mena = mena[0]
mena
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $11,614.87              6          4.30%    |      $10,364.87
# 2  2020.0        $448.88              2          0.17%    |         $448.88
# 3  2019.0      $2,571.60              3          0.95%    |           $0.00
# 4  2018.0      $1,000.00              2          0.37%    |           $0.00
# 5  2017.0    $254,417.92              4         94.21%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               5           3.84%    |            $1,250.00
# 2               2           0.17%    |                $0.00
# 3               0           0.00%    |            $2,571.60
# 4               0           0.00%    |            $1,000.00
# 5               0           0.00%    |          $254,417.92
#
# ...

# %%
mena.columns = mena.iloc[0]

# %%
mena = mena.drop([0])
mena
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $11,614.87             6         4.30%   |     $10,364.87
# 2  2020.0       $448.88             2         0.17%   |        $448.88
# 3  2019.0     $2,571.60             3         0.95%   |          $0.00
# 4  2018.0     $1,000.00             2         0.37%   |          $0.00
# 5  2017.0   $254,417.92             4        94.21%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              5          3.84%   |           $1,250.00                   1
# 2              2          0.17%   |               $0.00                   0
# 3              0          0.00%   |           $2,571.60                   3
# 4              0          0.00%   |           $1,000.00                   2
# 5              0          0.00%   |         $254,417.92                   4
#
# 0 Offline/LAN Results
# 1               0.46%
# 2               0.00%
# ...

# %%
mena['Player ID'] = 'MenaRD'
mena
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $11,614.87             6         4.30%   |     $10,364.87
# 2  2020.0       $448.88             2         0.17%   |        $448.88
# 3  2019.0     $2,571.60             3         0.95%   |          $0.00
# 4  2018.0     $1,000.00             2         0.37%   |          $0.00
# 5  2017.0   $254,417.92             4        94.21%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              5          3.84%   |           $1,250.00                   1
# 2              2          0.17%   |               $0.00                   0
# 3              0          0.00%   |           $2,571.60                   3
# 4              0          0.00%   |           $1,000.00                   2
# 5              0          0.00%   |         $254,417.92                   4
#
# 0 Offline/LAN Results Player ID
# 1               0.46%    MenaRD
# ...

# %%
mena.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mena
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $11,614.87            6         4.30%     |    $10,364.87
# 2  2020.0      $448.88            2         0.17%     |       $448.88
# 3  2019.0    $2,571.60            3         0.95%     |         $0.00
# 4  2018.0    $1,000.00            2         0.37%     |         $0.00
# 5  2017.0  $254,417.92            4        94.21%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             5          3.84%      |      $1,250.00              1
# 2             2          0.17%      |          $0.00              0
# 3             0          0.00%      |      $2,571.60              3
# 4             0          0.00%      |      $1,000.00              2
# 5             0          0.00%      |    $254,417.92              4
#
#   Offline Percent Player ID
# 1           0.46%    MenaRD
# 2           0.00%    MenaRD
# 3           0.95%    MenaRD
# ...

# %%
mena = mena.drop(columns=['blank', 'blank1'])
mena
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021.0   $11,614.87            6         4.30%    $10,364.87             5
# 2  2020.0      $448.88            2         0.17%       $448.88             2
# 3  2019.0    $2,571.60            3         0.95%         $0.00             0
# 4  2018.0    $1,000.00            2         0.37%         $0.00             0
# 5  2017.0  $254,417.92            4        94.21%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          3.84%      $1,250.00              1           0.46%    MenaRD
# 2          0.17%          $0.00              0           0.00%    MenaRD
# 3          0.00%      $2,571.60              3           0.95%    MenaRD
# 4          0.00%      $1,000.00              2           0.37%    MenaRD
# 5          0.00%    $254,417.92              4          94.21%    MenaRD

# %%
mena['Year'] = mena['Year'].round().astype(int)
mena
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $11,614.87            6         4.30%    $10,364.87             5
# 2  2020      $448.88            2         0.17%       $448.88             2
# 3  2019    $2,571.60            3         0.95%         $0.00             0
# 4  2018    $1,000.00            2         0.37%         $0.00             0
# 5  2017  $254,417.92            4        94.21%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          3.84%      $1,250.00              1           0.46%    MenaRD
# 2          0.17%          $0.00              0           0.00%    MenaRD
# 3          0.00%      $2,571.60              3           0.95%    MenaRD
# 4          0.00%      $1,000.00              2           0.37%    MenaRD
# 5          0.00%    $254,417.92              4          94.21%    MenaRD

# %%
mena_games = pd.read_html(str(tables), skiprows=1)

# %%
mena_games = mena_games[1]
mena_games
# Out:
#                                    0              1              2   \
# 0                                 NaN  Total Results  Total Results
# 1                Guilty Gear -STRIVE-        $100.00              1
# 2                    Street Fighter V    $254,417.92              4
# 3    Street Fighter V: Arcade Edition      $3,571.60              5
# 4  Street Fighter V: Champion Edition     $11,963.75              7
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.04%    |         $100.00               1           0.04%    |
# 2         94.21%    |           $0.00               0           0.00%    |
# 3          1.32%    |           $0.00               0           0.00%    |
# 4          4.43%    |      $10,713.75               6           3.97%    |
#
#                     9                    10                   11
# ...

# %%
mena_games.columns = mena_games.iloc[0]

# %%
mena_games = mena_games.drop([0])
mena_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                Guilty Gear -STRIVE-       $100.00             1
# 2                    Street Fighter V   $254,417.92             4
# 3    Street Fighter V: Arcade Edition     $3,571.60             5
# 4  Street Fighter V: Champion Edition    $11,963.75             7
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.04%   |        $100.00              1          0.04%   |
# 2        94.21%   |          $0.00              0          0.00%   |
# 3         1.32%   |          $0.00              0          0.00%   |
# 4         4.43%   |     $10,713.75              6          3.97%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results
# 1               $0.00                   0               0.00%
# 2         $254,417.92                   4              94.21%
# 3           $3,571.60                   5               1.32%
# ...

# %%
mena_games['Player ID'] = 'MenaRD'
mena_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                Guilty Gear -STRIVE-       $100.00             1
# 2                    Street Fighter V   $254,417.92             4
# 3    Street Fighter V: Arcade Edition     $3,571.60             5
# 4  Street Fighter V: Champion Edition    $11,963.75             7
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.04%   |        $100.00              1          0.04%   |
# 2        94.21%   |          $0.00              0          0.00%   |
# 3         1.32%   |          $0.00              0          0.00%   |
# 4         4.43%   |     $10,713.75              6          3.97%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1               $0.00                   0               0.00%    MenaRD
# 2         $254,417.92                   4              94.21%    MenaRD
# ...

# %%
mena_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mena_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                Guilty Gear -STRIVE-      $100.00            1         0.04%
# 2                    Street Fighter V  $254,417.92            4        94.21%
# 3    Street Fighter V: Arcade Edition    $3,571.60            5         1.32%
# 4  Street Fighter V: Champion Edition   $11,963.75            7         4.43%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |       $100.00             1          0.04%      |          $0.00
# 2     |         $0.00             0          0.00%      |    $254,417.92
# 3     |         $0.00             0          0.00%      |      $3,571.60
# 4     |    $10,713.75             6          3.97%      |      $1,250.00
#
#   Offline Placed Offline Percent Player ID
# 1              0           0.00%    MenaRD
# 2              4          94.21%    MenaRD
# 3              5           1.32%    MenaRD
# ...

# %%
mena_games = mena_games.drop(columns=['blank', 'blank1'])
mena_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                Guilty Gear -STRIVE-      $100.00            1         0.04%
# 2                    Street Fighter V  $254,417.92            4        94.21%
# 3    Street Fighter V: Arcade Edition    $3,571.60            5         1.32%
# 4  Street Fighter V: Champion Edition   $11,963.75            7         4.43%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1       $100.00             1          0.04%          $0.00              0
# 2         $0.00             0          0.00%    $254,417.92              4
# 3         $0.00             0          0.00%      $3,571.60              5
# 4    $10,713.75             6          3.97%      $1,250.00              1
#
#   Offline Percent Player ID
# 1           0.00%    MenaRD
# 2          94.21%    MenaRD
# 3           1.32%    MenaRD
# 4           0.46%    MenaRD

# %% [markdown]
# ## Daigo

# %%
daigo_url = 'https://www.esportsearnings.com/players/2847-umehara-daigo'
response = requests.get(daigo_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
daigo = pd.read_html(str(tables), skiprows=1)

# %%
daigo = daigo[0]
daigo.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $5,960.00              2          2.31%    |       $5,960.00
# 2  2020.0      $9,473.37              3          3.68%    |       $4,750.00
# 3  2019.0      $5,154.32              4          2.00%    |           $0.00
# 4  2018.0     $36,170.00              8         14.04%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               2           2.31%    |                $0.00
# 2               1           1.84%    |            $4,723.37
# 3               0           0.00%    |            $5,154.32
# 4               0           0.00%    |           $36,170.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
daigo.columns = daigo.iloc[0]

# %%
daigo = daigo.drop([0])

# %%
daigo.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $5,960.00             2         2.31%   |      $5,960.00
# 2  2020.0     $9,473.37             3         3.68%   |      $4,750.00
# 3  2019.0     $5,154.32             4         2.00%   |          $0.00
# 4  2018.0    $36,170.00             8        14.04%   |          $0.00
# 5  2017.0    $16,500.00             4         6.41%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          2.31%   |               $0.00                   0
# 2              1          1.84%   |           $4,723.37                   2
# 3              0          0.00%   |           $5,154.32                   4
# 4              0          0.00%   |          $36,170.00                   8
# 5              0          0.00%   |          $16,500.00                   4
#
# 0 Offline/LAN Results
# 1               0.00%
# 2               1.83%
# ...

# %%
daigo['Player ID'] = 'Daigo'
daigo.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $5,960.00             2         2.31%   |      $5,960.00
# 2  2020.0     $9,473.37             3         3.68%   |      $4,750.00
# 3  2019.0     $5,154.32             4         2.00%   |          $0.00
# 4  2018.0    $36,170.00             8        14.04%   |          $0.00
# 5  2017.0    $16,500.00             4         6.41%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          2.31%   |               $0.00                   0
# 2              1          1.84%   |           $4,723.37                   2
# 3              0          0.00%   |           $5,154.32                   4
# 4              0          0.00%   |          $36,170.00                   8
# 5              0          0.00%   |          $16,500.00                   4
#
# 0 Offline/LAN Results Player ID
# 1               0.00%     Daigo
# ...

# %%
daigo.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
daigo.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $5,960.00            2         2.31%     |     $5,960.00
# 2  2020.0    $9,473.37            3         3.68%     |     $4,750.00
# 3  2019.0    $5,154.32            4         2.00%     |         $0.00
# 4  2018.0   $36,170.00            8        14.04%     |         $0.00
# 5  2017.0   $16,500.00            4         6.41%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             2          2.31%      |          $0.00              0
# 2             1          1.84%      |      $4,723.37              2
# 3             0          0.00%      |      $5,154.32              4
# 4             0          0.00%      |     $36,170.00              8
# 5             0          0.00%      |     $16,500.00              4
#
#   Offline Percent Player ID
# 1           0.00%     Daigo
# 2           1.83%     Daigo
# 3           2.00%     Daigo
# ...

# %%
daigo = daigo.drop(columns=['blank', 'blank1'])
daigo.head()
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021.0    $5,960.00            2         2.31%     $5,960.00             2
# 2  2020.0    $9,473.37            3         3.68%     $4,750.00             1
# 3  2019.0    $5,154.32            4         2.00%         $0.00             0
# 4  2018.0   $36,170.00            8        14.04%         $0.00             0
# 5  2017.0   $16,500.00            4         6.41%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          2.31%          $0.00              0           0.00%     Daigo
# 2          1.84%      $4,723.37              2           1.83%     Daigo
# 3          0.00%      $5,154.32              4           2.00%     Daigo
# 4          0.00%     $36,170.00              8          14.04%     Daigo
# 5          0.00%     $16,500.00              4           6.41%     Daigo

# %%
daigo['Year'] = daigo['Year'].round().astype(int)
daigo
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021    $5,960.00            2         2.31%     $5,960.00             2
# 2   2020    $9,473.37            3         3.68%     $4,750.00             1
# 3   2019    $5,154.32            4         2.00%         $0.00             0
# 4   2018   $36,170.00            8        14.04%         $0.00             0
# 5   2017   $16,500.00            4         6.41%         $0.00             0
# 6   2016   $10,527.85            6         4.09%         $0.00             0
# 7   2015  $111,814.93            8        43.42%         $0.00             0
# 8   2014   $23,307.83            2         9.05%         $0.00             0
# 9   2013   $11,474.52            3         4.46%         $0.00             0
# 10  2012   $13,952.02            3         5.42%         $0.00             0
# 11  2011   $11,541.00            3         4.48%         $0.00             0
# ...

# %%
daigo_games = pd.read_html(str(tables), skiprows=1)

# %%
daigo_games = daigo_games[2]
daigo_games.head()
# Out:
#                         0              1              2              3    4   \
# 0                      NaN  Total Results  Total Results  Total Results  NaN
# 1         Capcom vs. SNK 2        $500.00              2          0.19%    |
# 2           Guilty Gear XX          $0.00              2          0.00%    |
# 3     Guilty Gear XX Slash        $666.67              1          0.26%    |
# 4  Hyper Street Fighter II        $500.00              1          0.19%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |              $500.00
# 2           $0.00               0           0.00%    |                $0.00
# 3           $0.00               0           0.00%    |              $666.67
# 4           $0.00               0           0.00%    |              $500.00
#
#                     10                   11
# ...

# %%
daigo_games.columns = daigo_games.iloc[0]

# %%
daigo_games = daigo_games.drop([0])
daigo_games.head()
# Out:
# 0                             NaN Total Results Total Results Total Results  \
# 1                Capcom vs. SNK 2       $500.00             2         0.19%
# 2                  Guilty Gear XX         $0.00             2         0.00%
# 3            Guilty Gear XX Slash       $666.67             1         0.26%
# 4         Hyper Street Fighter II       $500.00             1         0.19%
# 5  Street Fighter III: 3rd Strike         $0.00             2         0.00%
#
# 0 NaN Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1   |          $0.00              0          0.00%   |             $500.00
# 2   |          $0.00              0          0.00%   |               $0.00
# 3   |          $0.00              0          0.00%   |             $666.67
# 4   |          $0.00              0          0.00%   |             $500.00
# 5   |          $0.00              0          0.00%   |               $0.00
#
# 0 Offline/LAN Results Offline/LAN Results
# ...

# %%
daigo_games['Player ID'] = 'Daigo'
daigo_games.head()
# Out:
# 0                             NaN Total Results Total Results Total Results  \
# 1                Capcom vs. SNK 2       $500.00             2         0.19%
# 2                  Guilty Gear XX         $0.00             2         0.00%
# 3            Guilty Gear XX Slash       $666.67             1         0.26%
# 4         Hyper Street Fighter II       $500.00             1         0.19%
# 5  Street Fighter III: 3rd Strike         $0.00             2         0.00%
#
# 0 NaN Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1   |          $0.00              0          0.00%   |             $500.00
# 2   |          $0.00              0          0.00%   |               $0.00
# 3   |          $0.00              0          0.00%   |             $666.67
# 4   |          $0.00              0          0.00%   |             $500.00
# 5   |          $0.00              0          0.00%   |               $0.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
daigo_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
daigo_games.head()
# Out:
#                              Game Total Prizes Total Placed Total Percent  \
# 1                Capcom vs. SNK 2      $500.00            2         0.19%
# 2                  Guilty Gear XX        $0.00            2         0.00%
# 3            Guilty Gear XX Slash      $666.67            1         0.26%
# 4         Hyper Street Fighter II      $500.00            1         0.19%
# 5  Street Fighter III: 3rd Strike        $0.00            2         0.00%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |        $500.00
# 2     |         $0.00             0          0.00%      |          $0.00
# 3     |         $0.00             0          0.00%      |        $666.67
# 4     |         $0.00             0          0.00%      |        $500.00
# 5     |         $0.00             0          0.00%      |          $0.00
#
#   Offline Placed Offline Percent Player ID
# ...

# %%
daigo_games = daigo_games.drop(columns=['blank', 'blank1'])
daigo_games
# Out:
#                                       Game Total Prizes Total Placed  \
# 1                         Capcom vs. SNK 2      $500.00            2
# 2                           Guilty Gear XX        $0.00            2
# 3                     Guilty Gear XX Slash      $666.67            1
# 4                  Hyper Street Fighter II      $500.00            1
# 5           Street Fighter III: 3rd Strike        $0.00            2
# 6                        Street Fighter IV        $0.00            1
# 7                         Street Fighter V   $27,027.85           10
# 8         Street Fighter V: Arcade Edition   $41,324.32           12
# 9       Street Fighter V: Champion Edition   $15,433.37            5
# 10           Super Street Fighter II Turbo      $288.00            3
# 11                 Super Street Fighter IV        $0.00            1
# 12  Super Street Fighter IV Arcade Edition   $51,438.96            9
# 13                 Ultra Street Fighter IV  $120,363.34            9
#
# ...

# %% [markdown]
# ## Mango

# %%
mango_url = 'https://www.esportsearnings.com/players/3916-mango-joseph-marquez'
response = requests.get(mango_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
mango = pd.read_html(str(tables), skiprows=1)

# %%
mango = mango[0]
mango
# Out:
#         0              1              2              3    4               5   \
# 0      NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1   2021.0     $49,325.70              3         19.27%    |         $625.00
# 2   2020.0     $25,274.72              7          9.88%    |      $14,375.50
# 3   2019.0     $12,062.22             11          4.71%    |           $0.00
# 4   2018.0     $15,080.64             12          5.89%    |           $0.00
# 5   2017.0     $32,414.81             20         12.67%    |           $0.00
# 6   2016.0     $47,361.50             27         18.51%    |           $0.00
# 7   2015.0     $23,953.50             28          9.36%    |           $0.00
# 8   2014.0     $20,091.87             20          7.85%    |           $0.00
# 9   2013.0      $6,835.30             21          2.67%    |           $0.00
# 10  2012.0      $3,964.34             11          1.55%    |           $0.00
# ...

# %%
mango.columns = mango.iloc[0]

# %%
mango = mango.drop([0])
mango.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $49,325.70             3        19.27%   |        $625.00
# 2  2020.0    $25,274.72             7         9.88%   |     $14,375.50
# 3  2019.0    $12,062.22            11         4.71%   |          $0.00
# 4  2018.0    $15,080.64            12         5.89%   |          $0.00
# 5  2017.0    $32,414.81            20        12.67%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.24%   |          $48,700.70                   2
# 2              5          5.62%   |          $10,899.22                   2
# 3              0          0.00%   |          $12,062.22                  11
# 4              0          0.00%   |          $15,080.64                  12
# 5              0          0.00%   |          $32,414.81                  20
#
# 0 Offline/LAN Results
# 1              19.03%
# 2               4.26%
# ...

# %%
mango['Player ID'] = 'Mango'
mango.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $49,325.70             3        19.27%   |        $625.00
# 2  2020.0    $25,274.72             7         9.88%   |     $14,375.50
# 3  2019.0    $12,062.22            11         4.71%   |          $0.00
# 4  2018.0    $15,080.64            12         5.89%   |          $0.00
# 5  2017.0    $32,414.81            20        12.67%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.24%   |          $48,700.70                   2
# 2              5          5.62%   |          $10,899.22                   2
# 3              0          0.00%   |          $12,062.22                  11
# 4              0          0.00%   |          $15,080.64                  12
# 5              0          0.00%   |          $32,414.81                  20
#
# 0 Offline/LAN Results Player ID
# 1              19.03%     Mango
# ...

# %%
mango.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mango.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $49,325.70            3        19.27%     |       $625.00
# 2  2020.0   $25,274.72            7         9.88%     |    $14,375.50
# 3  2019.0   $12,062.22           11         4.71%     |         $0.00
# 4  2018.0   $15,080.64           12         5.89%     |         $0.00
# 5  2017.0   $32,414.81           20        12.67%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.24%      |     $48,700.70              2
# 2             5          5.62%      |     $10,899.22              2
# 3             0          0.00%      |     $12,062.22             11
# 4             0          0.00%      |     $15,080.64             12
# 5             0          0.00%      |     $32,414.81             20
#
#   Offline Percent Player ID
# 1          19.03%     Mango
# 2           4.26%     Mango
# 3           4.71%     Mango
# ...

# %%
mango['Year'] = mango['Year'].round().astype(int)

# %%
mango = mango.drop(columns=['blank', 'blank1'])
mango
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021   $49,325.70            3        19.27%       $625.00             1
# 2   2020   $25,274.72            7         9.88%    $14,375.50             5
# 3   2019   $12,062.22           11         4.71%         $0.00             0
# 4   2018   $15,080.64           12         5.89%         $0.00             0
# 5   2017   $32,414.81           20        12.67%         $0.00             0
# 6   2016   $47,361.50           27        18.51%         $0.00             0
# 7   2015   $23,953.50           28         9.36%         $0.00             0
# 8   2014   $20,091.87           20         7.85%         $0.00             0
# 9   2013    $6,835.30           21         2.67%         $0.00             0
# 10  2012    $3,964.34           11         1.55%         $0.00             0
# 11  2011    $4,752.88           12         1.86%         $0.00             0
# ...

# %%
mango_games = pd.read_html(str(tables), skiprows=1)

# %%
mango_games = mango_games[2]
mango_games
# Out:
#                            0              1              2              3   \
# 0                         NaN  Total Results  Total Results  Total Results
# 1                   Fall Guys      $2,750.00              4          1.07%
# 2                   Project M        $684.75              3          0.27%
# 3            Rivals of Aether        $250.00              1          0.10%
# 4     Super Smash Bros. Melee    $251,701.65            201         98.35%
# 5  Super Smash Bros. Ultimate        $526.13              1          0.21%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |       $2,750.00               4           1.07%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# 4    |      $12,250.50               2           4.79%    |
# 5    |           $0.00               0           0.00%    |
#
# ...

# %%
mango_games.columns = mango_games.iloc[0]

# %%
mango_games = mango_games.drop([0])
mango_games
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1                   Fall Guys     $2,750.00             4         1.07%   |
# 2                   Project M       $684.75             3         0.27%   |
# 3            Rivals of Aether       $250.00             1         0.10%   |
# 4     Super Smash Bros. Melee   $251,701.65           201        98.35%   |
# 5  Super Smash Bros. Ultimate       $526.13             1         0.21%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1      $2,750.00              4          1.07%   |               $0.00
# 2          $0.00              0          0.00%   |             $684.75
# 3          $0.00              0          0.00%   |             $250.00
# 4     $12,250.50              2          4.79%   |         $239,451.15
# 5          $0.00              0          0.00%   |             $526.13
#
# 0 Offline/LAN Results Offline/LAN Results
# ...

# %%
mango_games['Player ID'] = 'Mango'
mango_games
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1                   Fall Guys     $2,750.00             4         1.07%   |
# 2                   Project M       $684.75             3         0.27%   |
# 3            Rivals of Aether       $250.00             1         0.10%   |
# 4     Super Smash Bros. Melee   $251,701.65           201        98.35%   |
# 5  Super Smash Bros. Ultimate       $526.13             1         0.21%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1      $2,750.00              4          1.07%   |               $0.00
# 2          $0.00              0          0.00%   |             $684.75
# 3          $0.00              0          0.00%   |             $250.00
# 4     $12,250.50              2          4.79%   |         $239,451.15
# 5          $0.00              0          0.00%   |             $526.13
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
mango_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mango_games
# Out:
#                          Game Total Prizes Total Placed Total Percent blank  \
# 1                   Fall Guys    $2,750.00            4         1.07%     |
# 2                   Project M      $684.75            3         0.27%     |
# 3            Rivals of Aether      $250.00            1         0.10%     |
# 4     Super Smash Bros. Melee  $251,701.65          201        98.35%     |
# 5  Super Smash Bros. Ultimate      $526.13            1         0.21%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     $2,750.00             4          1.07%      |          $0.00
# 2         $0.00             0          0.00%      |        $684.75
# 3         $0.00             0          0.00%      |        $250.00
# 4    $12,250.50             2          4.79%      |    $239,451.15
# 5         $0.00             0          0.00%      |        $526.13
#
#   Offline Placed Offline Percent Player ID
# 1              0           0.00%     Mango
# ...

# %%
mango_games = mango_games.drop(columns=['blank', 'blank1'])
mango_games
# Out:
#                          Game Total Prizes Total Placed Total Percent  \
# 1                   Fall Guys    $2,750.00            4         1.07%
# 2                   Project M      $684.75            3         0.27%
# 3            Rivals of Aether      $250.00            1         0.10%
# 4     Super Smash Bros. Melee  $251,701.65          201        98.35%
# 5  Super Smash Bros. Ultimate      $526.13            1         0.21%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1     $2,750.00             4          1.07%          $0.00              0
# 2         $0.00             0          0.00%        $684.75              3
# 3         $0.00             0          0.00%        $250.00              1
# 4    $12,250.50             2          4.79%    $239,451.15            199
# 5         $0.00             0          0.00%        $526.13              1
#
#   Offline Percent Player ID
# 1           0.00%     Mango
# 2           0.27%     Mango
# ...

# %% [markdown]
# ## MKLeo

# %%
mkleo_url = 'https://www.esportsearnings.com/players/29570-mkleo-leonardo-perez'
response = requests.get(mkleo_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
mkleo = pd.read_html(str(tables), skiprows=1)

# %%
mkleo = mkleo[0]
mkleo
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $31,210.20              8         12.36%    |       $3,050.00
# 2  2020.0     $12,122.80             14          4.80%    |       $6,208.80
# 3  2019.0    $109,819.90             25         43.48%    |           $0.00
# 4  2018.0     $27,126.66             15         10.74%    |           $0.00
# 5  2017.0     $61,812.35             32         24.47%    |           $0.00
# 6  2016.0     $10,484.98             10          4.15%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               5           1.21%    |           $28,160.20
# 2              12           2.46%    |            $5,914.00
# 3               0           0.00%    |          $109,819.90
# ...

# %%
mkleo.columns = mkleo.iloc[0]

# %%
mkleo = mkleo.drop([0])
mkleo
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $31,210.20             8        12.36%   |      $3,050.00
# 2  2020.0    $12,122.80            14         4.80%   |      $6,208.80
# 3  2019.0   $109,819.90            25        43.48%   |          $0.00
# 4  2018.0    $27,126.66            15        10.74%   |          $0.00
# 5  2017.0    $61,812.35            32        24.47%   |          $0.00
# 6  2016.0    $10,484.98            10         4.15%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              5          1.21%   |          $28,160.20                   3
# 2             12          2.46%   |           $5,914.00                   2
# 3              0          0.00%   |         $109,819.90                  25
# 4              0          0.00%   |          $27,126.66                  15
# 5              0          0.00%   |          $61,812.35                  32
# ...

# %%
mkleo['Player ID'] = 'MKLeo'
mkleo
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $31,210.20             8        12.36%   |      $3,050.00
# 2  2020.0    $12,122.80            14         4.80%   |      $6,208.80
# 3  2019.0   $109,819.90            25        43.48%   |          $0.00
# 4  2018.0    $27,126.66            15        10.74%   |          $0.00
# 5  2017.0    $61,812.35            32        24.47%   |          $0.00
# 6  2016.0    $10,484.98            10         4.15%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              5          1.21%   |          $28,160.20                   3
# 2             12          2.46%   |           $5,914.00                   2
# 3              0          0.00%   |         $109,819.90                  25
# 4              0          0.00%   |          $27,126.66                  15
# 5              0          0.00%   |          $61,812.35                  32
# ...

# %%
mkleo.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mkleo
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $31,210.20            8        12.36%     |     $3,050.00
# 2  2020.0   $12,122.80           14         4.80%     |     $6,208.80
# 3  2019.0  $109,819.90           25        43.48%     |         $0.00
# 4  2018.0   $27,126.66           15        10.74%     |         $0.00
# 5  2017.0   $61,812.35           32        24.47%     |         $0.00
# 6  2016.0   $10,484.98           10         4.15%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             5          1.21%      |     $28,160.20              3
# 2            12          2.46%      |      $5,914.00              2
# 3             0          0.00%      |    $109,819.90             25
# 4             0          0.00%      |     $27,126.66             15
# 5             0          0.00%      |     $61,812.35             32
# ...

# %%
mkleo = mkleo.drop(columns=['blank', 'blank1'])

# %%
mkleo['Year'] = mkleo['Year'].round().astype(int)
mkleo
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $31,210.20            8        12.36%     $3,050.00             5
# 2  2020   $12,122.80           14         4.80%     $6,208.80            12
# 3  2019  $109,819.90           25        43.48%         $0.00             0
# 4  2018   $27,126.66           15        10.74%         $0.00             0
# 5  2017   $61,812.35           32        24.47%         $0.00             0
# 6  2016   $10,484.98           10         4.15%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          1.21%     $28,160.20              3          11.15%     MKLeo
# 2          2.46%      $5,914.00              2           2.34%     MKLeo
# 3          0.00%    $109,819.90             25          43.48%     MKLeo
# 4          0.00%     $27,126.66             15          10.74%     MKLeo
# ...

# %%
mkleo_games = pd.read_html(str(tables), skiprows=1)

# %%
mkleo_games = mkleo_games[2]
mkleo_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1   Super Smash Bros. Ultimate    $152,969.90             46         60.56%
# 2  Super Smash Bros. for Wii U     $99,606.99             58         39.44%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |       $9,258.80              17           3.67%    |
# 2    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# 1          $143,711.10                   29               56.90%
# 2           $99,606.99                   58               39.44%

# %%
mkleo_games.columns = mkleo_games.iloc[0]

# %%
mkleo_games = mkleo_games.drop([0])

# %%
mkleo_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1   Super Smash Bros. Ultimate   $152,969.90            46        60.56%   |
# 2  Super Smash Bros. for Wii U    $99,606.99            58        39.44%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1      $9,258.80             17          3.67%   |         $143,711.10
# 2          $0.00              0          0.00%   |          $99,606.99
#
# 0 Offline/LAN Results Offline/LAN Results
# 1                  29              56.90%
# 2                  58              39.44%

# %%
mkleo_games['Player ID'] = 'MKLeo'

# %%
mkleo_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1   Super Smash Bros. Ultimate   $152,969.90            46        60.56%   |
# 2  Super Smash Bros. for Wii U    $99,606.99            58        39.44%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1      $9,258.80             17          3.67%   |         $143,711.10
# 2          $0.00              0          0.00%   |          $99,606.99
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                  29              56.90%     MKLeo
# 2                  58              39.44%     MKLeo

# %%
mkleo_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mkleo_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1   Super Smash Bros. Ultimate  $152,969.90           46        60.56%     |
# 2  Super Smash Bros. for Wii U   $99,606.99           58        39.44%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     $9,258.80            17          3.67%      |    $143,711.10
# 2         $0.00             0          0.00%      |     $99,606.99
#
#   Offline Placed Offline Percent Player ID
# 1             29          56.90%     MKLeo
# 2             58          39.44%     MKLeo

# %%
mkleo_games = mkleo_games.drop(columns=['blank', 'blank1'])
mkleo_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1   Super Smash Bros. Ultimate  $152,969.90           46        60.56%
# 2  Super Smash Bros. for Wii U   $99,606.99           58        39.44%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1     $9,258.80            17          3.67%    $143,711.10             29
# 2         $0.00             0          0.00%     $99,606.99             58
#
#   Offline Percent Player ID
# 1          56.90%     MKLeo
# 2          39.44%     MKLeo

# %% [markdown]
# ## Knee

# %%
knee_url = 'https://www.esportsearnings.com/players/1524-knee-bae-jae-min'
response = requests.get(knee_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
knee = pd.read_html(str(tables), skiprows=1)

# %%
knee = knee[0]
knee.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $22,000.00              4          8.70%    |           $0.00
# 2  2020.0     $18,128.00             11          7.17%    |         $846.60
# 3  2019.0     $85,332.23             14         33.76%    |           $0.00
# 4  2018.0     $40,510.95             16         16.03%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |           $22,000.00
# 2               2           0.33%    |           $17,281.40
# 3               0           0.00%    |           $85,332.23
# 4               0           0.00%    |           $40,510.95
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    4                8.70%
# ...

# %%
knee.columns = knee.iloc[0]

# %%
knee = knee.drop([0])
knee.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $22,000.00             4         8.70%   |          $0.00
# 2  2020.0    $18,128.00            11         7.17%   |        $846.60
# 3  2019.0    $85,332.23            14        33.76%   |          $0.00
# 4  2018.0    $40,510.95            16        16.03%   |          $0.00
# 5  2017.0    $23,043.67            10         9.12%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |          $22,000.00                   4
# 2              2          0.33%   |          $17,281.40                   9
# 3              0          0.00%   |          $85,332.23                  14
# 4              0          0.00%   |          $40,510.95                  16
# 5              0          0.00%   |          $23,043.67                  10
#
# 0 Offline/LAN Results
# 1               8.70%
# 2               6.84%
# ...

# %%
knee['Player ID'] = 'Knee'
knee.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $22,000.00             4         8.70%   |          $0.00
# 2  2020.0    $18,128.00            11         7.17%   |        $846.60
# 3  2019.0    $85,332.23            14        33.76%   |          $0.00
# 4  2018.0    $40,510.95            16        16.03%   |          $0.00
# 5  2017.0    $23,043.67            10         9.12%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |          $22,000.00                   4
# 2              2          0.33%   |          $17,281.40                   9
# 3              0          0.00%   |          $85,332.23                  14
# 4              0          0.00%   |          $40,510.95                  16
# 5              0          0.00%   |          $23,043.67                  10
#
# 0 Offline/LAN Results Player ID
# 1               8.70%      Knee
# ...

# %%
knee.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
knee.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $22,000.00            4         8.70%     |         $0.00
# 2  2020.0   $18,128.00           11         7.17%     |       $846.60
# 3  2019.0   $85,332.23           14        33.76%     |         $0.00
# 4  2018.0   $40,510.95           16        16.03%     |         $0.00
# 5  2017.0   $23,043.67           10         9.12%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |     $22,000.00              4
# 2             2          0.33%      |     $17,281.40              9
# 3             0          0.00%      |     $85,332.23             14
# 4             0          0.00%      |     $40,510.95             16
# 5             0          0.00%      |     $23,043.67             10
#
#   Offline Percent Player ID
# 1           8.70%      Knee
# 2           6.84%      Knee
# 3          33.76%      Knee
# ...

# %%
knee['Year'] = knee['Year'].round().astype(int)
knee.head()
# Out:
#    Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021   $22,000.00            4         8.70%     |         $0.00
# 2  2020   $18,128.00           11         7.17%     |       $846.60
# 3  2019   $85,332.23           14        33.76%     |         $0.00
# 4  2018   $40,510.95           16        16.03%     |         $0.00
# 5  2017   $23,043.67           10         9.12%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |     $22,000.00              4
# 2             2          0.33%      |     $17,281.40              9
# 3             0          0.00%      |     $85,332.23             14
# 4             0          0.00%      |     $40,510.95             16
# 5             0          0.00%      |     $23,043.67             10
#
#   Offline Percent Player ID
# 1           8.70%      Knee
# 2           6.84%      Knee
# 3          33.76%      Knee
# 4          16.03%      Knee
# ...

# %%
knee = knee.drop(columns=['blank', 'blank1'])
knee
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021   $22,000.00            4         8.70%         $0.00             0
# 2   2020   $18,128.00           11         7.17%       $846.60             2
# 3   2019   $85,332.23           14        33.76%         $0.00             0
# 4   2018   $40,510.95           16        16.03%         $0.00             0
# 5   2017   $23,043.67           10         9.12%         $0.00             0
# 6   2016    $1,098.00            1         0.43%         $0.00             0
# 7   2015   $18,900.28            3         7.48%         $0.00             0
# 8   2013    $6,528.00            3         2.58%         $0.00             0
# 9   2012   $23,200.00            3         9.18%         $0.00             0
# 10  2011    $1,000.00            1         0.40%         $0.00             0
# 11  2010   $13,000.00            4         5.14%         $0.00             0
#
# ...

# %%
knee_games = pd.read_html(str(tables), skiprows=1)

# %%
knee_games = knee_games[2]
knee_games
# Out:
#                         0              1              2              3    4   \
# 0                      NaN  Total Results  Total Results  Total Results  NaN
# 1                 Tekken 6     $14,000.00              5          5.54%    |
# 2                 Tekken 7    $207,013.13             58         81.91%    |
# 3  Tekken Tag Tournament 2     $31,728.00              7         12.55%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |           $14,000.00
# 2         $846.60               2           0.33%    |          $206,166.53
# 3           $0.00               0           0.00%    |           $31,728.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    5                5.54%
# 2                   56               81.57%
# ...

# %%
knee_games.columns = knee_games.iloc[0]
knee_games
# Out:
# 0                      NaN  Total Results  Total Results  Total Results  NaN  \
# 0                      NaN  Total Results  Total Results  Total Results  NaN
# 1                 Tekken 6     $14,000.00              5          5.54%    |
# 2                 Tekken 7    $207,013.13             58         81.91%    |
# 3  Tekken Tag Tournament 2     $31,728.00              7         12.55%    |
#
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |           $14,000.00
# 2         $846.60               2           0.33%    |          $206,166.53
# 3           $0.00               0           0.00%    |           $31,728.00
#
# 0  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    5                5.54%
# 2                   56               81.57%
# ...

# %%
knee_games = knee_games.drop([0])
knee_games
# Out:
# 0                      NaN Total Results Total Results Total Results NaN  \
# 1                 Tekken 6    $14,000.00             5         5.54%   |
# 2                 Tekken 7   $207,013.13            58        81.91%   |
# 3  Tekken Tag Tournament 2    $31,728.00             7        12.55%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |          $14,000.00
# 2        $846.60              2          0.33%   |         $206,166.53
# 3          $0.00              0          0.00%   |          $31,728.00
#
# 0 Offline/LAN Results Offline/LAN Results
# 1                   5               5.54%
# 2                  56              81.57%
# 3                   7              12.55%

# %%
knee_games['Player ID'] = 'Knee'
knee_games
# Out:
# 0                      NaN Total Results Total Results Total Results NaN  \
# 1                 Tekken 6    $14,000.00             5         5.54%   |
# 2                 Tekken 7   $207,013.13            58        81.91%   |
# 3  Tekken Tag Tournament 2    $31,728.00             7        12.55%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |          $14,000.00
# 2        $846.60              2          0.33%   |         $206,166.53
# 3          $0.00              0          0.00%   |          $31,728.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                   5               5.54%      Knee
# 2                  56              81.57%      Knee
# 3                   7              12.55%      Knee

# %%
knee_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
knee_games
# Out:
#                       Game Total Prizes Total Placed Total Percent blank  \
# 1                 Tekken 6   $14,000.00            5         5.54%     |
# 2                 Tekken 7  $207,013.13           58        81.91%     |
# 3  Tekken Tag Tournament 2   $31,728.00            7        12.55%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |     $14,000.00
# 2       $846.60             2          0.33%      |    $206,166.53
# 3         $0.00             0          0.00%      |     $31,728.00
#
#   Offline Placed Offline Percent Player ID
# 1              5           5.54%      Knee
# 2             56          81.57%      Knee
# 3              7          12.55%      Knee

# %%
knee_games = knee_games.drop(columns=['blank', 'blank1'])
knee_games
# Out:
#                       Game Total Prizes Total Placed Total Percent  \
# 1                 Tekken 6   $14,000.00            5         5.54%
# 2                 Tekken 7  $207,013.13           58        81.91%
# 3  Tekken Tag Tournament 2   $31,728.00            7        12.55%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%     $14,000.00              5
# 2       $846.60             2          0.33%    $206,166.53             56
# 3         $0.00             0          0.00%     $31,728.00              7
#
#   Offline Percent Player ID
# 1           5.54%      Knee
# 2          81.57%      Knee
# 3          12.55%      Knee

# %% [markdown]
# ## Kazunoko

# %%
kazunoko_url = 'https://www.esportsearnings.com/players/3471-kazunoko-ryota-inoue'
response = requests.get(kazunoko_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
kazunoko = pd.read_html(str(tables), skiprows=1)

# %%
kazunoko = kazunoko[0]

# %%
kazunoko.columns = kazunoko.iloc[0]

# %%
kazunoko = kazunoko.drop([0])
kazunoko
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0     $1,600.00             1         0.67%   |          $0.00
# 2  2019.0    $20,942.80            10         8.83%   |          $0.00
# 3  2018.0    $17,325.72            13         7.31%   |          $0.00
# 4  2017.0    $18,532.50             9         7.81%   |          $0.00
# 5  2016.0    $29,144.00             7        12.29%   |          $0.00
# 6  2015.0   $146,813.83            17        61.91%   |          $0.00
# 7  2014.0       $600.00             2         0.25%   |          $0.00
# 8  2013.0     $1,940.52             2         0.82%   |          $0.00
# 9  2012.0       $250.00             3         0.11%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,600.00                   1
# 2              0          0.00%   |          $20,942.80                  10
# ...

# %%
kazunoko['Player ID'] = 'Kazunoko'
kazunoko
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0     $1,600.00             1         0.67%   |          $0.00
# 2  2019.0    $20,942.80            10         8.83%   |          $0.00
# 3  2018.0    $17,325.72            13         7.31%   |          $0.00
# 4  2017.0    $18,532.50             9         7.81%   |          $0.00
# 5  2016.0    $29,144.00             7        12.29%   |          $0.00
# 6  2015.0   $146,813.83            17        61.91%   |          $0.00
# 7  2014.0       $600.00             2         0.25%   |          $0.00
# 8  2013.0     $1,940.52             2         0.82%   |          $0.00
# 9  2012.0       $250.00             3         0.11%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,600.00                   1
# 2              0          0.00%   |          $20,942.80                  10
# ...

# %%
kazunoko.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
kazunoko
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2020.0    $1,600.00            1         0.67%     |         $0.00
# 2  2019.0   $20,942.80           10         8.83%     |         $0.00
# 3  2018.0   $17,325.72           13         7.31%     |         $0.00
# 4  2017.0   $18,532.50            9         7.81%     |         $0.00
# 5  2016.0   $29,144.00            7        12.29%     |         $0.00
# 6  2015.0  $146,813.83           17        61.91%     |         $0.00
# 7  2014.0      $600.00            2         0.25%     |         $0.00
# 8  2013.0    $1,940.52            2         0.82%     |         $0.00
# 9  2012.0      $250.00            3         0.11%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $1,600.00              1
# 2             0          0.00%      |     $20,942.80             10
# ...

# %%
kazunoko = kazunoko.drop(columns=['blank', 'blank1'])
kazunoko
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2020.0    $1,600.00            1         0.67%         $0.00             0
# 2  2019.0   $20,942.80           10         8.83%         $0.00             0
# 3  2018.0   $17,325.72           13         7.31%         $0.00             0
# 4  2017.0   $18,532.50            9         7.81%         $0.00             0
# 5  2016.0   $29,144.00            7        12.29%         $0.00             0
# 6  2015.0  $146,813.83           17        61.91%         $0.00             0
# 7  2014.0      $600.00            2         0.25%         $0.00             0
# 8  2013.0    $1,940.52            2         0.82%         $0.00             0
# 9  2012.0      $250.00            3         0.11%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%      $1,600.00              1           0.67%  Kazunoko
# ...

# %%
kazunoko['Year'] = kazunoko['Year'].round().astype(int)
kazunoko
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2020    $1,600.00            1         0.67%         $0.00             0
# 2  2019   $20,942.80           10         8.83%         $0.00             0
# 3  2018   $17,325.72           13         7.31%         $0.00             0
# 4  2017   $18,532.50            9         7.81%         $0.00             0
# 5  2016   $29,144.00            7        12.29%         $0.00             0
# 6  2015  $146,813.83           17        61.91%         $0.00             0
# 7  2014      $600.00            2         0.25%         $0.00             0
# 8  2013    $1,940.52            2         0.82%         $0.00             0
# 9  2012      $250.00            3         0.11%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%      $1,600.00              1           0.67%  Kazunoko
# ...

# %%
kazunoko_games = pd.read_html(str(tables), skiprows=1)

# %%
kazunoko_games = kazunoko_games[2]
kazunoko_games
# Out:
#                                         0              1              2   \
# 0                                      NaN  Total Results  Total Results
# 1               BlazBlue: Cross Tag Battle        $236.20              1
# 2                     Dragon Ball FighterZ     $28,992.82             18
# 3              Guilty Gear Xrd -REVELATOR-        $734.00              2
# 4                   Guilty Gear Xrd -SIGN-      $2,036.32              7
# 5                    Guilty Gear Xrd REV 2      $1,589.00              6
# 6              Marvel vs. Capcom: Infinite      $2,000.00              1
# 7                          Persona 4 Arena          $0.00              1
# 8                   Samurai Shodown (2019)      $9,458.00              1
# 9                         Street Fighter V     $44,125.00             10
# 10  Super Street Fighter IV Arcade Edition      $2,190.52              4
# 11            Ultimate Marvel vs. Capcom 3          $0.00              1
# ...

# %%
kazunoko_games.columns = kazunoko_games.iloc[0]

# %%
kazunoko_games = kazunoko_games.drop([0])
kazunoko_games
# Out:
# 0                                      NaN Total Results Total Results  \
# 1               BlazBlue: Cross Tag Battle       $236.20             1
# 2                     Dragon Ball FighterZ    $28,992.82            18
# 3              Guilty Gear Xrd -REVELATOR-       $734.00             2
# 4                   Guilty Gear Xrd -SIGN-     $2,036.32             7
# 5                    Guilty Gear Xrd REV 2     $1,589.00             6
# 6              Marvel vs. Capcom: Infinite     $2,000.00             1
# 7                          Persona 4 Arena         $0.00             1
# 8                   Samurai Shodown (2019)     $9,458.00             1
# 9                         Street Fighter V    $44,125.00            10
# 10  Super Street Fighter IV Arcade Edition     $2,190.52             4
# 11            Ultimate Marvel vs. Capcom 3         $0.00             1
# 12                 Ultra Street Fighter IV   $145,787.51            12
#
# ...

# %%
kazunoko_games['Player ID'] = 'Kazunoko'
kazunoko_games
# Out:
# 0                                      NaN Total Results Total Results  \
# 1               BlazBlue: Cross Tag Battle       $236.20             1
# 2                     Dragon Ball FighterZ    $28,992.82            18
# 3              Guilty Gear Xrd -REVELATOR-       $734.00             2
# 4                   Guilty Gear Xrd -SIGN-     $2,036.32             7
# 5                    Guilty Gear Xrd REV 2     $1,589.00             6
# 6              Marvel vs. Capcom: Infinite     $2,000.00             1
# 7                          Persona 4 Arena         $0.00             1
# 8                   Samurai Shodown (2019)     $9,458.00             1
# 9                         Street Fighter V    $44,125.00            10
# 10  Super Street Fighter IV Arcade Edition     $2,190.52             4
# 11            Ultimate Marvel vs. Capcom 3         $0.00             1
# 12                 Ultra Street Fighter IV   $145,787.51            12
#
# ...

# %%
kazunoko_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
kazunoko_games.head()
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1   BlazBlue: Cross Tag Battle      $236.20            1         0.10%     |
# 2         Dragon Ball FighterZ   $28,992.82           18        12.23%     |
# 3  Guilty Gear Xrd -REVELATOR-      $734.00            2         0.31%     |
# 4       Guilty Gear Xrd -SIGN-    $2,036.32            7         0.86%     |
# 5        Guilty Gear Xrd REV 2    $1,589.00            6         0.67%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |        $236.20
# 2         $0.00             0          0.00%      |     $28,992.82
# 3         $0.00             0          0.00%      |        $734.00
# 4         $0.00             0          0.00%      |      $2,036.32
# 5         $0.00             0          0.00%      |      $1,589.00
#
#   Offline Placed Offline Percent Player ID
# 1              1           0.10%  Kazunoko
# ...

# %%
kazunoko_games = kazunoko_games.drop(columns=['blank', 'blank1'])
kazunoko_games
# Out:
#                                       Game Total Prizes Total Placed  \
# 1               BlazBlue: Cross Tag Battle      $236.20            1
# 2                     Dragon Ball FighterZ   $28,992.82           18
# 3              Guilty Gear Xrd -REVELATOR-      $734.00            2
# 4                   Guilty Gear Xrd -SIGN-    $2,036.32            7
# 5                    Guilty Gear Xrd REV 2    $1,589.00            6
# 6              Marvel vs. Capcom: Infinite    $2,000.00            1
# 7                          Persona 4 Arena        $0.00            1
# 8                   Samurai Shodown (2019)    $9,458.00            1
# 9                         Street Fighter V   $44,125.00           10
# 10  Super Street Fighter IV Arcade Edition    $2,190.52            4
# 11            Ultimate Marvel vs. Capcom 3        $0.00            1
# 12                 Ultra Street Fighter IV  $145,787.51           12
#
# ...

# %% [markdown]
# ## Infiltration

# %%
infiltration_url = 'https://www.esportsearnings.com/players/2510-infiltration-lee-seon-woo'
response = requests.get(infiltration_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
infiltration = pd.read_html(str(tables), skiprows=1)

# %%
infiltration = infiltration[0]
infiltration
# Out:
#         0              1              2              3    4               5   \
# 0      NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1   2020.0        $730.27              1          0.31%    |           $0.00
# 2   2019.0     $28,374.00              1         11.97%    |           $0.00
# 3   2018.0     $22,901.10              7          9.66%    |           $0.00
# 4   2017.0        $500.00              1          0.21%    |           $0.00
# 5   2016.0     $80,892.00              6         34.12%    |           $0.00
# 6   2015.0     $19,503.33             11          8.23%    |           $0.00
# 7   2014.0     $12,497.01              9          5.27%    |           $0.00
# 8   2013.0      $8,642.67              8          3.65%    |           $0.00
# 9   2012.0     $58,039.45             12         24.48%    |           $0.00
# 10  2011.0      $4,972.02              5          2.10%    |           $0.00
# ...

# %%
infiltration.columns = infiltration.iloc[0]
infiltration.head()
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2020.0        $730.27              1          0.31%    |           $0.00
# 2  2019.0     $28,374.00              1         11.97%    |           $0.00
# 3  2018.0     $22,901.10              7          9.66%    |           $0.00
# 4  2017.0        $500.00              1          0.21%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |              $730.27
# 2               0           0.00%    |           $28,374.00
# 3               0           0.00%    |           $22,901.10
# 4               0           0.00%    |              $500.00
#
# 0  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                0.31%
# ...

# %%
infiltration = infiltration.drop([0])
infiltration.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0       $730.27             1         0.31%   |          $0.00
# 2  2019.0    $28,374.00             1        11.97%   |          $0.00
# 3  2018.0    $22,901.10             7         9.66%   |          $0.00
# 4  2017.0       $500.00             1         0.21%   |          $0.00
# 5  2016.0    $80,892.00             6        34.12%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |             $730.27                   1
# 2              0          0.00%   |          $28,374.00                   1
# 3              0          0.00%   |          $22,901.10                   7
# 4              0          0.00%   |             $500.00                   1
# 5              0          0.00%   |          $80,892.00                   6
#
# 0 Offline/LAN Results
# 1               0.31%
# 2              11.97%
# ...

# %%
infiltration['Player ID'] = 'Infiltration'
infiltration
# Out:
# 0      NaN Total Results Total Results Total Results NaN Online Results  \
# 1   2020.0       $730.27             1         0.31%   |          $0.00
# 2   2019.0    $28,374.00             1        11.97%   |          $0.00
# 3   2018.0    $22,901.10             7         9.66%   |          $0.00
# 4   2017.0       $500.00             1         0.21%   |          $0.00
# 5   2016.0    $80,892.00             6        34.12%   |          $0.00
# 6   2015.0    $19,503.33            11         8.23%   |          $0.00
# 7   2014.0    $12,497.01             9         5.27%   |          $0.00
# 8   2013.0     $8,642.67             8         3.65%   |          $0.00
# 9   2012.0    $58,039.45            12        24.48%   |          $0.00
# 10  2011.0     $4,972.02             5         2.10%   |          $0.00
# 11  2010.0         $0.00             1         0.00%   |          $0.00
#
# 0  Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# ...

# %%
infiltration.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
infiltration.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2020.0      $730.27            1         0.31%     |         $0.00
# 2  2019.0   $28,374.00            1        11.97%     |         $0.00
# 3  2018.0   $22,901.10            7         9.66%     |         $0.00
# 4  2017.0      $500.00            1         0.21%     |         $0.00
# 5  2016.0   $80,892.00            6        34.12%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |        $730.27              1
# 2             0          0.00%      |     $28,374.00              1
# 3             0          0.00%      |     $22,901.10              7
# 4             0          0.00%      |        $500.00              1
# 5             0          0.00%      |     $80,892.00              6
#
#   Offline Percent     Player ID
# 1           0.31%  Infiltration
# 2          11.97%  Infiltration
# 3           9.66%  Infiltration
# ...

# %%
infiltration['Year'] = infiltration['Year'].round().astype(int)

# %%
infiltration = infiltration.drop(columns=['blank', 'blank1'])
infiltration.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2020      $730.27            1         0.31%         $0.00             0
# 2  2019   $28,374.00            1        11.97%         $0.00             0
# 3  2018   $22,901.10            7         9.66%         $0.00             0
# 4  2017      $500.00            1         0.21%         $0.00             0
# 5  2016   $80,892.00            6        34.12%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent     Player ID
# 1          0.00%        $730.27              1           0.31%  Infiltration
# 2          0.00%     $28,374.00              1          11.97%  Infiltration
# 3          0.00%     $22,901.10              7           9.66%  Infiltration
# 4          0.00%        $500.00              1           0.21%  Infiltration
# 5          0.00%     $80,892.00              6          34.12%  Infiltration

# %%
infiltration_games = pd.read_html(str(tables), skiprows=1)

# %%
infiltration_games = infiltration_games[1]
infiltration_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                  Samurai Shodown (2019)     $28,374.00              1
# 2                        Street Fighter V     $81,392.00              7
# 3        Street Fighter V: Arcade Edition     $23,631.37              8
# 4                 Street Fighter X Tekken     $30,773.89             11
# 5                 Super Street Fighter IV          $0.00              1
# 6  Super Street Fighter IV Arcade Edition     $40,880.25             19
# 7                 Ultra Street Fighter IV     $32,000.34             15
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1         11.97%    |           $0.00               0           0.00%    |
# 2         34.34%    |           $0.00               0           0.00%    |
# ...

# %%
infiltration_games.columns = infiltration_games.iloc[0]

# %%
infiltration_games = infiltration_games.drop([0])
infiltration_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                  Samurai Shodown (2019)    $28,374.00             1
# 2                        Street Fighter V    $81,392.00             7
# 3        Street Fighter V: Arcade Edition    $23,631.37             8
# 4                 Street Fighter X Tekken    $30,773.89            11
# 5                 Super Street Fighter IV         $0.00             1
# 6  Super Street Fighter IV Arcade Edition    $40,880.25            19
# 7                 Ultra Street Fighter IV    $32,000.34            15
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        11.97%   |          $0.00              0          0.00%   |
# 2        34.34%   |          $0.00              0          0.00%   |
# 3         9.97%   |          $0.00              0          0.00%   |
# 4        12.98%   |          $0.00              0          0.00%   |
# ...

# %%
infiltration_games['Player ID'] = 'Infiltration'
infiltration_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                  Samurai Shodown (2019)    $28,374.00             1
# 2                        Street Fighter V    $81,392.00             7
# 3        Street Fighter V: Arcade Edition    $23,631.37             8
# 4                 Street Fighter X Tekken    $30,773.89            11
# 5                 Super Street Fighter IV         $0.00             1
# 6  Super Street Fighter IV Arcade Edition    $40,880.25            19
# 7                 Ultra Street Fighter IV    $32,000.34            15
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        11.97%   |          $0.00              0          0.00%   |
# 2        34.34%   |          $0.00              0          0.00%   |
# 3         9.97%   |          $0.00              0          0.00%   |
# 4        12.98%   |          $0.00              0          0.00%   |
# ...

# %%
infiltration_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
    'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
infiltration_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                  Samurai Shodown (2019)   $28,374.00            1
# 2                        Street Fighter V   $81,392.00            7
# 3        Street Fighter V: Arcade Edition   $23,631.37            8
# 4                 Street Fighter X Tekken   $30,773.89           11
# 5                 Super Street Fighter IV        $0.00            1
# 6  Super Street Fighter IV Arcade Edition   $40,880.25           19
# 7                 Ultra Street Fighter IV   $32,000.34           15
#
#   Total Percent blank Online Prizes Online Placed Online Percent blank1  \
# 1        11.97%     |         $0.00             0          0.00%      |
# 2        34.34%     |         $0.00             0          0.00%      |
# 3         9.97%     |         $0.00             0          0.00%      |
# 4        12.98%     |         $0.00             0          0.00%      |
# ...

# %%
infiltration_games = infiltration_games.drop(columns=['blank', 'blank1'])
infiltration_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                  Samurai Shodown (2019)   $28,374.00            1
# 2                        Street Fighter V   $81,392.00            7
# 3        Street Fighter V: Arcade Edition   $23,631.37            8
# 4                 Street Fighter X Tekken   $30,773.89           11
# 5                 Super Street Fighter IV        $0.00            1
# 6  Super Street Fighter IV Arcade Edition   $40,880.25           19
# 7                 Ultra Street Fighter IV   $32,000.34           15
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1        11.97%         $0.00             0          0.00%     $28,374.00
# 2        34.34%         $0.00             0          0.00%     $81,392.00
# 3         9.97%         $0.00             0          0.00%     $23,631.37
# 4        12.98%         $0.00             0          0.00%     $30,773.89
# ...

# %% [markdown]
# ## Fuudo

# %%
fuudo_url = 'https://www.esportsearnings.com/players/1695-fuudo-ai-keita'
response = requests.get(fuudo_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
fuudo = pd.read_html(str(tables), skiprows=1)

# %%
fuudo = fuudo[0]
fuudo.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $1,720.00              2          0.73%    |       $1,720.00
# 2  2020.0     $19,979.75              3          8.48%    |       $2,850.00
# 3  2019.0     $22,053.72              7          9.36%    |           $0.00
# 4  2018.0     $35,309.00             10         14.99%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               2           0.73%    |                $0.00
# 2               1           1.21%    |           $17,129.75
# 3               0           0.00%    |           $22,053.72
# 4               0           0.00%    |           $35,309.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
fuudo.columns = fuudo.iloc[0]
fuudo.head()
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $1,720.00              2          0.73%    |       $1,720.00
# 2  2020.0     $19,979.75              3          8.48%    |       $2,850.00
# 3  2019.0     $22,053.72              7          9.36%    |           $0.00
# 4  2018.0     $35,309.00             10         14.99%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               2           0.73%    |                $0.00
# 2               1           1.21%    |           $17,129.75
# 3               0           0.00%    |           $22,053.72
# 4               0           0.00%    |           $35,309.00
#
# 0  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
fuudo = fuudo.drop([0])
fuudo.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $1,720.00             2         0.73%   |      $1,720.00
# 2  2020.0    $19,979.75             3         8.48%   |      $2,850.00
# 3  2019.0    $22,053.72             7         9.36%   |          $0.00
# 4  2018.0    $35,309.00            10        14.99%   |          $0.00
# 5  2017.0    $41,500.00             9        17.61%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          0.73%   |               $0.00                   0
# 2              1          1.21%   |          $17,129.75                   2
# 3              0          0.00%   |          $22,053.72                   7
# 4              0          0.00%   |          $35,309.00                  10
# 5              0          0.00%   |          $41,500.00                   9
#
# 0 Offline/LAN Results
# 1               0.00%
# 2               7.27%
# ...

# %%
fuudo['Player ID'] = 'Fuudo'
fuudo.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $1,720.00             2         0.73%   |      $1,720.00
# 2  2020.0    $19,979.75             3         8.48%   |      $2,850.00
# 3  2019.0    $22,053.72             7         9.36%   |          $0.00
# 4  2018.0    $35,309.00            10        14.99%   |          $0.00
# 5  2017.0    $41,500.00             9        17.61%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          0.73%   |               $0.00                   0
# 2              1          1.21%   |          $17,129.75                   2
# 3              0          0.00%   |          $22,053.72                   7
# 4              0          0.00%   |          $35,309.00                  10
# 5              0          0.00%   |          $41,500.00                   9
#
# 0 Offline/LAN Results Player ID
# 1               0.00%     Fuudo
# ...

# %%
fuudo.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
fuudo.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $1,720.00            2         0.73%     |     $1,720.00
# 2  2020.0   $19,979.75            3         8.48%     |     $2,850.00
# 3  2019.0   $22,053.72            7         9.36%     |         $0.00
# 4  2018.0   $35,309.00           10        14.99%     |         $0.00
# 5  2017.0   $41,500.00            9        17.61%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             2          0.73%      |          $0.00              0
# 2             1          1.21%      |     $17,129.75              2
# 3             0          0.00%      |     $22,053.72              7
# 4             0          0.00%      |     $35,309.00             10
# 5             0          0.00%      |     $41,500.00              9
#
#   Offline Percent Player ID
# 1           0.00%     Fuudo
# 2           7.27%     Fuudo
# 3           9.36%     Fuudo
# ...

# %%
fuudo['Year'] = fuudo['Year'].round().astype(int)

# %%
fuudo = fuudo.drop(columns=['blank', 'blank1'])
fuudo.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $1,720.00            2         0.73%     $1,720.00             2
# 2  2020   $19,979.75            3         8.48%     $2,850.00             1
# 3  2019   $22,053.72            7         9.36%         $0.00             0
# 4  2018   $35,309.00           10        14.99%         $0.00             0
# 5  2017   $41,500.00            9        17.61%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.73%          $0.00              0           0.00%     Fuudo
# 2          1.21%     $17,129.75              2           7.27%     Fuudo
# 3          0.00%     $22,053.72              7           9.36%     Fuudo
# 4          0.00%     $35,309.00             10          14.99%     Fuudo
# 5          0.00%     $41,500.00              9          17.61%     Fuudo

# %%
fuudo_games = pd.read_html(str(tables), skiprows=1)

# %%
fuudo_games = fuudo_games[2]
fuudo_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                         Dead or Alive 5          $0.00              1
# 2                        Street Fighter V     $82,464.00             15
# 3        Street Fighter V: Arcade Edition     $57,362.72             17
# 4      Street Fighter V: Champion Edition     $21,699.75              5
# 5                 Street Fighter X Tekken          $0.00              2
# 6  Super Street Fighter IV Arcade Edition     $48,935.94             14
# 7                 Ultra Street Fighter IV     $18,161.65              7
# 8                        Virtua Fighter 5      $7,000.00              1
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.00%    |           $0.00               0           0.00%    |
# ...

# %%
fuudo_games.columns = fuudo_games.iloc[0]
fuudo_games.head()
# Out:
# 0                                 NaN  Total Results  Total Results  \
# 0                                 NaN  Total Results  Total Results
# 1                     Dead or Alive 5          $0.00              1
# 2                    Street Fighter V     $82,464.00             15
# 3    Street Fighter V: Arcade Edition     $57,362.72             17
# 4  Street Fighter V: Champion Edition     $21,699.75              5
#
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN  \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.00%    |           $0.00               0           0.00%    |
# 2         35.00%    |           $0.00               0           0.00%    |
# 3         24.35%    |           $0.00               0           0.00%    |
# 4          9.21%    |       $4,570.00               3           1.94%    |
#
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
fuudo_games = fuudo_games.drop([0])
fuudo_games.head()
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                     Dead or Alive 5         $0.00             1
# 2                    Street Fighter V    $82,464.00            15
# 3    Street Fighter V: Arcade Edition    $57,362.72            17
# 4  Street Fighter V: Champion Edition    $21,699.75             5
# 5             Street Fighter X Tekken         $0.00             2
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.00%   |          $0.00              0          0.00%   |
# 2        35.00%   |          $0.00              0          0.00%   |
# 3        24.35%   |          $0.00              0          0.00%   |
# 4         9.21%   |      $4,570.00              3          1.94%   |
# 5         0.00%   |          $0.00              0          0.00%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results
# 1               $0.00                   1               0.00%
# ...

# %%
fuudo_games['Player ID'] = 'Fuudo'
fuudo_games.head()
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                     Dead or Alive 5         $0.00             1
# 2                    Street Fighter V    $82,464.00            15
# 3    Street Fighter V: Arcade Edition    $57,362.72            17
# 4  Street Fighter V: Champion Edition    $21,699.75             5
# 5             Street Fighter X Tekken         $0.00             2
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.00%   |          $0.00              0          0.00%   |
# 2        35.00%   |          $0.00              0          0.00%   |
# 3        24.35%   |          $0.00              0          0.00%   |
# 4         9.21%   |      $4,570.00              3          1.94%   |
# 5         0.00%   |          $0.00              0          0.00%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1               $0.00                   1               0.00%     Fuudo
# ...

# %%
fuudo_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
fuudo_games.head()
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                     Dead or Alive 5        $0.00            1         0.00%
# 2                    Street Fighter V   $82,464.00           15        35.00%
# 3    Street Fighter V: Arcade Edition   $57,362.72           17        24.35%
# 4  Street Fighter V: Champion Edition   $21,699.75            5         9.21%
# 5             Street Fighter X Tekken        $0.00            2         0.00%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |          $0.00
# 2     |         $0.00             0          0.00%      |     $82,464.00
# 3     |         $0.00             0          0.00%      |     $57,362.72
# 4     |     $4,570.00             3          1.94%      |     $17,129.75
# 5     |         $0.00             0          0.00%      |          $0.00
#
#   Offline Placed Offline Percent Player ID
# ...

# %%
fuudo_games = fuudo_games.drop(columns=['blank', 'blank1'])
fuudo_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                         Dead or Alive 5        $0.00            1
# 2                        Street Fighter V   $82,464.00           15
# 3        Street Fighter V: Arcade Edition   $57,362.72           17
# 4      Street Fighter V: Champion Edition   $21,699.75            5
# 5                 Street Fighter X Tekken        $0.00            2
# 6  Super Street Fighter IV Arcade Edition   $48,935.94           14
# 7                 Ultra Street Fighter IV   $18,161.65            7
# 8                        Virtua Fighter 5    $7,000.00            1
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1         0.00%         $0.00             0          0.00%          $0.00
# 2        35.00%         $0.00             0          0.00%     $82,464.00
# 3        24.35%         $0.00             0          0.00%     $57,362.72
# ...

# %% [markdown]
# ## Momochi

# %%
momochi_url = 'https://www.esportsearnings.com/players/2026-momochi-yusuke'
response = requests.get(momochi_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
momochi = pd.read_html(str(tables), skiprows=1)

# %%
momochi = momochi[0]
momochi.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0        $240.00              1          0.10%    |         $240.00
# 2  2020.0      $1,425.00              1          0.61%    |           $0.00
# 3  2019.0     $64,160.28              4         27.28%    |           $0.00
# 4  2018.0     $23,000.00              6          9.78%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           0.10%    |                $0.00
# 2               0           0.00%    |            $1,425.00
# 3               0           0.00%    |           $64,160.28
# 4               0           0.00%    |           $23,000.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
momochi.columns = momochi.iloc[0]
momochi.head()
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0        $240.00              1          0.10%    |         $240.00
# 2  2020.0      $1,425.00              1          0.61%    |           $0.00
# 3  2019.0     $64,160.28              4         27.28%    |           $0.00
# 4  2018.0     $23,000.00              6          9.78%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           0.10%    |                $0.00
# 2               0           0.00%    |            $1,425.00
# 3               0           0.00%    |           $64,160.28
# 4               0           0.00%    |           $23,000.00
#
# 0  Offline/LAN Results  Offline/LAN Results
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
momochi = momochi.drop([0])
momochi.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0       $240.00             1         0.10%   |        $240.00
# 2  2020.0     $1,425.00             1         0.61%   |          $0.00
# 3  2019.0    $64,160.28             4        27.28%   |          $0.00
# 4  2018.0    $23,000.00             6         9.78%   |          $0.00
# 5  2017.0    $22,050.00             6         9.37%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.10%   |               $0.00                   0
# 2              0          0.00%   |           $1,425.00                   1
# 3              0          0.00%   |          $64,160.28                   4
# 4              0          0.00%   |          $23,000.00                   6
# 5              0          0.00%   |          $22,050.00                   6
#
# 0 Offline/LAN Results
# 1               0.00%
# 2               0.61%
# ...

# %%
momochi['Player ID'] = 'Momochi'
momochi.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0       $240.00             1         0.10%   |        $240.00
# 2  2020.0     $1,425.00             1         0.61%   |          $0.00
# 3  2019.0    $64,160.28             4        27.28%   |          $0.00
# 4  2018.0    $23,000.00             6         9.78%   |          $0.00
# 5  2017.0    $22,050.00             6         9.37%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.10%   |               $0.00                   0
# 2              0          0.00%   |           $1,425.00                   1
# 3              0          0.00%   |          $64,160.28                   4
# 4              0          0.00%   |          $23,000.00                   6
# 5              0          0.00%   |          $22,050.00                   6
#
# 0 Offline/LAN Results Player ID
# 1               0.00%   Momochi
# ...

# %%
momochi.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
momochi.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0      $240.00            1         0.10%     |       $240.00
# 2  2020.0    $1,425.00            1         0.61%     |         $0.00
# 3  2019.0   $64,160.28            4        27.28%     |         $0.00
# 4  2018.0   $23,000.00            6         9.78%     |         $0.00
# 5  2017.0   $22,050.00            6         9.37%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.10%      |          $0.00              0
# 2             0          0.00%      |      $1,425.00              1
# 3             0          0.00%      |     $64,160.28              4
# 4             0          0.00%      |     $23,000.00              6
# 5             0          0.00%      |     $22,050.00              6
#
#   Offline Percent Player ID
# 1           0.00%   Momochi
# 2           0.61%   Momochi
# 3          27.28%   Momochi
# ...

# %%
momochi['Year']= momochi['Year'].round().astype(int)
momochi.head()
# Out:
#    Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021      $240.00            1         0.10%     |       $240.00
# 2  2020    $1,425.00            1         0.61%     |         $0.00
# 3  2019   $64,160.28            4        27.28%     |         $0.00
# 4  2018   $23,000.00            6         9.78%     |         $0.00
# 5  2017   $22,050.00            6         9.37%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.10%      |          $0.00              0
# 2             0          0.00%      |      $1,425.00              1
# 3             0          0.00%      |     $64,160.28              4
# 4             0          0.00%      |     $23,000.00              6
# 5             0          0.00%      |     $22,050.00              6
#
#   Offline Percent Player ID
# 1           0.00%   Momochi
# 2           0.61%   Momochi
# 3          27.28%   Momochi
# 4           9.78%   Momochi
# ...

# %%
momochi = momochi.drop(columns=['blank', 'blank1'])
momochi
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021      $240.00            1         0.10%       $240.00             1
# 2   2020    $1,425.00            1         0.61%         $0.00             0
# 3   2019   $64,160.28            4        27.28%         $0.00             0
# 4   2018   $23,000.00            6         9.78%         $0.00             0
# 5   2017   $22,050.00            6         9.37%         $0.00             0
# 6   2016   $23,836.66            6        10.13%         $0.00             0
# 7   2015   $57,747.63            9        24.55%         $0.00             0
# 8   2014   $34,791.42            5        14.79%         $0.00             0
# 9   2013    $1,180.00            4         0.50%         $0.00             0
# 10  2012    $5,262.50            4         2.24%         $0.00             0
# 11  2011    $1,306.85            1         0.56%         $0.00             0
# ...

# %%
momochi_games = pd.read_html(str(tables), skiprows=1)

# %%
momochi_games = momochi_games[2]
momochi_games.head()
# Out:
#                                  0              1              2   \
# 0                               NaN  Total Results  Total Results
# 1    Street Fighter III: 3rd Strike      $1,500.00              1
# 2                 Street Fighter IV        $221.38              1
# 3                  Street Fighter V     $45,886.66             12
# 4  Street Fighter V: Arcade Edition     $87,160.28             10
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.64%    |           $0.00               0           0.00%    |
# 2          0.09%    |           $0.00               0           0.00%    |
# 3         19.51%    |           $0.00               0           0.00%    |
# 4         37.05%    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# ...

# %%
momochi_games.columns = momochi_games.iloc[0]
momochi_games.head()
# Out:
# 0                               NaN  Total Results  Total Results  \
# 0                               NaN  Total Results  Total Results
# 1    Street Fighter III: 3rd Strike      $1,500.00              1
# 2                 Street Fighter IV        $221.38              1
# 3                  Street Fighter V     $45,886.66             12
# 4  Street Fighter V: Arcade Edition     $87,160.28             10
#
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN  \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.64%    |           $0.00               0           0.00%    |
# 2          0.09%    |           $0.00               0           0.00%    |
# 3         19.51%    |           $0.00               0           0.00%    |
# 4         37.05%    |           $0.00               0           0.00%    |
#
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
momochi_games = momochi_games.drop([0])
momochi_games.head()
# Out:
# 0                                 NaN Total Results Total Results  \
# 1      Street Fighter III: 3rd Strike     $1,500.00             1
# 2                   Street Fighter IV       $221.38             1
# 3                    Street Fighter V    $45,886.66            12
# 4    Street Fighter V: Arcade Edition    $87,160.28            10
# 5  Street Fighter V: Champion Edition     $1,665.00             2
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.64%   |          $0.00              0          0.00%   |
# 2         0.09%   |          $0.00              0          0.00%   |
# 3        19.51%   |          $0.00              0          0.00%   |
# 4        37.05%   |          $0.00              0          0.00%   |
# 5         0.71%   |        $240.00              1          0.10%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results
# 1           $1,500.00                   1               0.64%
# ...

# %%
momochi_games['Player ID'] = 'Momochi'
momochi_games.head()
# Out:
# 0                                 NaN Total Results Total Results  \
# 1      Street Fighter III: 3rd Strike     $1,500.00             1
# 2                   Street Fighter IV       $221.38             1
# 3                    Street Fighter V    $45,886.66            12
# 4    Street Fighter V: Arcade Edition    $87,160.28            10
# 5  Street Fighter V: Champion Edition     $1,665.00             2
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.64%   |          $0.00              0          0.00%   |
# 2         0.09%   |          $0.00              0          0.00%   |
# 3        19.51%   |          $0.00              0          0.00%   |
# 4        37.05%   |          $0.00              0          0.00%   |
# 5         0.71%   |        $240.00              1          0.10%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1           $1,500.00                   1               0.64%   Momochi
# ...

# %%
momochi_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
momochi_games.head()
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1      Street Fighter III: 3rd Strike    $1,500.00            1         0.64%
# 2                   Street Fighter IV      $221.38            1         0.09%
# 3                    Street Fighter V   $45,886.66           12        19.51%
# 4    Street Fighter V: Arcade Edition   $87,160.28           10        37.05%
# 5  Street Fighter V: Champion Edition    $1,665.00            2         0.71%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |      $1,500.00
# 2     |         $0.00             0          0.00%      |        $221.38
# 3     |         $0.00             0          0.00%      |     $45,886.66
# 4     |         $0.00             0          0.00%      |     $87,160.28
# 5     |       $240.00             1          0.10%      |      $1,425.00
#
#   Offline Placed Offline Percent Player ID
# ...

# %%
momochi_games = momochi_games.drop(columns=['blank', 'blank1'])
momochi_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1          Street Fighter III: 3rd Strike    $1,500.00            1
# 2                       Street Fighter IV      $221.38            1
# 3                        Street Fighter V   $45,886.66           12
# 4        Street Fighter V: Arcade Edition   $87,160.28           10
# 5      Street Fighter V: Champion Edition    $1,665.00            2
# 6                 Street Fighter X Tekken    $2,480.00            3
# 7  Super Street Fighter IV Arcade Edition    $5,129.95            6
# 8                 Ultra Street Fighter IV   $91,178.45           13
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1         0.64%         $0.00             0          0.00%      $1,500.00
# 2         0.09%         $0.00             0          0.00%        $221.38
# 3        19.51%         $0.00             0          0.00%     $45,886.66
# ...

# %% [markdown]
# ## ZeRo

# %%
zero_url = 'https://www.esportsearnings.com/players/5750-zero-gonzalo-barrios'
response = requests.get(zero_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
zero = pd.read_html(str(tables), skiprows=1)

# %%
zero = zero[0]
zero.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2019.0        $925.73              3          0.51%    |           $0.00
# 2  2017.0     $79,457.85             47         43.47%    |           $0.00
# 3  2016.0     $41,029.92             32         22.45%    |           $0.00
# 4  2015.0     $50,230.25             36         27.48%    |         $500.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |              $925.73
# 2               0           0.00%    |           $79,457.85
# 3               0           0.00%    |           $41,029.92
# 4               1           0.27%    |           $49,730.25
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    3                0.51%
# ...

# %%
zero.columns = zero.iloc[0]
zero
# Out:
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results  \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2019.0        $925.73              3          0.51%    |           $0.00
# 2  2017.0     $79,457.85             47         43.47%    |           $0.00
# 3  2016.0     $41,029.92             32         22.45%    |           $0.00
# 4  2015.0     $50,230.25             36         27.48%    |         $500.00
# 5  2014.0      $9,711.84             31          5.31%    |         $500.00
# 6  2013.0      $1,015.80             18          0.56%    |           $0.00
# 7  2012.0        $407.50              3          0.22%    |           $0.00
#
# 0  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |              $925.73
# 2               0           0.00%    |           $79,457.85
# ...

# %%
zero = zero.drop([0])
zero.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0       $925.73             3         0.51%   |          $0.00
# 2  2017.0    $79,457.85            47        43.47%   |          $0.00
# 3  2016.0    $41,029.92            32        22.45%   |          $0.00
# 4  2015.0    $50,230.25            36        27.48%   |        $500.00
# 5  2014.0     $9,711.84            31         5.31%   |        $500.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |             $925.73                   3
# 2              0          0.00%   |          $79,457.85                  47
# 3              0          0.00%   |          $41,029.92                  32
# 4              1          0.27%   |          $49,730.25                  35
# 5              1          0.27%   |           $9,211.84                  30
#
# 0 Offline/LAN Results
# 1               0.51%
# 2              43.47%
# ...

# %%
zero['Player ID'] = 'ZeRo'
zero.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0       $925.73             3         0.51%   |          $0.00
# 2  2017.0    $79,457.85            47        43.47%   |          $0.00
# 3  2016.0    $41,029.92            32        22.45%   |          $0.00
# 4  2015.0    $50,230.25            36        27.48%   |        $500.00
# 5  2014.0     $9,711.84            31         5.31%   |        $500.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |             $925.73                   3
# 2              0          0.00%   |          $79,457.85                  47
# 3              0          0.00%   |          $41,029.92                  32
# 4              1          0.27%   |          $49,730.25                  35
# 5              1          0.27%   |           $9,211.84                  30
#
# 0 Offline/LAN Results Player ID
# 1               0.51%      ZeRo
# ...

# %%
zero.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
zero.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2019.0      $925.73            3         0.51%     |         $0.00
# 2  2017.0   $79,457.85           47        43.47%     |         $0.00
# 3  2016.0   $41,029.92           32        22.45%     |         $0.00
# 4  2015.0   $50,230.25           36        27.48%     |       $500.00
# 5  2014.0    $9,711.84           31         5.31%     |       $500.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |        $925.73              3
# 2             0          0.00%      |     $79,457.85             47
# 3             0          0.00%      |     $41,029.92             32
# 4             1          0.27%      |     $49,730.25             35
# 5             1          0.27%      |      $9,211.84             30
#
#   Offline Percent Player ID
# 1           0.51%      ZeRo
# 2          43.47%      ZeRo
# 3          22.45%      ZeRo
# ...

# %%
zero['Year'] = zero['Year'].round().astype(int)
zero.head()
# Out:
#    Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2019      $925.73            3         0.51%     |         $0.00
# 2  2017   $79,457.85           47        43.47%     |         $0.00
# 3  2016   $41,029.92           32        22.45%     |         $0.00
# 4  2015   $50,230.25           36        27.48%     |       $500.00
# 5  2014    $9,711.84           31         5.31%     |       $500.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |        $925.73              3
# 2             0          0.00%      |     $79,457.85             47
# 3             0          0.00%      |     $41,029.92             32
# 4             1          0.27%      |     $49,730.25             35
# 5             1          0.27%      |      $9,211.84             30
#
#   Offline Percent Player ID
# 1           0.51%      ZeRo
# 2          43.47%      ZeRo
# 3          22.45%      ZeRo
# 4          27.21%      ZeRo
# ...

# %%
zero = zero.drop(columns=['blank', 'blank1'])
zero
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2019      $925.73            3         0.51%         $0.00             0
# 2  2017   $79,457.85           47        43.47%         $0.00             0
# 3  2016   $41,029.92           32        22.45%         $0.00             0
# 4  2015   $50,230.25           36        27.48%       $500.00             1
# 5  2014    $9,711.84           31         5.31%       $500.00             1
# 6  2013    $1,015.80           18         0.56%         $0.00             0
# 7  2012      $407.50            3         0.22%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%        $925.73              3           0.51%      ZeRo
# 2          0.00%     $79,457.85             47          43.47%      ZeRo
# 3          0.00%     $41,029.92             32          22.45%      ZeRo
# ...

# %%
zero_games = pd.read_html(str(tables), skiprows=1)

# %%
zero_games = zero_games[2]
zero_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $6,377.22             18          3.49%
# 2            Super Smash Bros.         $12.00              1          0.01%
# 3      Super Smash Bros. Brawl      $3,735.30             23          2.04%
# 4      Super Smash Bros. Melee        $408.62              9          0.22%
# 5   Super Smash Bros. Ultimate        $925.73              3          0.51%
# 6  Super Smash Bros. for Wii U    $171,320.02            116         93.73%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# ...

# %%
zero_games.columns = zero_games.iloc[0]
zero_games.head()
# Out:
# 0                      NaN  Total Results  Total Results  Total Results  NaN  \
# 0                      NaN  Total Results  Total Results  Total Results  NaN
# 1                Project M      $6,377.22             18          3.49%    |
# 2        Super Smash Bros.         $12.00              1          0.01%    |
# 3  Super Smash Bros. Brawl      $3,735.30             23          2.04%    |
# 4  Super Smash Bros. Melee        $408.62              9          0.22%    |
#
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results  \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |            $6,377.22
# 2           $0.00               0           0.00%    |               $12.00
# 3           $0.00               0           0.00%    |            $3,735.30
# 4           $0.00               0           0.00%    |              $408.62
#
# 0  Offline/LAN Results  Offline/LAN Results
# ...

# %%
zero_games = zero_games.drop([0])
zero_games.head()
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1                   Project M     $6,377.22            18         3.49%   |
# 2           Super Smash Bros.        $12.00             1         0.01%   |
# 3     Super Smash Bros. Brawl     $3,735.30            23         2.04%   |
# 4     Super Smash Bros. Melee       $408.62             9         0.22%   |
# 5  Super Smash Bros. Ultimate       $925.73             3         0.51%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $6,377.22
# 2          $0.00              0          0.00%   |              $12.00
# 3          $0.00              0          0.00%   |           $3,735.30
# 4          $0.00              0          0.00%   |             $408.62
# 5          $0.00              0          0.00%   |             $925.73
#
# 0 Offline/LAN Results Offline/LAN Results
# ...

# %%
zero_games['Player ID'] = 'ZeRo'
zero_games.head()
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1                   Project M     $6,377.22            18         3.49%   |
# 2           Super Smash Bros.        $12.00             1         0.01%   |
# 3     Super Smash Bros. Brawl     $3,735.30            23         2.04%   |
# 4     Super Smash Bros. Melee       $408.62             9         0.22%   |
# 5  Super Smash Bros. Ultimate       $925.73             3         0.51%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $6,377.22
# 2          $0.00              0          0.00%   |              $12.00
# 3          $0.00              0          0.00%   |           $3,735.30
# 4          $0.00              0          0.00%   |             $408.62
# 5          $0.00              0          0.00%   |             $925.73
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
zero_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
zero_games.head()
# Out:
#                          Game Total Prizes Total Placed Total Percent blank  \
# 1                   Project M    $6,377.22           18         3.49%     |
# 2           Super Smash Bros.       $12.00            1         0.01%     |
# 3     Super Smash Bros. Brawl    $3,735.30           23         2.04%     |
# 4     Super Smash Bros. Melee      $408.62            9         0.22%     |
# 5  Super Smash Bros. Ultimate      $925.73            3         0.51%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $6,377.22
# 2         $0.00             0          0.00%      |         $12.00
# 3         $0.00             0          0.00%      |      $3,735.30
# 4         $0.00             0          0.00%      |        $408.62
# 5         $0.00             0          0.00%      |        $925.73
#
#   Offline Placed Offline Percent Player ID
# 1             18           3.49%      ZeRo
# ...

# %%
zero_games = zero_games.drop(columns=['blank', 'blank1'])
zero_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M    $6,377.22           18         3.49%
# 2            Super Smash Bros.       $12.00            1         0.01%
# 3      Super Smash Bros. Brawl    $3,735.30           23         2.04%
# 4      Super Smash Bros. Melee      $408.62            9         0.22%
# 5   Super Smash Bros. Ultimate      $925.73            3         0.51%
# 6  Super Smash Bros. for Wii U  $171,320.02          116        93.73%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $6,377.22             18
# 2         $0.00             0          0.00%         $12.00              1
# 3         $0.00             0          0.00%      $3,735.30             23
# 4         $0.00             0          0.00%        $408.62              9
# 5         $0.00             0          0.00%        $925.73              3
# ...

# %% [markdown]
# ## Sandstorm

# %%
sandstorm_url = 'https://www.esportsearnings.com/players/5750-zero-gonzalo-barrios'
response = requests.get(sandstorm_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
sandstorm = pd.read_html(str(tables), skiprows=1)

# %%
sandstorm = sandstorm[0]
sandstorm.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2019.0        $925.73              3          0.51%    |           $0.00
# 2  2017.0     $79,457.85             47         43.47%    |           $0.00
# 3  2016.0     $41,029.92             32         22.45%    |           $0.00
# 4  2015.0     $50,230.25             36         27.48%    |         $500.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |              $925.73
# 2               0           0.00%    |           $79,457.85
# 3               0           0.00%    |           $41,029.92
# 4               1           0.27%    |           $49,730.25
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    3                0.51%
# ...

# %%
sandstorm.columns = sandstorm.iloc[0]

# %%
sandstorm = sandstorm.drop([0])
sandstorm.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0       $925.73             3         0.51%   |          $0.00
# 2  2017.0    $79,457.85            47        43.47%   |          $0.00
# 3  2016.0    $41,029.92            32        22.45%   |          $0.00
# 4  2015.0    $50,230.25            36        27.48%   |        $500.00
# 5  2014.0     $9,711.84            31         5.31%   |        $500.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |             $925.73                   3
# 2              0          0.00%   |          $79,457.85                  47
# 3              0          0.00%   |          $41,029.92                  32
# 4              1          0.27%   |          $49,730.25                  35
# 5              1          0.27%   |           $9,211.84                  30
#
# 0 Offline/LAN Results
# 1               0.51%
# 2              43.47%
# ...

# %%
sandstorm['Player ID'] = 'Sandstorm'
sandstorm.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0       $925.73             3         0.51%   |          $0.00
# 2  2017.0    $79,457.85            47        43.47%   |          $0.00
# 3  2016.0    $41,029.92            32        22.45%   |          $0.00
# 4  2015.0    $50,230.25            36        27.48%   |        $500.00
# 5  2014.0     $9,711.84            31         5.31%   |        $500.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |             $925.73                   3
# 2              0          0.00%   |          $79,457.85                  47
# 3              0          0.00%   |          $41,029.92                  32
# 4              1          0.27%   |          $49,730.25                  35
# 5              1          0.27%   |           $9,211.84                  30
#
# 0 Offline/LAN Results  Player ID
# 1               0.51%  Sandstorm
# ...

# %%
sandstorm.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
sandstorm.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2019.0      $925.73            3         0.51%     |         $0.00
# 2  2017.0   $79,457.85           47        43.47%     |         $0.00
# 3  2016.0   $41,029.92           32        22.45%     |         $0.00
# 4  2015.0   $50,230.25           36        27.48%     |       $500.00
# 5  2014.0    $9,711.84           31         5.31%     |       $500.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |        $925.73              3
# 2             0          0.00%      |     $79,457.85             47
# 3             0          0.00%      |     $41,029.92             32
# 4             1          0.27%      |     $49,730.25             35
# 5             1          0.27%      |      $9,211.84             30
#
#   Offline Percent  Player ID
# 1           0.51%  Sandstorm
# 2          43.47%  Sandstorm
# 3          22.45%  Sandstorm
# ...

# %%
sandstorm['Year'] = sandstorm['Year'].round().astype(int)

# %%
sandstorm = sandstorm.drop(columns=['blank', 'blank1'])
sandstorm
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2019      $925.73            3         0.51%         $0.00             0
# 2  2017   $79,457.85           47        43.47%         $0.00             0
# 3  2016   $41,029.92           32        22.45%         $0.00             0
# 4  2015   $50,230.25           36        27.48%       $500.00             1
# 5  2014    $9,711.84           31         5.31%       $500.00             1
# 6  2013    $1,015.80           18         0.56%         $0.00             0
# 7  2012      $407.50            3         0.22%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent  Player ID
# 1          0.00%        $925.73              3           0.51%  Sandstorm
# 2          0.00%     $79,457.85             47          43.47%  Sandstorm
# 3          0.00%     $41,029.92             32          22.45%  Sandstorm
# ...

# %%
sandstorm_games = pd.read_html(str(tables), skiprows=1)

# %%
sandstorm_games = sandstorm_games[2]
sandstorm_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $6,377.22             18          3.49%
# 2            Super Smash Bros.         $12.00              1          0.01%
# 3      Super Smash Bros. Brawl      $3,735.30             23          2.04%
# 4      Super Smash Bros. Melee        $408.62              9          0.22%
# 5   Super Smash Bros. Ultimate        $925.73              3          0.51%
# 6  Super Smash Bros. for Wii U    $171,320.02            116         93.73%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# ...

# %%
sandstorm_games.columns = sandstorm_games.iloc[0]
sandstorm_games
# Out:
# 0                          NaN  Total Results  Total Results  Total Results  \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $6,377.22             18          3.49%
# 2            Super Smash Bros.         $12.00              1          0.01%
# 3      Super Smash Bros. Brawl      $3,735.30             23          2.04%
# 4      Super Smash Bros. Melee        $408.62              9          0.22%
# 5   Super Smash Bros. Ultimate        $925.73              3          0.51%
# 6  Super Smash Bros. for Wii U    $171,320.02            116         93.73%
#
# 0  NaN  Online Results  Online Results  Online Results  NaN  \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# ...

# %%
sandstorm_games = sandstorm_games.drop([0])
sandstorm_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $6,377.22            18         3.49%   |
# 2            Super Smash Bros.        $12.00             1         0.01%   |
# 3      Super Smash Bros. Brawl     $3,735.30            23         2.04%   |
# 4      Super Smash Bros. Melee       $408.62             9         0.22%   |
# 5   Super Smash Bros. Ultimate       $925.73             3         0.51%   |
# 6  Super Smash Bros. for Wii U   $171,320.02           116        93.73%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $6,377.22
# 2          $0.00              0          0.00%   |              $12.00
# 3          $0.00              0          0.00%   |           $3,735.30
# 4          $0.00              0          0.00%   |             $408.62
# 5          $0.00              0          0.00%   |             $925.73
# ...

# %%
sandstorm_games['Player ID'] = 'Sandstorm'
sandstorm_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $6,377.22            18         3.49%   |
# 2            Super Smash Bros.        $12.00             1         0.01%   |
# 3      Super Smash Bros. Brawl     $3,735.30            23         2.04%   |
# 4      Super Smash Bros. Melee       $408.62             9         0.22%   |
# 5   Super Smash Bros. Ultimate       $925.73             3         0.51%   |
# 6  Super Smash Bros. for Wii U   $171,320.02           116        93.73%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $6,377.22
# 2          $0.00              0          0.00%   |              $12.00
# 3          $0.00              0          0.00%   |           $3,735.30
# 4          $0.00              0          0.00%   |             $408.62
# 5          $0.00              0          0.00%   |             $925.73
# ...

# %%
sandstorm_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
sandstorm_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1                    Project M    $6,377.22           18         3.49%     |
# 2            Super Smash Bros.       $12.00            1         0.01%     |
# 3      Super Smash Bros. Brawl    $3,735.30           23         2.04%     |
# 4      Super Smash Bros. Melee      $408.62            9         0.22%     |
# 5   Super Smash Bros. Ultimate      $925.73            3         0.51%     |
# 6  Super Smash Bros. for Wii U  $171,320.02          116        93.73%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $6,377.22
# 2         $0.00             0          0.00%      |         $12.00
# 3         $0.00             0          0.00%      |      $3,735.30
# 4         $0.00             0          0.00%      |        $408.62
# 5         $0.00             0          0.00%      |        $925.73
# ...

# %%
sandstorm_games = sandstorm_games.drop(columns=['blank', 'blank1'])
sandstorm_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M    $6,377.22           18         3.49%
# 2            Super Smash Bros.       $12.00            1         0.01%
# 3      Super Smash Bros. Brawl    $3,735.30           23         2.04%
# 4      Super Smash Bros. Melee      $408.62            9         0.22%
# 5   Super Smash Bros. Ultimate      $925.73            3         0.51%
# 6  Super Smash Bros. for Wii U  $171,320.02          116        93.73%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $6,377.22             18
# 2         $0.00             0          0.00%         $12.00              1
# 3         $0.00             0          0.00%      $3,735.30             23
# 4         $0.00             0          0.00%        $408.62              9
# 5         $0.00             0          0.00%        $925.73              3
# ...

# %% [markdown]
# ## A Foxy Grampa

# %%
afoxygrandpa_url = 'https://www.esportsearnings.com/players/18711-a-foxy-grampa-denom-jones'
response = requests.get(afoxygrandpa_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
afoxygrandpa = pd.read_html(str(tables), skiprows=1)

# %%
afoxygrandpa = afoxygrandpa[0]
afoxygrandpa.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $2,000.00              1          1.16%    |           $0.00
# 2  2020.0     $16,000.00              2          9.27%    |           $0.00
# 3  2019.0     $12,502.43             13          7.24%    |          $25.00
# 4  2018.0        $308.42              2          0.18%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |            $2,000.00
# 2               0           0.00%    |           $16,000.00
# 3               1           0.01%    |           $12,477.43
# 4               0           0.00%    |              $308.42
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                1.16%
# ...

# %%
afoxygrandpa.columns = afoxygrandpa.iloc[0]

# %%
afoxygrandpa = afoxygrandpa.drop([0])
afoxygrandpa.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $2,000.00             1         1.16%   |          $0.00
# 2  2020.0    $16,000.00             2         9.27%   |          $0.00
# 3  2019.0    $12,502.43            13         7.24%   |         $25.00
# 4  2018.0       $308.42             2         0.18%   |          $0.00
# 5  2017.0    $57,198.35             7        33.14%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $2,000.00                   1
# 2              0          0.00%   |          $16,000.00                   2
# 3              1          0.01%   |          $12,477.43                  12
# 4              0          0.00%   |             $308.42                   2
# 5              0          0.00%   |          $57,198.35                   7
#
# 0 Offline/LAN Results
# 1               1.16%
# 2               9.27%
# ...

# %%
afoxygrandpa['Player ID'] = 'A Foxy Grampa'
afoxygrandpa.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $2,000.00             1         1.16%   |          $0.00
# 2  2020.0    $16,000.00             2         9.27%   |          $0.00
# 3  2019.0    $12,502.43            13         7.24%   |         $25.00
# 4  2018.0       $308.42             2         0.18%   |          $0.00
# 5  2017.0    $57,198.35             7        33.14%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $2,000.00                   1
# 2              0          0.00%   |          $16,000.00                   2
# 3              1          0.01%   |          $12,477.43                  12
# 4              0          0.00%   |             $308.42                   2
# 5              0          0.00%   |          $57,198.35                   7
#
# 0 Offline/LAN Results      Player ID
# 1               1.16%  A Foxy Grampa
# ...

# %%
afoxygrandpa.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
afoxygrandpa.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $2,000.00            1         1.16%     |         $0.00
# 2  2020.0   $16,000.00            2         9.27%     |         $0.00
# 3  2019.0   $12,502.43           13         7.24%     |        $25.00
# 4  2018.0      $308.42            2         0.18%     |         $0.00
# 5  2017.0   $57,198.35            7        33.14%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $2,000.00              1
# 2             0          0.00%      |     $16,000.00              2
# 3             1          0.01%      |     $12,477.43             12
# 4             0          0.00%      |        $308.42              2
# 5             0          0.00%      |     $57,198.35              7
#
#   Offline Percent      Player ID
# 1           1.16%  A Foxy Grampa
# 2           9.27%  A Foxy Grampa
# ...

# %%
afoxygrandpa['Year'] = afoxygrandpa['Year'].round().astype(int)

# %%
afoxygrandpa = afoxygrandpa.drop(columns=['blank', 'blank1'])
afoxygrandpa
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $2,000.00            1         1.16%         $0.00             0
# 2  2020   $16,000.00            2         9.27%         $0.00             0
# 3  2019   $12,502.43           13         7.24%        $25.00             1
# 4  2018      $308.42            2         0.18%         $0.00             0
# 5  2017   $57,198.35            7        33.14%         $0.00             0
# 6  2016   $63,531.50            4        36.81%         $0.00             0
# 7  2015   $21,032.23            3        12.19%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent      Player ID
# 1          0.00%      $2,000.00              1           1.16%  A Foxy Grampa
# 2          0.00%     $16,000.00              2           9.27%  A Foxy Grampa
# 3          0.01%     $12,477.43             12           7.23%  A Foxy Grampa
# ...

# %%
afoxygrandpa_games = pd.read_html(str(tables), skiprows=1)

# %%
afoxygrandpa_games = afoxygrandpa_games[1]
afoxygrandpa_games
# Out:
#                      0              1              2              3    4   \
# 0                   NaN  Total Results  Total Results  Total Results  NaN
# 1  Dragon Ball FighterZ        $232.22              1          0.13%    |
# 2           Injustice 2     $57,169.35              6         33.13%    |
# 3      Mortal Kombat 11     $30,502.43             16         17.68%    |
# 4       Mortal Kombat X     $72,022.23              5         41.73%    |
# 5      Mortal Kombat XL     $12,646.70              4          7.33%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |              $232.22
# 2           $0.00               0           0.00%    |           $57,169.35
# 3          $25.00               1           0.01%    |           $30,477.43
# ...

# %%
afoxygrandpa_games.columns = afoxygrandpa_games.iloc[0]

# %%
afoxygrandpa_games = afoxygrandpa_games.drop([0])

# %%
afoxygrandpa_games['Player ID'] = 'A Foxy Grampa'
afoxygrandpa_games
# Out:
# 0                   NaN Total Results Total Results Total Results NaN  \
# 1  Dragon Ball FighterZ       $232.22             1         0.13%   |
# 2           Injustice 2    $57,169.35             6        33.13%   |
# 3      Mortal Kombat 11    $30,502.43            16        17.68%   |
# 4       Mortal Kombat X    $72,022.23             5        41.73%   |
# 5      Mortal Kombat XL    $12,646.70             4         7.33%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |             $232.22
# 2          $0.00              0          0.00%   |          $57,169.35
# 3         $25.00              1          0.01%   |          $30,477.43
# 4          $0.00              0          0.00%   |          $72,022.23
# 5          $0.00              0          0.00%   |          $12,646.70
#
# 0 Offline/LAN Results Offline/LAN Results      Player ID
# 1                   1               0.13%  A Foxy Grampa
# ...

# %%
afoxygrandpa_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
    'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
afoxygrandpa_games
# Out:
#                    Game Total Prizes Total Placed Total Percent blank  \
# 1  Dragon Ball FighterZ      $232.22            1         0.13%     |
# 2           Injustice 2   $57,169.35            6        33.13%     |
# 3      Mortal Kombat 11   $30,502.43           16        17.68%     |
# 4       Mortal Kombat X   $72,022.23            5        41.73%     |
# 5      Mortal Kombat XL   $12,646.70            4         7.33%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |        $232.22
# 2         $0.00             0          0.00%      |     $57,169.35
# 3        $25.00             1          0.01%      |     $30,477.43
# 4         $0.00             0          0.00%      |     $72,022.23
# 5         $0.00             0          0.00%      |     $12,646.70
#
#   Offline Placed Offline Percent      Player ID
# 1              1           0.13%  A Foxy Grampa
# ...

# %%
afoxygrandpa_games = afoxygrandpa_games.drop(columns=['blank', 'blank1'])
afoxygrandpa_games
# Out:
#                    Game Total Prizes Total Placed Total Percent Online Prizes  \
# 1  Dragon Ball FighterZ      $232.22            1         0.13%         $0.00
# 2           Injustice 2   $57,169.35            6        33.13%         $0.00
# 3      Mortal Kombat 11   $30,502.43           16        17.68%        $25.00
# 4       Mortal Kombat X   $72,022.23            5        41.73%         $0.00
# 5      Mortal Kombat XL   $12,646.70            4         7.33%         $0.00
#
#   Online Placed Online Percent Offline Prizes Offline Placed Offline Percent  \
# 1             0          0.00%        $232.22              1           0.13%
# 2             0          0.00%     $57,169.35              6          33.13%
# 3             1          0.01%     $30,477.43             15          17.66%
# 4             0          0.00%     $72,022.23              5          41.73%
# 5             0          0.00%     $12,646.70              4           7.33%
#
#        Player ID
# ...

# %% [markdown]
# ## Leffen

# %%
leffen_url = 'https://www.esportsearnings.com/players/5742-leffen-william-hjelte'
response = requests.get(leffen_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
leffen = pd.read_html(str(tables), skiprows=1)

# %%
leffen = leffen[0]
leffen.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $1,756.30              2          1.08%    |         $156.30
# 2  2020.0      $2,694.31              4          1.65%    |         $855.34
# 3  2019.0     $16,113.77              9          9.89%    |           $0.00
# 4  2018.0     $32,223.31             13         19.77%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           0.10%    |            $1,600.00
# 2               2           0.52%    |            $1,838.97
# 3               0           0.00%    |           $16,113.77
# 4               0           0.00%    |           $32,223.31
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                0.98%
# ...

# %%
leffen.columns = leffen.iloc[0]

# %%
leffen = leffen.drop([0])

# %%
leffen['Player ID'] = 'Leffen'
leffen.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $1,756.30             2         1.08%   |        $156.30
# 2  2020.0     $2,694.31             4         1.65%   |        $855.34
# 3  2019.0    $16,113.77             9         9.89%   |          $0.00
# 4  2018.0    $32,223.31            13        19.77%   |          $0.00
# 5  2017.0    $41,301.32            29        25.34%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.10%   |           $1,600.00                   1
# 2              2          0.52%   |           $1,838.97                   2
# 3              0          0.00%   |          $16,113.77                   9
# 4              0          0.00%   |          $32,223.31                  13
# 5              0          0.00%   |          $41,301.32                  29
#
# 0 Offline/LAN Results Player ID
# 1               0.98%    Leffen
# ...

# %%
leffen.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
leffen.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $1,756.30            2         1.08%     |       $156.30
# 2  2020.0    $2,694.31            4         1.65%     |       $855.34
# 3  2019.0   $16,113.77            9         9.89%     |         $0.00
# 4  2018.0   $32,223.31           13        19.77%     |         $0.00
# 5  2017.0   $41,301.32           29        25.34%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.10%      |      $1,600.00              1
# 2             2          0.52%      |      $1,838.97              2
# 3             0          0.00%      |     $16,113.77              9
# 4             0          0.00%      |     $32,223.31             13
# 5             0          0.00%      |     $41,301.32             29
#
#   Offline Percent Player ID
# 1           0.98%    Leffen
# 2           1.13%    Leffen
# 3           9.89%    Leffen
# ...

# %%
leffen['Year'] = leffen['Year'].round().astype(int)

# %%
leffen = leffen.drop(columns=['blank', 'blank1'])
leffen
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021    $1,756.30            2         1.08%       $156.30             1
# 2   2020    $2,694.31            4         1.65%       $855.34             2
# 3   2019   $16,113.77            9         9.89%         $0.00             0
# 4   2018   $32,223.31           13        19.77%         $0.00             0
# 5   2017   $41,301.32           29        25.34%         $0.00             0
# 6   2016   $23,868.76           26        14.65%         $0.00             0
# 7   2015   $37,357.87           39        22.92%         $0.00             0
# 8   2014    $6,532.30           14         4.01%         $0.00             0
# 9   2013       $27.40            1         0.02%         $0.00             0
# 10  2012      $774.54            4         0.48%         $0.00             0
# 11  2011      $329.23            5         0.20%         $0.00             0
#
# ...

# %%
leffen_games = pd.read_html(str(tables), skiprows=1)

# %%
leffen_games = leffen_games[2]
leffen_games.head()
# Out:
#                      0              1              2              3    4   \
# 0                   NaN  Total Results  Total Results  Total Results  NaN
# 1  Dragon Ball FighterZ      $2,730.11              2          1.68%    |
# 2             Fall Guys        $500.00              1          0.31%    |
# 3  Guilty Gear -STRIVE-        $156.30              1          0.10%    |
# 4             Project M        $249.92              5          0.15%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |            $2,730.11
# 2         $500.00               1           0.31%    |                $0.00
# 3         $156.30               1           0.10%    |                $0.00
# 4           $0.00               0           0.00%    |              $249.92
#
#                     10                   11
# ...

# %%
leffen_games.columns = leffen_games.iloc[0]

# %%
leffen_games = leffen_games.drop([0])

# %%
leffen_games['Player ID'] = 'Leffen'
leffen_games.head()
# Out:
# 0                      NaN Total Results Total Results Total Results NaN  \
# 1     Dragon Ball FighterZ     $2,730.11             2         1.68%   |
# 2                Fall Guys       $500.00             1         0.31%   |
# 3     Guilty Gear -STRIVE-       $156.30             1         0.10%   |
# 4                Project M       $249.92             5         0.15%   |
# 5  Super Smash Bros. Melee   $154,966.56           133        95.08%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $2,730.11
# 2        $500.00              1          0.31%   |               $0.00
# 3        $156.30              1          0.10%   |               $0.00
# 4          $0.00              0          0.00%   |             $249.92
# 5        $355.34              1          0.22%   |         $154,611.22
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
leffen_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
leffen_games.head()
# Out:
#                       Game Total Prizes Total Placed Total Percent blank  \
# 1     Dragon Ball FighterZ    $2,730.11            2         1.68%     |
# 2                Fall Guys      $500.00            1         0.31%     |
# 3     Guilty Gear -STRIVE-      $156.30            1         0.10%     |
# 4                Project M      $249.92            5         0.15%     |
# 5  Super Smash Bros. Melee  $154,966.56          133        95.08%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $2,730.11
# 2       $500.00             1          0.31%      |          $0.00
# 3       $156.30             1          0.10%      |          $0.00
# 4         $0.00             0          0.00%      |        $249.92
# 5       $355.34             1          0.22%      |    $154,611.22
#
#   Offline Placed Offline Percent Player ID
# 1              2           1.68%    Leffen
# ...

# %%
leffen_games = leffen_games.drop(columns=['blank', 'blank1'])
leffen_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1         Dragon Ball FighterZ    $2,730.11            2         1.68%
# 2                    Fall Guys      $500.00            1         0.31%
# 3         Guilty Gear -STRIVE-      $156.30            1         0.10%
# 4                    Project M      $249.92            5         0.15%
# 5      Super Smash Bros. Melee  $154,966.56          133        95.08%
# 6   Super Smash Bros. Ultimate    $4,215.17            3         2.59%
# 7  Super Smash Bros. for Wii U      $161.05            1         0.10%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $2,730.11              2
# 2       $500.00             1          0.31%          $0.00              0
# 3       $156.30             1          0.10%          $0.00              0
# 4         $0.00             0          0.00%        $249.92              5
# ...

# %% [markdown]
# ## Fujimura

# %%
fujimura_url = 'https://www.esportsearnings.com/players/30579-fujimura-atsushi'
response = requests.get(fujimura_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
fujimura = pd.read_html(str(tables), skiprows=1)

# %%
fujimura = fujimura[0]
fujimura
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0        $240.00              1          0.16%    |         $240.00
# 2  2019.0     $17,926.40              6         12.19%    |           $0.00
# 3  2018.0     $71,474.80             13         48.60%    |           $0.00
# 4  2017.0     $39,975.00              7         27.18%    |           $0.00
# 5  2016.0     $17,460.28              3         11.87%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           0.16%    |                $0.00
# 2               0           0.00%    |           $17,926.40
# 3               0           0.00%    |           $71,474.80
# 4               0           0.00%    |           $39,975.00
# 5               0           0.00%    |           $17,460.28
#
# ...

# %%
fujimura.columns = fujimura.iloc[0]

# %%
fujimura = fujimura.drop([0])

# %%
fujimura['Player ID'] = 'Fujimura'
fujimura
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0       $240.00             1         0.16%   |        $240.00
# 2  2019.0    $17,926.40             6        12.19%   |          $0.00
# 3  2018.0    $71,474.80            13        48.60%   |          $0.00
# 4  2017.0    $39,975.00             7        27.18%   |          $0.00
# 5  2016.0    $17,460.28             3        11.87%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.16%   |               $0.00                   0
# 2              0          0.00%   |          $17,926.40                   6
# 3              0          0.00%   |          $71,474.80                  13
# 4              0          0.00%   |          $39,975.00                   7
# 5              0          0.00%   |          $17,460.28                   3
#
# 0 Offline/LAN Results Player ID
# 1               0.00%  Fujimura
# ...

# %%
fujimura.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
fujimura
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0      $240.00            1         0.16%     |       $240.00
# 2  2019.0   $17,926.40            6        12.19%     |         $0.00
# 3  2018.0   $71,474.80           13        48.60%     |         $0.00
# 4  2017.0   $39,975.00            7        27.18%     |         $0.00
# 5  2016.0   $17,460.28            3        11.87%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.16%      |          $0.00              0
# 2             0          0.00%      |     $17,926.40              6
# 3             0          0.00%      |     $71,474.80             13
# 4             0          0.00%      |     $39,975.00              7
# 5             0          0.00%      |     $17,460.28              3
#
#   Offline Percent Player ID
# 1           0.00%  Fujimura
# 2          12.19%  Fujimura
# 3          48.60%  Fujimura
# ...

# %%
fujimura['Year'] = fujimura['Year'].round().astype(int)

# %%
fujimura = fujimura.drop(columns=['blank', 'blank1'])
fujimura
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021      $240.00            1         0.16%       $240.00             1
# 2  2019   $17,926.40            6        12.19%         $0.00             0
# 3  2018   $71,474.80           13        48.60%         $0.00             0
# 4  2017   $39,975.00            7        27.18%         $0.00             0
# 5  2016   $17,460.28            3        11.87%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.16%          $0.00              0           0.00%  Fujimura
# 2          0.00%     $17,926.40              6          12.19%  Fujimura
# 3          0.00%     $71,474.80             13          48.60%  Fujimura
# 4          0.00%     $39,975.00              7          27.18%  Fujimura
# 5          0.00%     $17,460.28              3          11.87%  Fujimura

# %%
fujimura_games = pd.read_html(str(tables), skiprows=1)

# %%
fujimura_games = fujimura_games[1]
fujimura_games
# Out:
#                                    0              1              2   \
# 0                                 NaN  Total Results  Total Results
# 1                    Street Fighter V     $57,935.28             11
# 2    Street Fighter V: Arcade Edition     $88,901.20             18
# 3  Street Fighter V: Champion Edition        $240.00              1
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1         39.39%    |           $0.00               0           0.00%    |
# 2         60.45%    |           $0.00               0           0.00%    |
# 3          0.16%    |         $240.00               1           0.16%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# 1           $57,935.28                   11               39.39%
# ...

# %%
fujimura_games.columns = fujimura_games.iloc[0]

# %%
fujimura_games = fujimura_games.drop([0])

# %%
fujimura_games['Player ID'] = 'Fujimura'
fujimura_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                    Street Fighter V    $57,935.28            11
# 2    Street Fighter V: Arcade Edition    $88,901.20            18
# 3  Street Fighter V: Champion Edition       $240.00             1
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        39.39%   |          $0.00              0          0.00%   |
# 2        60.45%   |          $0.00              0          0.00%   |
# 3         0.16%   |        $240.00              1          0.16%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1          $57,935.28                  11              39.39%  Fujimura
# 2          $88,901.20                  18              60.45%  Fujimura
# 3               $0.00                   0               0.00%  Fujimura

# %%
fujimura_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
fujimura_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V   $57,935.28           11        39.39%
# 2    Street Fighter V: Arcade Edition   $88,901.20           18        60.45%
# 3  Street Fighter V: Champion Edition      $240.00            1         0.16%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |     $57,935.28
# 2     |         $0.00             0          0.00%      |     $88,901.20
# 3     |       $240.00             1          0.16%      |          $0.00
#
#   Offline Placed Offline Percent Player ID
# 1             11          39.39%  Fujimura
# 2             18          60.45%  Fujimura
# 3              0           0.00%  Fujimura

# %%
fujimura_games = fujimura_games.drop(columns=['blank', 'blank1'])
fujimura_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V   $57,935.28           11        39.39%
# 2    Street Fighter V: Arcade Edition   $88,901.20           18        60.45%
# 3  Street Fighter V: Champion Edition      $240.00            1         0.16%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%     $57,935.28             11
# 2         $0.00             0          0.00%     $88,901.20             18
# 3       $240.00             1          0.16%          $0.00              0
#
#   Offline Percent Player ID
# 1          39.39%  Fujimura
# 2          60.45%  Fujimura
# 3           0.00%  Fujimura

# %% [markdown]
# ## Itabashi Zangief

# %%
itabashi_url = 'https://www.esportsearnings.com/players/2032-itabashi-zangief-kumada-hiromiki'
response = requests.get(itabashi_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
itabashi = pd.read_html(str(tables), skiprows=1)

# %%
itabashi = itabashi[0]
itabashi.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $7,648.00              3          5.27%    |       $6,000.00
# 2  2020.0     $24,909.70              2         17.18%    |           $0.00
# 3  2019.0        $500.00              1          0.34%    |           $0.00
# 4  2018.0     $71,142.00              7         49.07%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           4.14%    |            $1,648.00
# 2               0           0.00%    |           $24,909.70
# 3               0           0.00%    |              $500.00
# 4               0           0.00%    |           $71,142.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    2                1.14%
# ...

# %%
itabashi.columns = itabashi.iloc[0]

# %%
itabashi = itabashi.drop([0])

# %%
itabashi['Player ID'] = 'Itabashi Zangief'
itabashi.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $7,648.00             3         5.27%   |      $6,000.00
# 2  2020.0    $24,909.70             2        17.18%   |          $0.00
# 3  2019.0       $500.00             1         0.34%   |          $0.00
# 4  2018.0    $71,142.00             7        49.07%   |          $0.00
# 5  2017.0    $21,550.00             6        14.86%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          4.14%   |           $1,648.00                   2
# 2              0          0.00%   |          $24,909.70                   2
# 3              0          0.00%   |             $500.00                   1
# 4              0          0.00%   |          $71,142.00                   7
# 5              0          0.00%   |          $21,550.00                   6
#
# 0 Offline/LAN Results         Player ID
# 1               1.14%  Itabashi Zangief
# ...

# %%
itabashi.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
itabashi.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $7,648.00            3         5.27%     |     $6,000.00
# 2  2020.0   $24,909.70            2        17.18%     |         $0.00
# 3  2019.0      $500.00            1         0.34%     |         $0.00
# 4  2018.0   $71,142.00            7        49.07%     |         $0.00
# 5  2017.0   $21,550.00            6        14.86%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          4.14%      |      $1,648.00              2
# 2             0          0.00%      |     $24,909.70              2
# 3             0          0.00%      |        $500.00              1
# 4             0          0.00%      |     $71,142.00              7
# 5             0          0.00%      |     $21,550.00              6
#
#   Offline Percent         Player ID
# 1           1.14%  Itabashi Zangief
# 2          17.18%  Itabashi Zangief
# ...

# %%
itabashi['Year'] = itabashi['Year'].round().astype(int)

# %%
itabashi = itabashi.drop(columns=['blank', 'blank1'])
itabashi
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021    $7,648.00            3         5.27%     $6,000.00             1
# 2   2020   $24,909.70            2        17.18%         $0.00             0
# 3   2019      $500.00            1         0.34%         $0.00             0
# 4   2018   $71,142.00            7        49.07%         $0.00             0
# 5   2017   $21,550.00            6        14.86%         $0.00             0
# 6   2016    $1,500.00            2         1.03%         $0.00             0
# 7   2015    $1,637.49            2         1.13%         $0.00             0
# 8   2014    $1,100.80            2         0.76%         $0.00             0
# 9   2008   $10,000.00            1         6.90%         $0.00             0
# 10  2007    $5,000.00            1         3.45%         $0.00             0
# 11  2004        $0.00            1         0.00%         $0.00             0
#
# ...

# %%
itabashi_games = pd.read_html(str(tables), skiprows=1)

# %%
itabashi_games = itabashi_games[2]
itabashi_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                        Street Fighter V     $23,050.00              8
# 2        Street Fighter V: Arcade Edition     $72,372.27              9
# 3      Street Fighter V: Champion Edition     $31,827.43              4
# 4  Super Street Fighter IV Arcade Edition        $637.49              1
# 5                 Ultra Street Fighter IV      $2,100.80              3
# 6             Virtua Fighter 4: Evolution          $0.00              1
# 7                        Virtua Fighter 5     $15,000.00              2
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1         15.90%    |           $0.00               0           0.00%    |
# 2         49.92%    |           $0.00               0           0.00%    |
# ...

# %%
itabashi_games.columns = itabashi_games.iloc[0]

# %%
itabashi_games = itabashi_games.drop([0])

# %%
itabashi_games['Player ID'] = 'Itabashi Zangief'
itabashi_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                        Street Fighter V    $23,050.00             8
# 2        Street Fighter V: Arcade Edition    $72,372.27             9
# 3      Street Fighter V: Champion Edition    $31,827.43             4
# 4  Super Street Fighter IV Arcade Edition       $637.49             1
# 5                 Ultra Street Fighter IV     $2,100.80             3
# 6             Virtua Fighter 4: Evolution         $0.00             1
# 7                        Virtua Fighter 5    $15,000.00             2
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        15.90%   |          $0.00              0          0.00%   |
# 2        49.92%   |          $0.00              0          0.00%   |
# 3        21.95%   |      $6,000.00              1          4.14%   |
# 4         0.44%   |          $0.00              0          0.00%   |
# ...

# %%
itabashi_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
itabashi_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                        Street Fighter V   $23,050.00            8
# 2        Street Fighter V: Arcade Edition   $72,372.27            9
# 3      Street Fighter V: Champion Edition   $31,827.43            4
# 4  Super Street Fighter IV Arcade Edition      $637.49            1
# 5                 Ultra Street Fighter IV    $2,100.80            3
# 6             Virtua Fighter 4: Evolution        $0.00            1
# 7                        Virtua Fighter 5   $15,000.00            2
#
#   Total Percent blank Online Prizes Online Placed Online Percent blank1  \
# 1        15.90%     |         $0.00             0          0.00%      |
# 2        49.92%     |         $0.00             0          0.00%      |
# 3        21.95%     |     $6,000.00             1          4.14%      |
# 4         0.44%     |         $0.00             0          0.00%      |
# ...

# %%
itabashi_games = itabashi_games.drop(columns=['blank', 'blank1'])
itabashi_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                        Street Fighter V   $23,050.00            8
# 2        Street Fighter V: Arcade Edition   $72,372.27            9
# 3      Street Fighter V: Champion Edition   $31,827.43            4
# 4  Super Street Fighter IV Arcade Edition      $637.49            1
# 5                 Ultra Street Fighter IV    $2,100.80            3
# 6             Virtua Fighter 4: Evolution        $0.00            1
# 7                        Virtua Fighter 5   $15,000.00            2
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1        15.90%         $0.00             0          0.00%     $23,050.00
# 2        49.92%         $0.00             0          0.00%     $72,372.27
# 3        21.95%     $6,000.00             1          4.14%     $25,827.43
# 4         0.44%         $0.00             0          0.00%        $637.49
# ...

# %% [markdown]
# ## Boomie

# %%
boomie_url = 'https://www.esportsearnings.com/players/29916-boomie-zack-bielamowicz'
response = requests.get(boomie_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
boomie = pd.read_html(str(tables), skiprows=1)

# %%
boomie = boomie[0]
boomie
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $15,216.67              8         10.66%    |      $15,216.67
# 2  2020.0     $19,720.00             20         13.82%    |      $19,720.00
# 3  2019.0     $55,327.00             44         38.77%    |      $11,425.00
# 4  2018.0     $25,020.00             26         17.53%    |       $3,245.00
# 5  2017.0     $23,359.00             21         16.37%    |       $3,242.50
# 6  2016.0      $4,065.00             17          2.85%    |       $1,615.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               8          10.66%    |                $0.00
# 2              20          13.82%    |                $0.00
# 3              23           8.01%    |           $43,902.00
# ...

# %%
boomie.columns = boomie.iloc[0]

# %%
boomie = boomie.drop([0])

# %%
boomie['Player ID'] = 'Boomie'
boomie
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $15,216.67             8        10.66%   |     $15,216.67
# 2  2020.0    $19,720.00            20        13.82%   |     $19,720.00
# 3  2019.0    $55,327.00            44        38.77%   |     $11,425.00
# 4  2018.0    $25,020.00            26        17.53%   |      $3,245.00
# 5  2017.0    $23,359.00            21        16.37%   |      $3,242.50
# 6  2016.0     $4,065.00            17         2.85%   |      $1,615.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              8         10.66%   |               $0.00                   0
# 2             20         13.82%   |               $0.00                   0
# 3             23          8.01%   |          $43,902.00                  21
# 4             16          2.27%   |          $21,775.00                  10
# 5             14          2.27%   |          $20,116.50                   7
# ...

# %%
boomie.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
boomie
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $15,216.67            8        10.66%     |    $15,216.67
# 2  2020.0   $19,720.00           20        13.82%     |    $19,720.00
# 3  2019.0   $55,327.00           44        38.77%     |    $11,425.00
# 4  2018.0   $25,020.00           26        17.53%     |     $3,245.00
# 5  2017.0   $23,359.00           21        16.37%     |     $3,242.50
# 6  2016.0    $4,065.00           17         2.85%     |     $1,615.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             8         10.66%      |          $0.00              0
# 2            20         13.82%      |          $0.00              0
# 3            23          8.01%      |     $43,902.00             21
# 4            16          2.27%      |     $21,775.00             10
# 5            14          2.27%      |     $20,116.50              7
# ...

# %%
boomie['Year'] = boomie['Year'].round().astype(int)

# %%
boomie = boomie.drop(columns=['blank', 'blank1'])
boomie
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $15,216.67            8        10.66%    $15,216.67             8
# 2  2020   $19,720.00           20        13.82%    $19,720.00            20
# 3  2019   $55,327.00           44        38.77%    $11,425.00            23
# 4  2018   $25,020.00           26        17.53%     $3,245.00            16
# 5  2017   $23,359.00           21        16.37%     $3,242.50            14
# 6  2016    $4,065.00           17         2.85%     $1,615.00            14
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1         10.66%          $0.00              0           0.00%    Boomie
# 2         13.82%          $0.00              0           0.00%    Boomie
# 3          8.01%     $43,902.00             21          30.76%    Boomie
# 4          2.27%     $21,775.00             10          15.26%    Boomie
# ...

# %%
boomie_games = pd.read_html(str(tables), skiprows=1)

# %%
boomie_games = boomie_games[2]
boomie_games
# Out:
#            0              1              2              3    4   \
# 0         NaN  Total Results  Total Results  Total Results  NaN
# 1  Brawlhalla    $142,707.67            136        100.00%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1      $54,464.17              95          38.16%    |           $88,243.50
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                   41               61.84%

# %%
boomie_games.columns = boomie_games.iloc[0]

# %%
boomie_games = boomie_games.drop([0])

# %%
boomie_games['Player ID'] = 'Boomie'
boomie_games
# Out:
# 0         NaN Total Results Total Results Total Results NaN Online Results  \
# 1  Brawlhalla   $142,707.67           136       100.00%   |     $54,464.17
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1             95         38.16%   |          $88,243.50                  41
#
# 0 Offline/LAN Results Player ID
# 1              61.84%    Boomie

# %%
boomie_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
boomie_games
# Out:
#          Game Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  Brawlhalla  $142,707.67          136       100.00%     |    $54,464.17
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1            95         38.16%      |     $88,243.50             41
#
#   Offline Percent Player ID
# 1          61.84%    Boomie

# %%
boomie_games = boomie_games.drop(columns=['blank', 'blank1'])
boomie_games
# Out:
#          Game Total Prizes Total Placed Total Percent Online Prizes  \
# 1  Brawlhalla  $142,707.67          136       100.00%    $54,464.17
#
#   Online Placed Online Percent Offline Prizes Offline Placed Offline Percent  \
# 1            95         38.16%     $88,243.50             41          61.84%
#
#   Player ID
# 1    Boomie

# %% [markdown]
# ## Dabuz

# %%
dabuz_url = 'https://www.esportsearnings.com/players/13751-dabuz-samuel-buzby'
response = requests.get(dabuz_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
dabuz = pd.read_html(str(tables), skiprows=1)

# %%
dabuz = dabuz[0]
dabuz.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $4,696.14              9          3.47%    |         $590.00
# 2  2020.0      $6,685.66             16          4.94%    |       $6,480.00
# 3  2019.0     $47,377.29             22         35.03%    |       $1,640.00
# 4  2018.0     $19,940.51             21         14.74%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               5           0.44%    |            $4,106.14
# 2              15           4.79%    |              $205.66
# 3               2           1.21%    |           $45,737.29
# 4               0           0.00%    |           $19,940.51
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    4                3.04%
# ...

# %%
dabuz.columns = dabuz.iloc[0]

# %%
dabuz = dabuz.drop([0])

# %%
dabuz['Player ID'] = 'Dabuz'
dabuz.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $4,696.14             9         3.47%   |        $590.00
# 2  2020.0     $6,685.66            16         4.94%   |      $6,480.00
# 3  2019.0    $47,377.29            22        35.03%   |      $1,640.00
# 4  2018.0    $19,940.51            21        14.74%   |          $0.00
# 5  2017.0    $22,914.80            16        16.94%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              5          0.44%   |           $4,106.14                   4
# 2             15          4.79%   |             $205.66                   1
# 3              2          1.21%   |          $45,737.29                  20
# 4              0          0.00%   |          $19,940.51                  21
# 5              0          0.00%   |          $22,914.80                  16
#
# 0 Offline/LAN Results Player ID
# 1               3.04%     Dabuz
# ...

# %%
dabuz.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
dabuz.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $4,696.14            9         3.47%     |       $590.00
# 2  2020.0    $6,685.66           16         4.94%     |     $6,480.00
# 3  2019.0   $47,377.29           22        35.03%     |     $1,640.00
# 4  2018.0   $19,940.51           21        14.74%     |         $0.00
# 5  2017.0   $22,914.80           16        16.94%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             5          0.44%      |      $4,106.14              4
# 2            15          4.79%      |        $205.66              1
# 3             2          1.21%      |     $45,737.29             20
# 4             0          0.00%      |     $19,940.51             21
# 5             0          0.00%      |     $22,914.80             16
#
#   Offline Percent Player ID
# 1           3.04%     Dabuz
# 2           0.15%     Dabuz
# 3          33.82%     Dabuz
# ...

# %%
dabuz['Year'] = dabuz['Year'].round().astype(int)

# %%
dabuz = dabuz.drop(columns=['blank', 'blank1'])
dabuz.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $4,696.14            9         3.47%       $590.00             5
# 2  2020    $6,685.66           16         4.94%     $6,480.00            15
# 3  2019   $47,377.29           22        35.03%     $1,640.00             2
# 4  2018   $19,940.51           21        14.74%         $0.00             0
# 5  2017   $22,914.80           16        16.94%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.44%      $4,106.14              4           3.04%     Dabuz
# 2          4.79%        $205.66              1           0.15%     Dabuz
# 3          1.21%     $45,737.29             20          33.82%     Dabuz
# 4          0.00%     $19,940.51             21          14.74%     Dabuz
# 5          0.00%     $22,914.80             16          16.94%     Dabuz

# %%
dabuz_games = pd.read_html(str(tables), skiprows=1)

# %%
dabuz_games = dabuz_games[2]
dabuz_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1              Mortal Kombat 9          $2.00              1          0.00%
# 2                    Project M          $6.00              1          0.00%
# 3      Super Smash Bros. Brawl      $1,177.07             15          0.87%
# 4   Super Smash Bros. Ultimate     $60,477.99             47         44.72%
# 5  Super Smash Bros. for Wii U     $73,586.67             86         54.41%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# 4    |       $8,710.00              22           6.44%    |
# 5    |           $0.00               0           0.00%    |
#
# ...

# %%
dabuz_games.columns = dabuz_games.iloc[0]

# %%
dabuz_games = dabuz_games.drop([0])

# %%
dabuz_games['Player ID'] = 'Dabuz'
dabuz_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1              Mortal Kombat 9         $2.00             1         0.00%   |
# 2                    Project M         $6.00             1         0.00%   |
# 3      Super Smash Bros. Brawl     $1,177.07            15         0.87%   |
# 4   Super Smash Bros. Ultimate    $60,477.99            47        44.72%   |
# 5  Super Smash Bros. for Wii U    $73,586.67            86        54.41%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |               $2.00
# 2          $0.00              0          0.00%   |               $6.00
# 3          $0.00              0          0.00%   |           $1,177.07
# 4      $8,710.00             22          6.44%   |          $51,767.99
# 5          $0.00              0          0.00%   |          $73,586.67
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
dabuz_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
dabuz_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1              Mortal Kombat 9        $2.00            1         0.00%     |
# 2                    Project M        $6.00            1         0.00%     |
# 3      Super Smash Bros. Brawl    $1,177.07           15         0.87%     |
# 4   Super Smash Bros. Ultimate   $60,477.99           47        44.72%     |
# 5  Super Smash Bros. for Wii U   $73,586.67           86        54.41%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |          $2.00
# 2         $0.00             0          0.00%      |          $6.00
# 3         $0.00             0          0.00%      |      $1,177.07
# 4     $8,710.00            22          6.44%      |     $51,767.99
# 5         $0.00             0          0.00%      |     $73,586.67
#
#   Offline Placed Offline Percent Player ID
# 1              1           0.00%     Dabuz
# ...

# %%
dabuz_games = dabuz_games.drop(columns=['blank', 'blank1'])
dabuz_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1              Mortal Kombat 9        $2.00            1         0.00%
# 2                    Project M        $6.00            1         0.00%
# 3      Super Smash Bros. Brawl    $1,177.07           15         0.87%
# 4   Super Smash Bros. Ultimate   $60,477.99           47        44.72%
# 5  Super Smash Bros. for Wii U   $73,586.67           86        54.41%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%          $2.00              1
# 2         $0.00             0          0.00%          $6.00              1
# 3         $0.00             0          0.00%      $1,177.07             15
# 4     $8,710.00            22          6.44%     $51,767.99             25
# 5         $0.00             0          0.00%     $73,586.67             86
#
#   Offline Percent Player ID
# 1           0.00%     Dabuz
# 2           0.00%     Dabuz
# ...

# %% [markdown]
# ## Nairo

# %%
nairo_url = 'https://www.esportsearnings.com/players/5749-nairo-nairoby-quezada'
response = requests.get(nairo_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
nairo = pd.read_html(str(tables), skiprows=1)

# %%
nairo = nairo[0]
nairo.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $1,525.15              1          1.14%    |           $0.00
# 2  2020.0      $1,991.91              3          1.49%    |       $1,400.00
# 3  2019.0     $21,309.27             26         15.89%    |       $1,600.00
# 4  2018.0     $18,213.37             16         13.58%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |            $1,525.15
# 2               1           1.04%    |              $591.91
# 3               1           1.19%    |           $19,709.27
# 4               0           0.00%    |           $18,213.37
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                1.14%
# ...

# %%
nairo.columns = nairo.iloc[0]

# %%
nairo = nairo.drop([0])

# %%
nairo['Player ID'] = 'Nairo'
nairo.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $1,525.15             1         1.14%   |          $0.00
# 2  2020.0     $1,991.91             3         1.49%   |      $1,400.00
# 3  2019.0    $21,309.27            26        15.89%   |      $1,600.00
# 4  2018.0    $18,213.37            16        13.58%   |          $0.00
# 5  2017.0    $24,118.45            34        17.98%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $1,525.15                   1
# 2              1          1.04%   |             $591.91                   2
# 3              1          1.19%   |          $19,709.27                  25
# 4              0          0.00%   |          $18,213.37                  16
# 5              0          0.00%   |          $24,118.45                  34
#
# 0 Offline/LAN Results Player ID
# 1               1.14%     Nairo
# ...

# %%
nairo.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
nairo.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $1,525.15            1         1.14%     |         $0.00
# 2  2020.0    $1,991.91            3         1.49%     |     $1,400.00
# 3  2019.0   $21,309.27           26        15.89%     |     $1,600.00
# 4  2018.0   $18,213.37           16        13.58%     |         $0.00
# 5  2017.0   $24,118.45           34        17.98%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $1,525.15              1
# 2             1          1.04%      |        $591.91              2
# 3             1          1.19%      |     $19,709.27             25
# 4             0          0.00%      |     $18,213.37             16
# 5             0          0.00%      |     $24,118.45             34
#
#   Offline Percent Player ID
# 1           1.14%     Nairo
# 2           0.44%     Nairo
# 3          14.70%     Nairo
# ...

# %%
nairo['Year'] = nairo['Year'].round().astype(int)

# %%
nairo = nairo.drop(columns=['blank', 'blank1'])
nairo
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021    $1,525.15            1         1.14%         $0.00             0
# 2   2020    $1,991.91            3         1.49%     $1,400.00             1
# 3   2019   $21,309.27           26        15.89%     $1,600.00             1
# 4   2018   $18,213.37           16        13.58%         $0.00             0
# 5   2017   $24,118.45           34        17.98%         $0.00             0
# 6   2016   $33,505.35           41        24.98%         $0.00             0
# 7   2015   $24,325.28           31        18.14%         $0.00             0
# 8   2014    $3,915.70            8         2.92%         $0.00             0
# 9   2013    $2,071.95           21         1.54%         $0.00             0
# 10  2012    $2,574.75           14         1.92%         $0.00             0
# 11  2011      $519.05            8         0.39%         $0.00             0
# ...

# %%
nairo_games = pd.read_html(str(tables), skiprows=1)

# %%
nairo_games = nairo_games[2]
nairo_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1      Super Smash Bros. Brawl     $13,690.07             67         10.21%
# 2      Super Smash Bros. Melee         $10.00              1          0.01%
# 3   Super Smash Bros. Ultimate     $25,022.48             31         18.66%
# 4  Super Smash Bros. for Wii U     $95,384.88            105         71.13%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |       $3,000.00               2           2.24%    |
# 4    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
nairo_games.columns = nairo_games.iloc[0]

# %%
nairo_games = nairo_games.drop([0])

# %%
nairo_games['Player ID'] = 'Nairo'
nairo_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1      Super Smash Bros. Brawl    $13,690.07            67        10.21%   |
# 2      Super Smash Bros. Melee        $10.00             1         0.01%   |
# 3   Super Smash Bros. Ultimate    $25,022.48            31        18.66%   |
# 4  Super Smash Bros. for Wii U    $95,384.88           105        71.13%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |          $13,690.07
# 2          $0.00              0          0.00%   |              $10.00
# 3      $3,000.00              2          2.24%   |          $22,022.48
# 4          $0.00              0          0.00%   |          $95,384.88
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                  67              10.21%     Nairo
# 2                   1               0.01%     Nairo
# 3                  29              16.42%     Nairo
# ...

# %%
nairo_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
nairo_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1      Super Smash Bros. Brawl   $13,690.07           67        10.21%     |
# 2      Super Smash Bros. Melee       $10.00            1         0.01%     |
# 3   Super Smash Bros. Ultimate   $25,022.48           31        18.66%     |
# 4  Super Smash Bros. for Wii U   $95,384.88          105        71.13%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |     $13,690.07
# 2         $0.00             0          0.00%      |         $10.00
# 3     $3,000.00             2          2.24%      |     $22,022.48
# 4         $0.00             0          0.00%      |     $95,384.88
#
#   Offline Placed Offline Percent Player ID
# 1             67          10.21%     Nairo
# 2              1           0.01%     Nairo
# 3             29          16.42%     Nairo
# 4            105          71.13%     Nairo

# %%
nairo_games = nairo_games.drop(columns=['blank', 'blank1'])
nairo_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1      Super Smash Bros. Brawl   $13,690.07           67        10.21%
# 2      Super Smash Bros. Melee       $10.00            1         0.01%
# 3   Super Smash Bros. Ultimate   $25,022.48           31        18.66%
# 4  Super Smash Bros. for Wii U   $95,384.88          105        71.13%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%     $13,690.07             67
# 2         $0.00             0          0.00%         $10.00              1
# 3     $3,000.00             2          2.24%     $22,022.48             29
# 4         $0.00             0          0.00%     $95,384.88            105
#
#   Offline Percent Player ID
# 1          10.21%     Nairo
# 2           0.01%     Nairo
# 3          16.42%     Nairo
# 4          71.13%     Nairo

# %% [markdown]
# ## JWong (Justin Wong)

# %%
jwong_url = 'https://www.esportsearnings.com/players/1694-jwong-justin-wong'
response = requests.get(jwong_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
jwong = pd.read_html(str(tables), skiprows=1)

# %%
jwong = jwong[0]
jwong.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $1,497.70              5          1.13%    |         $375.14
# 2  2019.0      $8,608.10             20          6.49%    |           $0.00
# 3  2018.0     $23,725.70             18         17.90%    |           $0.00
# 4  2017.0     $15,564.61             16         11.74%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               2           0.28%    |            $1,122.56
# 2               0           0.00%    |            $8,608.10
# 3               0           0.00%    |           $23,725.70
# 4               0           0.00%    |           $15,564.61
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    3                0.85%
# ...

# %%
jwong.columns = jwong.iloc[0]

# %%
jwong = jwong.drop([0])

# %%
jwong['Player ID'] = 'JWong'
jwong.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $1,497.70             5         1.13%   |        $375.14
# 2  2019.0     $8,608.10            20         6.49%   |          $0.00
# 3  2018.0    $23,725.70            18        17.90%   |          $0.00
# 4  2017.0    $15,564.61            16        11.74%   |          $0.00
# 5  2016.0    $18,409.21            17        13.89%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              2          0.28%   |           $1,122.56                   3
# 2              0          0.00%   |           $8,608.10                  20
# 3              0          0.00%   |          $23,725.70                  18
# 4              0          0.00%   |          $15,564.61                  16
# 5              0          0.00%   |          $18,409.21                  17
#
# 0 Offline/LAN Results Player ID
# 1               0.85%     JWong
# ...

# %%
jwong.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
jwong.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $1,497.70            5         1.13%     |       $375.14
# 2  2019.0    $8,608.10           20         6.49%     |         $0.00
# 3  2018.0   $23,725.70           18        17.90%     |         $0.00
# 4  2017.0   $15,564.61           16        11.74%     |         $0.00
# 5  2016.0   $18,409.21           17        13.89%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             2          0.28%      |      $1,122.56              3
# 2             0          0.00%      |      $8,608.10             20
# 3             0          0.00%      |     $23,725.70             18
# 4             0          0.00%      |     $15,564.61             16
# 5             0          0.00%      |     $18,409.21             17
#
#   Offline Percent Player ID
# 1           0.85%     JWong
# 2           6.49%     JWong
# 3          17.90%     JWong
# ...

# %%
jwong['Year'] = jwong['Year'].round().astype(int)

# %%
jwong = jwong.drop(columns=['blank', 'blank1'])
jwong.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $1,497.70            5         1.13%       $375.14             2
# 2  2019    $8,608.10           20         6.49%         $0.00             0
# 3  2018   $23,725.70           18        17.90%         $0.00             0
# 4  2017   $15,564.61           16        11.74%         $0.00             0
# 5  2016   $18,409.21           17        13.89%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.28%      $1,122.56              3           0.85%     JWong
# 2          0.00%      $8,608.10             20           6.49%     JWong
# 3          0.00%     $23,725.70             18          17.90%     JWong
# 4          0.00%     $15,564.61             16          11.74%     JWong
# 5          0.00%     $18,409.21             17          13.89%     JWong

# %%
jwong_games = pd.read_html(str(tables), skiprows=1)

# %%
jwong_games = jwong_games[2]
jwong_games.head()
# Out:
#                   0              1              2              3    4   \
# 0                NaN  Total Results  Total Results  Total Results  NaN
# 1   Capcom vs. SNK 2      $2,026.79              8          1.53%    |
# 2    Dead or Alive 5          $0.00              1          0.00%    |
# 3           Divekick        $550.00              1          0.41%    |
# 4  Fighting EX Layer         $76.48              1          0.06%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |            $2,026.79
# 2           $0.00               0           0.00%    |                $0.00
# 3           $0.00               0           0.00%    |              $550.00
# 4           $0.00               0           0.00%    |               $76.48
#
#                     10                   11
# ...

# %%
jwong_games.columns = jwong_games.iloc[0]

# %%
jwong_games = jwong_games.drop([0])

# %%
jwong_games['Player ID'] = 'JWong'
jwong_games.head()
# Out:
# 0                        NaN Total Results Total Results Total Results NaN  \
# 1           Capcom vs. SNK 2     $2,026.79             8         1.53%   |
# 2            Dead or Alive 5         $0.00             1         0.00%   |
# 3                   Divekick       $550.00             1         0.41%   |
# 4          Fighting EX Layer        $76.48             1         0.06%   |
# 5  Garou: Mark of the Wolves        $70.66             1         0.05%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $2,026.79
# 2          $0.00              0          0.00%   |               $0.00
# 3          $0.00              0          0.00%   |             $550.00
# 4          $0.00              0          0.00%   |              $76.48
# 5          $0.00              0          0.00%   |              $70.66
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
jwong_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
jwong_games.head()
# Out:
#                         Game Total Prizes Total Placed Total Percent blank  \
# 1           Capcom vs. SNK 2    $2,026.79            8         1.53%     |
# 2            Dead or Alive 5        $0.00            1         0.00%     |
# 3                   Divekick      $550.00            1         0.41%     |
# 4          Fighting EX Layer       $76.48            1         0.06%     |
# 5  Garou: Mark of the Wolves       $70.66            1         0.05%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $2,026.79
# 2         $0.00             0          0.00%      |          $0.00
# 3         $0.00             0          0.00%      |        $550.00
# 4         $0.00             0          0.00%      |         $76.48
# 5         $0.00             0          0.00%      |         $70.66
#
#   Offline Placed Offline Percent Player ID
# 1              8           1.53%     JWong
# ...

# %%
jwong_games = jwong_games.drop(columns=['blank', 'blank1'])
jwong_games.head()
# Out:
#                         Game Total Prizes Total Placed Total Percent  \
# 1           Capcom vs. SNK 2    $2,026.79            8         1.53%
# 2            Dead or Alive 5        $0.00            1         0.00%
# 3                   Divekick      $550.00            1         0.41%
# 4          Fighting EX Layer       $76.48            1         0.06%
# 5  Garou: Mark of the Wolves       $70.66            1         0.05%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $2,026.79              8
# 2         $0.00             0          0.00%          $0.00              1
# 3         $0.00             0          0.00%        $550.00              1
# 4         $0.00             0          0.00%         $76.48              1
# 5         $0.00             0          0.00%         $70.66              1
#
#   Offline Percent Player ID
# 1           1.53%     JWong
# 2           0.00%     JWong
# ...

# %% [markdown]
# ## Xian

# %%
xian_url = 'https://www.esportsearnings.com/players/3470-xian-ho-kun-xian'
response = requests.get(xian_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
xian = pd.read_html(str(tables), skiprows=1)

# %%
xian = xian[0]
xian.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $5,000.00              1          3.82%    |       $5,000.00
# 2  2019.0      $4,500.00              4          3.44%    |           $0.00
# 3  2018.0     $19,024.00              6         14.52%    |           $0.00
# 4  2017.0     $14,250.00              6         10.88%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           3.82%    |                $0.00
# 2               0           0.00%    |            $4,500.00
# 3               0           0.00%    |           $19,024.00
# 4               0           0.00%    |           $14,250.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
xian.columns = xian.iloc[0]

# %%
xian = xian.drop([0])

# %%
xian['Player ID'] = 'Xian'
xian.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $5,000.00             1         3.82%   |      $5,000.00
# 2  2019.0     $4,500.00             4         3.44%   |          $0.00
# 3  2018.0    $19,024.00             6        14.52%   |          $0.00
# 4  2017.0    $14,250.00             6        10.88%   |          $0.00
# 5  2016.0     $6,089.64             7         4.65%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          3.82%   |               $0.00                   0
# 2              0          0.00%   |           $4,500.00                   4
# 3              0          0.00%   |          $19,024.00                   6
# 4              0          0.00%   |          $14,250.00                   6
# 5              0          0.00%   |           $6,089.64                   7
#
# 0 Offline/LAN Results Player ID
# 1               0.00%      Xian
# ...

# %%
xian.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
xian.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $5,000.00            1         3.82%     |     $5,000.00
# 2  2019.0    $4,500.00            4         3.44%     |         $0.00
# 3  2018.0   $19,024.00            6        14.52%     |         $0.00
# 4  2017.0   $14,250.00            6        10.88%     |         $0.00
# 5  2016.0    $6,089.64            7         4.65%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          3.82%      |          $0.00              0
# 2             0          0.00%      |      $4,500.00              4
# 3             0          0.00%      |     $19,024.00              6
# 4             0          0.00%      |     $14,250.00              6
# 5             0          0.00%      |      $6,089.64              7
#
#   Offline Percent Player ID
# 1           0.00%      Xian
# 2           3.44%      Xian
# 3          14.52%      Xian
# ...

# %%
xian['Year'] = xian['Year'].round().astype(int)

# %%
xian = xian.drop(columns=['blank', 'blank1'])
xian.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $5,000.00            1         3.82%     $5,000.00             1
# 2  2019    $4,500.00            4         3.44%         $0.00             0
# 3  2018   $19,024.00            6        14.52%         $0.00             0
# 4  2017   $14,250.00            6        10.88%         $0.00             0
# 5  2016    $6,089.64            7         4.65%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          3.82%          $0.00              0           0.00%      Xian
# 2          0.00%      $4,500.00              4           3.44%      Xian
# 3          0.00%     $19,024.00              6          14.52%      Xian
# 4          0.00%     $14,250.00              6          10.88%      Xian
# 5          0.00%      $6,089.64              7           4.65%      Xian

# %%
xian_games = pd.read_html(str(tables), skiprows=1)

# %%
xian_games = xian_games[1]
xian_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                   King of Fighters XIII        $298.90              6
# 2                         Persona 4 Arena          $0.00              1
# 3                        Street Fighter V     $20,176.64             12
# 4        Street Fighter V: Arcade Edition     $23,524.00             10
# 5      Street Fighter V: Champion Edition      $5,000.00              1
# 6  Super Street Fighter IV Arcade Edition     $11,570.07              9
# 7                 Ultra Street Fighter IV     $70,415.31             15
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.23%    |           $0.00               0           0.00%    |
# 2          0.00%    |           $0.00               0           0.00%    |
# ...

# %%
xian_games.columns = xian_games.iloc[0]

# %%
xian_games = xian_games.drop([0])

# %%
xian_games['Player ID'] = 'Xian'
xian_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                   King of Fighters XIII       $298.90             6
# 2                         Persona 4 Arena         $0.00             1
# 3                        Street Fighter V    $20,176.64            12
# 4        Street Fighter V: Arcade Edition    $23,524.00            10
# 5      Street Fighter V: Champion Edition     $5,000.00             1
# 6  Super Street Fighter IV Arcade Edition    $11,570.07             9
# 7                 Ultra Street Fighter IV    $70,415.31            15
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.23%   |          $0.00              0          0.00%   |
# 2         0.00%   |          $0.00              0          0.00%   |
# 3        15.40%   |          $0.00              0          0.00%   |
# 4        17.96%   |          $0.00              0          0.00%   |
# ...

# %%
xian_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
xian_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                   King of Fighters XIII      $298.90            6
# 2                         Persona 4 Arena        $0.00            1
# 3                        Street Fighter V   $20,176.64           12
# 4        Street Fighter V: Arcade Edition   $23,524.00           10
# 5      Street Fighter V: Champion Edition    $5,000.00            1
# 6  Super Street Fighter IV Arcade Edition   $11,570.07            9
# 7                 Ultra Street Fighter IV   $70,415.31           15
#
#   Total Percent blank Online Prizes Online Placed Online Percent blank1  \
# 1         0.23%     |         $0.00             0          0.00%      |
# 2         0.00%     |         $0.00             0          0.00%      |
# 3        15.40%     |         $0.00             0          0.00%      |
# 4        17.96%     |         $0.00             0          0.00%      |
# ...

# %%
xian_games = xian_games.drop(columns=['blank', 'blank1'])
xian_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                   King of Fighters XIII      $298.90            6
# 2                         Persona 4 Arena        $0.00            1
# 3                        Street Fighter V   $20,176.64           12
# 4        Street Fighter V: Arcade Edition   $23,524.00           10
# 5      Street Fighter V: Champion Edition    $5,000.00            1
# 6  Super Street Fighter IV Arcade Edition   $11,570.07            9
# 7                 Ultra Street Fighter IV   $70,415.31           15
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1         0.23%         $0.00             0          0.00%        $298.90
# 2         0.00%         $0.00             0          0.00%          $0.00
# 3        15.40%         $0.00             0          0.00%     $20,176.64
# 4        17.96%         $0.00             0          0.00%     $23,524.00
# ...

# %% [markdown]
# ## JDCR

# %%
jdcr_url = 'https://www.esportsearnings.com/players/1504-jdcr-kim-hyun-jin'
response = requests.get(jdcr_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
jdcr = pd.read_html(str(tables), skiprows=1)

# %%
jdcr = jdcr[0]
jdcr.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $9,750.00              2          7.56%    |           $0.00
# 2  2020.0     $10,132.00              3          7.86%    |           $0.00
# 3  2019.0     $17,437.90             11         13.53%    |           $0.00
# 4  2018.0      $7,374.10              8          5.72%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |            $9,750.00
# 2               0           0.00%    |           $10,132.00
# 3               0           0.00%    |           $17,437.90
# 4               0           0.00%    |            $7,374.10
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    2                7.56%
# ...

# %%
jdcr.columns = jdcr.iloc[0]

# %%
jdcr = jdcr.drop([0])

# %%
jdcr['Player ID'] = 'JDCR'
jdcr.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $9,750.00             2         7.56%   |          $0.00
# 2  2020.0    $10,132.00             3         7.86%   |          $0.00
# 3  2019.0    $17,437.90            11        13.53%   |          $0.00
# 4  2018.0     $7,374.10             8         5.72%   |          $0.00
# 5  2017.0    $59,512.00            13        46.16%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $9,750.00                   2
# 2              0          0.00%   |          $10,132.00                   3
# 3              0          0.00%   |          $17,437.90                  11
# 4              0          0.00%   |           $7,374.10                   8
# 5              0          0.00%   |          $59,512.00                  13
#
# 0 Offline/LAN Results Player ID
# 1               7.56%      JDCR
# ...

# %%
jdcr.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
jdcr.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $9,750.00            2         7.56%     |         $0.00
# 2  2020.0   $10,132.00            3         7.86%     |         $0.00
# 3  2019.0   $17,437.90           11        13.53%     |         $0.00
# 4  2018.0    $7,374.10            8         5.72%     |         $0.00
# 5  2017.0   $59,512.00           13        46.16%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $9,750.00              2
# 2             0          0.00%      |     $10,132.00              3
# 3             0          0.00%      |     $17,437.90             11
# 4             0          0.00%      |      $7,374.10              8
# 5             0          0.00%      |     $59,512.00             13
#
#   Offline Percent Player ID
# 1           7.56%      JDCR
# 2           7.86%      JDCR
# 3          13.53%      JDCR
# ...

# %%
jdcr['Year'] = jdcr['Year'].round().astype(int)

# %%
jdcr = jdcr.drop(columns=['blank', 'blank1'])
jdcr
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021    $9,750.00            2         7.56%         $0.00             0
# 2   2020   $10,132.00            3         7.86%         $0.00             0
# 3   2019   $17,437.90           11        13.53%         $0.00             0
# 4   2018    $7,374.10            8         5.72%         $0.00             0
# 5   2017   $59,512.00           13        46.16%         $0.00             0
# 6   2015    $1,383.20            2         1.07%         $0.00             0
# 7   2014    $9,542.00            4         7.40%         $0.00             0
# 8   2013    $4,800.00            3         3.72%         $0.00             0
# 9   2012    $7,985.61            2         6.19%         $0.00             0
# 10  2011    $1,000.00            1         0.78%         $0.00             0
#
#    Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# ...

# %%
jdcr_games = pd.read_html(str(tables), skiprows=1)

# %%
jdcr_games = jdcr_games[2]
jdcr_games.head()
# Out:
#                         0              1              2              3    4   \
# 0                      NaN  Total Results  Total Results  Total Results  NaN
# 1                 Tekken 6      $2,985.61              2          2.32%    |
# 2                 Tekken 7    $105,589.20             38         81.90%    |
# 3  Tekken Tag Tournament 2     $20,342.00              9         15.78%    |
#
#                5               6               7    8                    9   \
# 0  Online Results  Online Results  Online Results  NaN  Offline/LAN Results
# 1           $0.00               0           0.00%    |            $2,985.61
# 2           $0.00               0           0.00%    |          $105,589.20
# 3           $0.00               0           0.00%    |           $20,342.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    2                2.32%
# 2                   38               81.90%
# ...

# %%
jdcr_games.columns = jdcr_games.iloc[0]

# %%
jdcr_games = jdcr_games.drop([0])

# %%
jdcr_games['Player ID'] = 'JDCR'
jdcr_games.head()
# Out:
# 0                      NaN Total Results Total Results Total Results NaN  \
# 1                 Tekken 6     $2,985.61             2         2.32%   |
# 2                 Tekken 7   $105,589.20            38        81.90%   |
# 3  Tekken Tag Tournament 2    $20,342.00             9        15.78%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $2,985.61
# 2          $0.00              0          0.00%   |         $105,589.20
# 3          $0.00              0          0.00%   |          $20,342.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                   2               2.32%      JDCR
# 2                  38              81.90%      JDCR
# 3                   9              15.78%      JDCR

# %%
jdcr_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
jdcr_games.head()
# Out:
#                       Game Total Prizes Total Placed Total Percent blank  \
# 1                 Tekken 6    $2,985.61            2         2.32%     |
# 2                 Tekken 7  $105,589.20           38        81.90%     |
# 3  Tekken Tag Tournament 2   $20,342.00            9        15.78%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $2,985.61
# 2         $0.00             0          0.00%      |    $105,589.20
# 3         $0.00             0          0.00%      |     $20,342.00
#
#   Offline Placed Offline Percent Player ID
# 1              2           2.32%      JDCR
# 2             38          81.90%      JDCR
# 3              9          15.78%      JDCR

# %%
jdcr_games = jdcr_games.drop(columns=['blank', 'blank1'])
jdcr_games
# Out:
#                       Game Total Prizes Total Placed Total Percent  \
# 1                 Tekken 6    $2,985.61            2         2.32%
# 2                 Tekken 7  $105,589.20           38        81.90%
# 3  Tekken Tag Tournament 2   $20,342.00            9        15.78%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $2,985.61              2
# 2         $0.00             0          0.00%    $105,589.20             38
# 3         $0.00             0          0.00%     $20,342.00              9
#
#   Offline Percent Player ID
# 1           2.32%      JDCR
# 2          81.90%      JDCR
# 3          15.78%      JDCR

# %% [markdown]
# ## Plup

# %%
plup_url = 'https://www.esportsearnings.com/players/5745-plup-justin-mcgrath'
response = requests.get(plup_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
plup = pd.read_html(str(tables), skiprows=1)

# %%
plup = plup[0]
plup.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $17,166.90              2         13.37%    |           $0.00
# 2  2020.0     $15,880.72              3         12.37%    |       $1,750.07
# 3  2019.0      $8,012.61             17          6.24%    |           $0.00
# 4  2018.0     $27,343.43             19         21.30%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |           $17,166.90
# 2               1           1.36%    |           $14,130.65
# 3               0           0.00%    |            $8,012.61
# 4               0           0.00%    |           $27,343.43
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    2               13.37%
# ...

# %%
plup.columns = plup.iloc[0]

# %%
plup = plup.drop([0])

# %%
plup['Player ID'] = 'Plup'
plup.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $17,166.90             2        13.37%   |          $0.00
# 2  2020.0    $15,880.72             3        12.37%   |      $1,750.07
# 3  2019.0     $8,012.61            17         6.24%   |          $0.00
# 4  2018.0    $27,343.43            19        21.30%   |          $0.00
# 5  2017.0    $27,088.73            35        21.10%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |          $17,166.90                   2
# 2              1          1.36%   |          $14,130.65                   2
# 3              0          0.00%   |           $8,012.61                  17
# 4              0          0.00%   |          $27,343.43                  19
# 5              0          0.00%   |          $27,088.73                  35
#
# 0 Offline/LAN Results Player ID
# 1              13.37%      Plup
# ...

# %%
plup.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
plup.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $17,166.90            2        13.37%     |         $0.00
# 2  2020.0   $15,880.72            3        12.37%     |     $1,750.07
# 3  2019.0    $8,012.61           17         6.24%     |         $0.00
# 4  2018.0   $27,343.43           19        21.30%     |         $0.00
# 5  2017.0   $27,088.73           35        21.10%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |     $17,166.90              2
# 2             1          1.36%      |     $14,130.65              2
# 3             0          0.00%      |      $8,012.61             17
# 4             0          0.00%      |     $27,343.43             19
# 5             0          0.00%      |     $27,088.73             35
#
#   Offline Percent Player ID
# 1          13.37%      Plup
# 2          11.01%      Plup
# 3           6.24%      Plup
# ...

# %%
plup['Year'] = plup['Year'].round().astype(int)

# %%
plup = plup.drop(columns=['blank', 'blank1'])
plup.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $17,166.90            2        13.37%         $0.00             0
# 2  2020   $15,880.72            3        12.37%     $1,750.07             1
# 3  2019    $8,012.61           17         6.24%         $0.00             0
# 4  2018   $27,343.43           19        21.30%         $0.00             0
# 5  2017   $27,088.73           35        21.10%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%     $17,166.90              2          13.37%      Plup
# 2          1.36%     $14,130.65              2          11.01%      Plup
# 3          0.00%      $8,012.61             17           6.24%      Plup
# 4          0.00%     $27,343.43             19          21.30%      Plup
# 5          0.00%     $27,088.73             35          21.10%      Plup

# %%
plup_games = pd.read_html(str(tables), skiprows=1)

# %%
plup_games = plup_games[2]
plup_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $2,431.85             18          1.89%
# 2             Rivals of Aether        $250.00              1          0.19%
# 3      Super Smash Bros. Melee    $124,728.49            214         97.14%
# 4   Super Smash Bros. Ultimate        $761.84              2          0.59%
# 5  Super Smash Bros. for Wii U        $224.40              4          0.17%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |       $1,750.07               1           1.36%    |
# 4    |           $0.00               0           0.00%    |
# 5    |           $0.00               0           0.00%    |
#
# ...

# %%
plup_games.columns = plup_games.iloc[0]

# %%
plup_games = plup_games.drop([0])

# %%
plup_games['Player ID'] = 'Plup'
plup_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $2,431.85            18         1.89%   |
# 2             Rivals of Aether       $250.00             1         0.19%   |
# 3      Super Smash Bros. Melee   $124,728.49           214        97.14%   |
# 4   Super Smash Bros. Ultimate       $761.84             2         0.59%   |
# 5  Super Smash Bros. for Wii U       $224.40             4         0.17%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $2,431.85
# 2          $0.00              0          0.00%   |             $250.00
# 3      $1,750.07              1          1.36%   |         $122,978.42
# 4          $0.00              0          0.00%   |             $761.84
# 5          $0.00              0          0.00%   |             $224.40
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
plup_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
plup_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1                    Project M    $2,431.85           18         1.89%     |
# 2             Rivals of Aether      $250.00            1         0.19%     |
# 3      Super Smash Bros. Melee  $124,728.49          214        97.14%     |
# 4   Super Smash Bros. Ultimate      $761.84            2         0.59%     |
# 5  Super Smash Bros. for Wii U      $224.40            4         0.17%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $2,431.85
# 2         $0.00             0          0.00%      |        $250.00
# 3     $1,750.07             1          1.36%      |    $122,978.42
# 4         $0.00             0          0.00%      |        $761.84
# 5         $0.00             0          0.00%      |        $224.40
#
#   Offline Placed Offline Percent Player ID
# 1             18           1.89%      Plup
# ...

# %%
plup_games = plup_games.drop(columns=['blank', 'blank1'])
plup_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M    $2,431.85           18         1.89%
# 2             Rivals of Aether      $250.00            1         0.19%
# 3      Super Smash Bros. Melee  $124,728.49          214        97.14%
# 4   Super Smash Bros. Ultimate      $761.84            2         0.59%
# 5  Super Smash Bros. for Wii U      $224.40            4         0.17%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $2,431.85             18
# 2         $0.00             0          0.00%        $250.00              1
# 3     $1,750.07             1          1.36%    $122,978.42            213
# 4         $0.00             0          0.00%        $761.84              2
# 5         $0.00             0          0.00%        $224.40              4
#
#   Offline Percent Player ID
# 1           1.89%      Plup
# 2           0.19%      Plup
# ...

# %% [markdown]
# ## Tweek

# %%
tweek_url = 'https://www.esportsearnings.com/players/21593-tweek-gavin-dempsey'
response = requests.get(tweek_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
tweek = pd.read_html(str(tables), skiprows=1)

# %%
tweek = tweek[0]
tweek.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0     $48,879.46              3         38.14%    |           $0.00
# 2  2020.0      $3,892.21              9          3.04%    |       $2,805.00
# 3  2019.0     $27,298.83             17         21.30%    |           $0.00
# 4  2018.0     $30,311.14             21         23.65%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |           $48,879.46
# 2               6           2.19%    |            $1,087.21
# 3               0           0.00%    |           $27,298.83
# 4               0           0.00%    |           $30,311.14
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    3               38.14%
# ...

# %%
tweek.columns = tweek.iloc[0]

# %%
tweek = tweek.drop([0])

# %%
tweek['Player ID'] = 'Tweek'
tweek.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0    $48,879.46             3        38.14%   |          $0.00
# 2  2020.0     $3,892.21             9         3.04%   |      $2,805.00
# 3  2019.0    $27,298.83            17        21.30%   |          $0.00
# 4  2018.0    $30,311.14            21        23.65%   |          $0.00
# 5  2017.0    $12,661.10            30         9.88%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |          $48,879.46                   3
# 2              6          2.19%   |           $1,087.21                   3
# 3              0          0.00%   |          $27,298.83                  17
# 4              0          0.00%   |          $30,311.14                  21
# 5              0          0.00%   |          $12,661.10                  30
#
# 0 Offline/LAN Results Player ID
# 1              38.14%     Tweek
# ...

# %%
tweek.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
tweek.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0   $48,879.46            3        38.14%     |         $0.00
# 2  2020.0    $3,892.21            9         3.04%     |     $2,805.00
# 3  2019.0   $27,298.83           17        21.30%     |         $0.00
# 4  2018.0   $30,311.14           21        23.65%     |         $0.00
# 5  2017.0   $12,661.10           30         9.88%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |     $48,879.46              3
# 2             6          2.19%      |      $1,087.21              3
# 3             0          0.00%      |     $27,298.83             17
# 4             0          0.00%      |     $30,311.14             21
# 5             0          0.00%      |     $12,661.10             30
#
#   Offline Percent Player ID
# 1          38.14%     Tweek
# 2           0.85%     Tweek
# 3          21.30%     Tweek
# ...

# %%
tweek['Year'] = tweek['Year'].round().astype(int)

# %%
tweek = tweek.drop(columns=['blank', 'blank1'])
tweek
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021   $48,879.46            3        38.14%         $0.00             0
# 2  2020    $3,892.21            9         3.04%     $2,805.00             6
# 3  2019   $27,298.83           17        21.30%         $0.00             0
# 4  2018   $30,311.14           21        23.65%         $0.00             0
# 5  2017   $12,661.10           30         9.88%         $0.00             0
# 6  2016    $4,214.92           22         3.29%         $0.00             0
# 7  2015      $904.75            9         0.71%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%     $48,879.46              3          38.14%     Tweek
# 2          2.19%      $1,087.21              3           0.85%     Tweek
# 3          0.00%     $27,298.83             17          21.30%     Tweek
# ...

# %%
tweek_games = pd.read_html(str(tables), skiprows=1)

# %%
tweek_games = tweek_games[2]
tweek_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1      Super Smash Bros. Melee        $106.75              4          0.08%
# 2   Super Smash Bros. Ultimate     $87,826.50             33         68.53%
# 3  Super Smash Bros. for Wii U     $40,229.16             74         31.39%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |       $2,805.00               6           2.19%    |
# 3    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# 1              $106.75                    4                0.08%
# 2           $85,021.50                   27               66.34%
# ...

# %%
tweek_games.columns = tweek_games.iloc[0]

# %%
tweek_games = tweek_games.drop([0])

# %%
tweek_games['Player ID'] = 'Tweek'
tweek_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1      Super Smash Bros. Melee       $106.75             4         0.08%   |
# 2   Super Smash Bros. Ultimate    $87,826.50            33        68.53%   |
# 3  Super Smash Bros. for Wii U    $40,229.16            74        31.39%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |             $106.75
# 2      $2,805.00              6          2.19%   |          $85,021.50
# 3          $0.00              0          0.00%   |          $40,229.16
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                   4               0.08%     Tweek
# 2                  27              66.34%     Tweek
# 3                  74              31.39%     Tweek

# %%
tweek_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
tweek_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1      Super Smash Bros. Melee      $106.75            4         0.08%     |
# 2   Super Smash Bros. Ultimate   $87,826.50           33        68.53%     |
# 3  Super Smash Bros. for Wii U   $40,229.16           74        31.39%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |        $106.75
# 2     $2,805.00             6          2.19%      |     $85,021.50
# 3         $0.00             0          0.00%      |     $40,229.16
#
#   Offline Placed Offline Percent Player ID
# 1              4           0.08%     Tweek
# 2             27          66.34%     Tweek
# 3             74          31.39%     Tweek

# %%
tweek_games = tweek_games.drop(columns=['blank', 'blank1'])
tweek_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1      Super Smash Bros. Melee      $106.75            4         0.08%
# 2   Super Smash Bros. Ultimate   $87,826.50           33        68.53%
# 3  Super Smash Bros. for Wii U   $40,229.16           74        31.39%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%        $106.75              4
# 2     $2,805.00             6          2.19%     $85,021.50             27
# 3         $0.00             0          0.00%     $40,229.16             74
#
#   Offline Percent Player ID
# 1           0.08%     Tweek
# 2          66.34%     Tweek
# 3          31.39%     Tweek

# %% [markdown]
# ## Bonchan

# %%
bonchan_url = 'https://www.esportsearnings.com/players/2028-bonchan-takahashi-masato'
response = requests.get(bonchan_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
bonchan = pd.read_html(str(tables), skiprows=1)

# %%
bonchan = bonchan[0]
bonchan.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $3,881.33              2          3.13%    |       $1,750.00
# 2  2019.0     $56,862.06              7         45.88%    |           $0.00
# 3  2018.0     $15,456.10              6         12.47%    |           $0.00
# 4  2017.0     $10,000.00              3          8.07%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           1.41%    |            $2,131.33
# 2               0           0.00%    |           $56,862.06
# 3               0           0.00%    |           $15,456.10
# 4               0           0.00%    |           $10,000.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                1.72%
# ...

# %%
bonchan.columns = bonchan.iloc[0]

# %%
bonchan = bonchan.drop([0])

# %%
bonchan['Player ID'] = 'Bonchan'
bonchan.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $3,881.33             2         3.13%   |      $1,750.00
# 2  2019.0    $56,862.06             7        45.88%   |          $0.00
# 3  2018.0    $15,456.10             6        12.47%   |          $0.00
# 4  2017.0    $10,000.00             3         8.07%   |          $0.00
# 5  2016.0     $3,706.73             5         2.99%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          1.41%   |           $2,131.33                   1
# 2              0          0.00%   |          $56,862.06                   7
# 3              0          0.00%   |          $15,456.10                   6
# 4              0          0.00%   |          $10,000.00                   3
# 5              0          0.00%   |           $3,706.73                   5
#
# 0 Offline/LAN Results Player ID
# 1               1.72%   Bonchan
# ...

# %%
bonchan.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
bonchan.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $3,881.33            2         3.13%     |     $1,750.00
# 2  2019.0   $56,862.06            7        45.88%     |         $0.00
# 3  2018.0   $15,456.10            6        12.47%     |         $0.00
# 4  2017.0   $10,000.00            3         8.07%     |         $0.00
# 5  2016.0    $3,706.73            5         2.99%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          1.41%      |      $2,131.33              1
# 2             0          0.00%      |     $56,862.06              7
# 3             0          0.00%      |     $15,456.10              6
# 4             0          0.00%      |     $10,000.00              3
# 5             0          0.00%      |      $3,706.73              5
#
#   Offline Percent Player ID
# 1           1.72%   Bonchan
# 2          45.88%   Bonchan
# 3          12.47%   Bonchan
# ...

# %%
bonchan['Year'] = bonchan['Year'].round().astype(int)

# %%
bonchan = bonchan.drop(columns=['blank', 'blank1'])
bonchan
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2021    $3,881.33            2         3.13%     $1,750.00             1
# 2   2019   $56,862.06            7        45.88%         $0.00             0
# 3   2018   $15,456.10            6        12.47%         $0.00             0
# 4   2017   $10,000.00            3         8.07%         $0.00             0
# 5   2016    $3,706.73            5         2.99%         $0.00             0
# 6   2015   $22,366.22            7        18.05%         $0.00             0
# 7   2014    $8,961.77            6         7.23%         $0.00             0
# 8   2013    $1,940.52            2         1.57%         $0.00             0
# 9   2012      $637.84            2         0.51%         $0.00             0
# 10  2010      $110.69            1         0.09%         $0.00             0
#
#    Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# ...

# %%
bonchan_games = pd.read_html(str(tables), skiprows=1)

# %%
bonchan_games = bonchan_games[2]
bonchan_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                       Street Fighter IV        $110.69              1
# 2                        Street Fighter V     $13,706.73              8
# 3        Street Fighter V: Arcade Edition     $72,318.16             13
# 4      Street Fighter V: Champion Edition      $3,881.33              2
# 5  Super Street Fighter IV Arcade Edition      $5,038.26              6
# 6            Ultimate Marvel vs. Capcom 3          $0.00              1
# 7                 Ultra Street Fighter IV     $28,868.09             10
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1          0.09%    |           $0.00               0           0.00%    |
# 2         11.06%    |           $0.00               0           0.00%    |
# ...

# %%
bonchan_games.columns = bonchan_games.iloc[0]

# %%
bonchan_games = bonchan_games.drop([0])

# %%
bonchan_games['Player ID'] = 'Bonchan'
bonchan_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                       Street Fighter IV       $110.69             1
# 2                        Street Fighter V    $13,706.73             8
# 3        Street Fighter V: Arcade Edition    $72,318.16            13
# 4      Street Fighter V: Champion Edition     $3,881.33             2
# 5  Super Street Fighter IV Arcade Edition     $5,038.26             6
# 6            Ultimate Marvel vs. Capcom 3         $0.00             1
# 7                 Ultra Street Fighter IV    $28,868.09            10
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1         0.09%   |          $0.00              0          0.00%   |
# 2        11.06%   |          $0.00              0          0.00%   |
# 3        58.36%   |          $0.00              0          0.00%   |
# 4         3.13%   |      $1,750.00              1          1.41%   |
# ...

# %%
bonchan_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
bonchan_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                       Street Fighter IV      $110.69            1
# 2                        Street Fighter V   $13,706.73            8
# 3        Street Fighter V: Arcade Edition   $72,318.16           13
# 4      Street Fighter V: Champion Edition    $3,881.33            2
# 5  Super Street Fighter IV Arcade Edition    $5,038.26            6
# 6            Ultimate Marvel vs. Capcom 3        $0.00            1
# 7                 Ultra Street Fighter IV   $28,868.09           10
#
#   Total Percent blank Online Prizes Online Placed Online Percent blank1  \
# 1         0.09%     |         $0.00             0          0.00%      |
# 2        11.06%     |         $0.00             0          0.00%      |
# 3        58.36%     |         $0.00             0          0.00%      |
# 4         3.13%     |     $1,750.00             1          1.41%      |
# ...

# %%
bonchan_games = bonchan_games.drop(columns=['blank', 'blank1'])
bonchan_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                       Street Fighter IV      $110.69            1
# 2                        Street Fighter V   $13,706.73            8
# 3        Street Fighter V: Arcade Edition   $72,318.16           13
# 4      Street Fighter V: Champion Edition    $3,881.33            2
# 5  Super Street Fighter IV Arcade Edition    $5,038.26            6
# 6            Ultimate Marvel vs. Capcom 3        $0.00            1
# 7                 Ultra Street Fighter IV   $28,868.09           10
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1         0.09%         $0.00             0          0.00%        $110.69
# 2        11.06%         $0.00             0          0.00%     $13,706.73
# 3        58.36%         $0.00             0          0.00%     $72,318.16
# 4         3.13%     $1,750.00             1          1.41%      $2,131.33
# ...

# %% [markdown]
# ## Phenom

# %%
phenom_url = 'https://www.esportsearnings.com/players/12071-phenom-arman-hanjani'
response = requests.get(phenom_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
phenom = pd.read_html(str(tables), skiprows=1)

# %%
phenom = phenom[0]
phenom.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $9,022.38              2          7.39%    |       $7,500.00
# 2  2019.0     $30,912.95              8         25.32%    |           $0.00
# 3  2018.0     $12,701.52             10         10.40%    |           $0.00
# 4  2017.0     $53,716.73              9         44.00%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           6.14%    |            $1,522.38
# 2               0           0.00%    |           $30,912.95
# 3               0           0.00%    |           $12,701.52
# 4               0           0.00%    |           $53,716.73
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                1.25%
# ...

# %%
phenom.columns = phenom.iloc[0]

# %%
phenom = phenom.drop([0])

# %%
phenom['Player ID'] = 'Phenom'
phenom
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $9,022.38             2         7.39%   |      $7,500.00
# 2  2019.0    $30,912.95             8        25.32%   |          $0.00
# 3  2018.0    $12,701.52            10        10.40%   |          $0.00
# 4  2017.0    $53,716.73             9        44.00%   |          $0.00
# 5  2016.0    $12,866.93             5        10.54%   |          $0.00
# 6  2015.0     $2,178.10             4         1.78%   |          $0.00
# 7  2014.0       $688.02             1         0.56%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          6.14%   |           $1,522.38                   1
# 2              0          0.00%   |          $30,912.95                   8
# 3              0          0.00%   |          $12,701.52                  10
# 4              0          0.00%   |          $53,716.73                   9
# ...

# %%
phenom.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
phenom
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $9,022.38            2         7.39%     |     $7,500.00
# 2  2019.0   $30,912.95            8        25.32%     |         $0.00
# 3  2018.0   $12,701.52           10        10.40%     |         $0.00
# 4  2017.0   $53,716.73            9        44.00%     |         $0.00
# 5  2016.0   $12,866.93            5        10.54%     |         $0.00
# 6  2015.0    $2,178.10            4         1.78%     |         $0.00
# 7  2014.0      $688.02            1         0.56%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          6.14%      |      $1,522.38              1
# 2             0          0.00%      |     $30,912.95              8
# 3             0          0.00%      |     $12,701.52             10
# 4             0          0.00%      |     $53,716.73              9
# ...

# %%
phenom['Year'] = phenom['Year'].round().astype(int)

# %%
phenom = phenom.drop(columns=['blank', 'blank1'])
phenom
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $9,022.38            2         7.39%     $7,500.00             1
# 2  2019   $30,912.95            8        25.32%         $0.00             0
# 3  2018   $12,701.52           10        10.40%         $0.00             0
# 4  2017   $53,716.73            9        44.00%         $0.00             0
# 5  2016   $12,866.93            5        10.54%         $0.00             0
# 6  2015    $2,178.10            4         1.78%         $0.00             0
# 7  2014      $688.02            1         0.56%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          6.14%      $1,522.38              1           1.25%    Phenom
# 2          0.00%     $30,912.95              8          25.32%    Phenom
# 3          0.00%     $12,701.52             10          10.40%    Phenom
# ...

# %%
phenom_games = pd.read_html(str(tables), skiprows=1)

# %%
phenom_games = phenom_games[1]
phenom_games
# Out:
#                                    0              1              2   \
# 0                                 NaN  Total Results  Total Results
# 1                    Street Fighter V     $66,583.66             14
# 2    Street Fighter V: Arcade Edition     $43,614.47             18
# 3  Street Fighter V: Champion Edition      $9,022.38              2
# 4             Ultra Street Fighter IV      $2,866.12              5
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1         54.54%    |           $0.00               0           0.00%    |
# 2         35.72%    |           $0.00               0           0.00%    |
# 3          7.39%    |       $7,500.00               1           6.14%    |
# 4          2.35%    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# ...

# %%
phenom_games.columns = phenom_games.iloc[0]

# %%
phenom_games = phenom_games.drop([0])

# %%
phenom_games['Player ID'] = 'Phenom'
phenom_games
# Out:
# 0                                 NaN Total Results Total Results  \
# 1                    Street Fighter V    $66,583.66            14
# 2    Street Fighter V: Arcade Edition    $43,614.47            18
# 3  Street Fighter V: Champion Edition     $9,022.38             2
# 4             Ultra Street Fighter IV     $2,866.12             5
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        54.54%   |          $0.00              0          0.00%   |
# 2        35.72%   |          $0.00              0          0.00%   |
# 3         7.39%   |      $7,500.00              1          6.14%   |
# 4         2.35%   |          $0.00              0          0.00%   |
#
# 0 Offline/LAN Results Offline/LAN Results Offline/LAN Results Player ID
# 1          $66,583.66                  14              54.54%    Phenom
# 2          $43,614.47                  18              35.72%    Phenom
# ...

# %%
phenom_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
phenom_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V   $66,583.66           14        54.54%
# 2    Street Fighter V: Arcade Edition   $43,614.47           18        35.72%
# 3  Street Fighter V: Champion Edition    $9,022.38            2         7.39%
# 4             Ultra Street Fighter IV    $2,866.12            5         2.35%
#
#   blank Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1     |         $0.00             0          0.00%      |     $66,583.66
# 2     |         $0.00             0          0.00%      |     $43,614.47
# 3     |     $7,500.00             1          6.14%      |      $1,522.38
# 4     |         $0.00             0          0.00%      |      $2,866.12
#
#   Offline Placed Offline Percent Player ID
# 1             14          54.54%    Phenom
# 2             18          35.72%    Phenom
# 3              1           1.25%    Phenom
# ...

# %%
phenom_games = phenom_games.drop(columns=['blank', 'blank1'])
phenom_games
# Out:
#                                  Game Total Prizes Total Placed Total Percent  \
# 1                    Street Fighter V   $66,583.66           14        54.54%
# 2    Street Fighter V: Arcade Edition   $43,614.47           18        35.72%
# 3  Street Fighter V: Champion Edition    $9,022.38            2         7.39%
# 4             Ultra Street Fighter IV    $2,866.12            5         2.35%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%     $66,583.66             14
# 2         $0.00             0          0.00%     $43,614.47             18
# 3     $7,500.00             1          6.14%      $1,522.38              1
# 4         $0.00             0          0.00%      $2,866.12              5
#
#   Offline Percent Player ID
# 1          54.54%    Phenom
# 2          35.72%    Phenom
# 3           1.25%    Phenom
# 4           2.35%    Phenom

# %% [markdown]
# ## Ally

# %%
ally_url = 'https://www.esportsearnings.com/players/5752-ally-elliot-carroza-oyarce'
response = requests.get(ally_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
ally = pd.read_html(str(tables), skiprows=1)

# %%
ally = ally[0]
ally.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2020.0        $125.00              1          0.11%    |         $125.00
# 2  2019.0      $9,705.66              7          8.38%    |           $0.00
# 3  2018.0      $5,843.89             11          5.04%    |           $0.00
# 4  2017.0     $15,448.55             23         13.33%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           0.11%    |                $0.00
# 2               0           0.00%    |            $9,705.66
# 3               0           0.00%    |            $5,843.89
# 4               0           0.00%    |           $15,448.55
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
ally.columns = ally.iloc[0]

# %%
ally = ally.drop([0])

# %%
ally['Player ID'] = 'Ally'
ally.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2020.0       $125.00             1         0.11%   |        $125.00
# 2  2019.0     $9,705.66             7         8.38%   |          $0.00
# 3  2018.0     $5,843.89            11         5.04%   |          $0.00
# 4  2017.0    $15,448.55            23        13.33%   |          $0.00
# 5  2016.0    $39,906.48            61        34.44%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.11%   |               $0.00                   0
# 2              0          0.00%   |           $9,705.66                   7
# 3              0          0.00%   |           $5,843.89                  11
# 4              0          0.00%   |          $15,448.55                  23
# 5              0          0.00%   |          $39,906.48                  61
#
# 0 Offline/LAN Results Player ID
# 1               0.00%      Ally
# ...

# %%
ally.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
ally.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2020.0      $125.00            1         0.11%     |       $125.00
# 2  2019.0    $9,705.66            7         8.38%     |         $0.00
# 3  2018.0    $5,843.89           11         5.04%     |         $0.00
# 4  2017.0   $15,448.55           23        13.33%     |         $0.00
# 5  2016.0   $39,906.48           61        34.44%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.11%      |          $0.00              0
# 2             0          0.00%      |      $9,705.66              7
# 3             0          0.00%      |      $5,843.89             11
# 4             0          0.00%      |     $15,448.55             23
# 5             0          0.00%      |     $39,906.48             61
#
#   Offline Percent Player ID
# 1           0.00%      Ally
# 2           8.38%      Ally
# 3           5.04%      Ally
# ...

# %%
ally['Year'] = ally['Year'].round().astype(int)

# %%
ally = ally.drop(columns=['blank', 'blank1'])
ally
# Out:
#     Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1   2020      $125.00            1         0.11%       $125.00             1
# 2   2019    $9,705.66            7         8.38%         $0.00             0
# 3   2018    $5,843.89           11         5.04%         $0.00             0
# 4   2017   $15,448.55           23        13.33%         $0.00             0
# 5   2016   $39,906.48           61        34.44%         $0.00             0
# 6   2015   $21,340.78           42        18.42%         $0.00             0
# 7   2014      $304.51            5         0.26%         $0.00             0
# 8   2013    $1,163.10            9         1.00%         $0.00             0
# 9   2012    $1,096.45           10         0.95%         $0.00             0
# 10  2011    $5,785.09           14         4.99%         $0.00             0
# 11  2010    $8,041.50           10         6.94%         $0.00             0
# ...

# %%
ally_games = pd.read_html(str(tables), skiprows=1)

# %%
ally_games = ally_games[2]
ally_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1                    Project M      $4,269.83             22          3.69%
# 2      Super Smash Bros. Brawl     $24,679.87             66         21.30%
# 3   Super Smash Bros. Ultimate     $11,755.66             10         10.15%
# 4  Super Smash Bros. for Wii U     $75,162.58            109         64.87%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |         $125.00               1           0.11%    |
# 4    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
ally_games.columns = ally_games.iloc[0]

# %%
ally_games = ally_games.drop([0])

# %%
ally_games['Player ID'] = 'Ally'
ally_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1                    Project M     $4,269.83            22         3.69%   |
# 2      Super Smash Bros. Brawl    $24,679.87            66        21.30%   |
# 3   Super Smash Bros. Ultimate    $11,755.66            10        10.15%   |
# 4  Super Smash Bros. for Wii U    $75,162.58           109        64.87%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |           $4,269.83
# 2          $0.00              0          0.00%   |          $24,679.87
# 3        $125.00              1          0.11%   |          $11,630.66
# 4          $0.00              0          0.00%   |          $75,162.58
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                  22               3.69%      Ally
# 2                  66              21.30%      Ally
# 3                   9              10.04%      Ally
# ...

# %%
ally_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
ally_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1                    Project M    $4,269.83           22         3.69%     |
# 2      Super Smash Bros. Brawl   $24,679.87           66        21.30%     |
# 3   Super Smash Bros. Ultimate   $11,755.66           10        10.15%     |
# 4  Super Smash Bros. for Wii U   $75,162.58          109        64.87%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |      $4,269.83
# 2         $0.00             0          0.00%      |     $24,679.87
# 3       $125.00             1          0.11%      |     $11,630.66
# 4         $0.00             0          0.00%      |     $75,162.58
#
#   Offline Placed Offline Percent Player ID
# 1             22           3.69%      Ally
# 2             66          21.30%      Ally
# 3              9          10.04%      Ally
# 4            109          64.87%      Ally

# %%
ally_games = ally_games.drop(columns=['blank', 'blank1'])
ally_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1                    Project M    $4,269.83           22         3.69%
# 2      Super Smash Bros. Brawl   $24,679.87           66        21.30%
# 3   Super Smash Bros. Ultimate   $11,755.66           10        10.15%
# 4  Super Smash Bros. for Wii U   $75,162.58          109        64.87%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%      $4,269.83             22
# 2         $0.00             0          0.00%     $24,679.87             66
# 3       $125.00             1          0.11%     $11,630.66              9
# 4         $0.00             0          0.00%     $75,162.58            109
#
#   Offline Percent Player ID
# 1           3.69%      Ally
# 2          21.30%      Ally
# 3          10.04%      Ally
# 4          64.87%      Ally

# %% [markdown]
# ## Qudans

# %%
qudans_url = 'https://www.esportsearnings.com/players/4100-qudans-byeong-mun-son'
response = requests.get(qudans_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
qudans = pd.read_html(str(tables), skiprows=1)

# %%
qudans = qudans[0]
qudans
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2019.0     $61,130.00              5         53.83%    |           $0.00
# 2  2018.0     $15,106.00             10         13.30%    |           $0.00
# 3  2017.0     $37,334.01              6         32.87%    |           $0.00
# 4  2005.0          $0.00              1          0.00%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |           $61,130.00
# 2               0           0.00%    |           $15,106.00
# 3               0           0.00%    |           $37,334.01
# 4               0           0.00%    |                $0.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    5               53.83%
# ...

# %%
qudans.columns = qudans.iloc[0]

# %%
qudans = qudans.drop([0])

# %%
qudans['Player ID'] = 'Qudans'
qudans
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2019.0    $61,130.00             5        53.83%   |          $0.00
# 2  2018.0    $15,106.00            10        13.30%   |          $0.00
# 3  2017.0    $37,334.01             6        32.87%   |          $0.00
# 4  2005.0         $0.00             1         0.00%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |          $61,130.00                   5
# 2              0          0.00%   |          $15,106.00                  10
# 3              0          0.00%   |          $37,334.01                   6
# 4              0          0.00%   |               $0.00                   1
#
# 0 Offline/LAN Results Player ID
# 1              53.83%    Qudans
# 2              13.30%    Qudans
# 3              32.87%    Qudans
# 4               0.00%    Qudans

# %%
qudans.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
qudans
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2019.0   $61,130.00            5        53.83%     |         $0.00
# 2  2018.0   $15,106.00           10        13.30%     |         $0.00
# 3  2017.0   $37,334.01            6        32.87%     |         $0.00
# 4  2005.0        $0.00            1         0.00%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |     $61,130.00              5
# 2             0          0.00%      |     $15,106.00             10
# 3             0          0.00%      |     $37,334.01              6
# 4             0          0.00%      |          $0.00              1
#
#   Offline Percent Player ID
# 1          53.83%    Qudans
# 2          13.30%    Qudans
# 3          32.87%    Qudans
# 4           0.00%    Qudans

# %%
qudans['Year'] = qudans['Year'].round().astype(int)

# %%
qudans = qudans.drop(columns=['blank', 'blank1'])
qudans
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2019   $61,130.00            5        53.83%         $0.00             0
# 2  2018   $15,106.00           10        13.30%         $0.00             0
# 3  2017   $37,334.01            6        32.87%         $0.00             0
# 4  2005        $0.00            1         0.00%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%     $61,130.00              5          53.83%    Qudans
# 2          0.00%     $15,106.00             10          13.30%    Qudans
# 3          0.00%     $37,334.01              6          32.87%    Qudans
# 4          0.00%          $0.00              1           0.00%    Qudans

# %%
qudans_games = pd.read_html(str(tables), skiprows=1)

# %%
qudans_games = qudans_games[1]
qudans_games
# Out:
#                             0              1              2              3   \
# 0                          NaN  Total Results  Total Results  Total Results
# 1  Tekken 5: Dark Resurrection        $105.00              1          0.09%
# 2                     Tekken 7    $113,465.01             20         99.91%
# 3        Tekken Tag Tournament          $0.00              1          0.00%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# 1              $105.00                    1                0.09%
# 2          $113,465.01                   20               99.91%
# ...

# %%
qudans_games.columns = qudans_games.iloc[0]

# %%
qudans_games = qudans_games.drop([0])

# %%
qudans_games['Player ID'] = 'Qudans'
qudans_games
# Out:
# 0                          NaN Total Results Total Results Total Results NaN  \
# 1  Tekken 5: Dark Resurrection       $105.00             1         0.09%   |
# 2                     Tekken 7   $113,465.01            20        99.91%   |
# 3        Tekken Tag Tournament         $0.00             1         0.00%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |             $105.00
# 2          $0.00              0          0.00%   |         $113,465.01
# 3          $0.00              0          0.00%   |               $0.00
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# 1                   1               0.09%    Qudans
# 2                  20              99.91%    Qudans
# 3                   1               0.00%    Qudans

# %%
qudans_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
qudans_games
# Out:
#                           Game Total Prizes Total Placed Total Percent blank  \
# 1  Tekken 5: Dark Resurrection      $105.00            1         0.09%     |
# 2                     Tekken 7  $113,465.01           20        99.91%     |
# 3        Tekken Tag Tournament        $0.00            1         0.00%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |        $105.00
# 2         $0.00             0          0.00%      |    $113,465.01
# 3         $0.00             0          0.00%      |          $0.00
#
#   Offline Placed Offline Percent Player ID
# 1              1           0.09%    Qudans
# 2             20          99.91%    Qudans
# 3              1           0.00%    Qudans

# %%
qudans_games = qudans_games.drop(columns=['blank', 'blank1'])
qudans_games
# Out:
#                           Game Total Prizes Total Placed Total Percent  \
# 1  Tekken 5: Dark Resurrection      $105.00            1         0.09%
# 2                     Tekken 7  $113,465.01           20        99.91%
# 3        Tekken Tag Tournament        $0.00            1         0.00%
#
#   Online Prizes Online Placed Online Percent Offline Prizes Offline Placed  \
# 1         $0.00             0          0.00%        $105.00              1
# 2         $0.00             0          0.00%    $113,465.01             20
# 3         $0.00             0          0.00%          $0.00              1
#
#   Offline Percent Player ID
# 1           0.09%    Qudans
# 2          99.91%    Qudans
# 3           0.00%    Qudans

# %% [markdown]
# ## Problem X

# %%
problem_x_url = 'https://www.esportsearnings.com/players/3599-problem-x-benjamin-simon'
response = requests.get(problem_x_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 5

# %%
problem_x = pd.read_html(str(tables), skiprows=1)

# %%
problem_x = problem_x[0]
problem_x.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0      $7,108.95              2          6.31%    |           $0.00
# 2  2019.0     $12,458.05              8         11.06%    |           $0.00
# 3  2018.0     $57,084.07              6         50.70%    |           $0.00
# 4  2017.0     $27,319.78              6         24.26%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |            $7,108.95
# 2               0           0.00%    |           $12,458.05
# 3               0           0.00%    |           $57,084.07
# 4               0           0.00%    |           $27,319.78
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    2                6.31%
# ...

# %%
problem_x.columns = problem_x.iloc[0]

# %%
problem_x = problem_x.drop([0])

# %%
problem_x['Player ID'] = 'Problem X'
problem_x.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0     $7,108.95             2         6.31%   |          $0.00
# 2  2019.0    $12,458.05             8        11.06%   |          $0.00
# 3  2018.0    $57,084.07             6        50.70%   |          $0.00
# 4  2017.0    $27,319.78             6        24.26%   |          $0.00
# 5  2016.0       $661.81             1         0.59%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |           $7,108.95                   2
# 2              0          0.00%   |          $12,458.05                   8
# 3              0          0.00%   |          $57,084.07                   6
# 4              0          0.00%   |          $27,319.78                   6
# 5              0          0.00%   |             $661.81                   1
#
# 0 Offline/LAN Results  Player ID
# 1               6.31%  Problem X
# ...

# %%
problem_x.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
problem_x.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0    $7,108.95            2         6.31%     |         $0.00
# 2  2019.0   $12,458.05            8        11.06%     |         $0.00
# 3  2018.0   $57,084.07            6        50.70%     |         $0.00
# 4  2017.0   $27,319.78            6        24.26%     |         $0.00
# 5  2016.0      $661.81            1         0.59%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |      $7,108.95              2
# 2             0          0.00%      |     $12,458.05              8
# 3             0          0.00%      |     $57,084.07              6
# 4             0          0.00%      |     $27,319.78              6
# 5             0          0.00%      |        $661.81              1
#
#   Offline Percent  Player ID
# 1           6.31%  Problem X
# 2          11.06%  Problem X
# 3          50.70%  Problem X
# ...

# %%
problem_x['Year'] = problem_x['Year'].round().astype(int)

# %%
problem_x = problem_x.drop(columns=['blank', 'blank1'])
problem_x.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021    $7,108.95            2         6.31%         $0.00             0
# 2  2019   $12,458.05            8        11.06%         $0.00             0
# 3  2018   $57,084.07            6        50.70%         $0.00             0
# 4  2017   $27,319.78            6        24.26%         $0.00             0
# 5  2016      $661.81            1         0.59%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent  Player ID
# 1          0.00%      $7,108.95              2           6.31%  Problem X
# 2          0.00%     $12,458.05              8          11.06%  Problem X
# 3          0.00%     $57,084.07              6          50.70%  Problem X
# 4          0.00%     $27,319.78              6          24.26%  Problem X
# 5          0.00%        $661.81              1           0.59%  Problem X

# %%
problem_x_games = pd.read_html(str(tables), skiprows=1)

# %%
problem_x_games = problem_x_games[1]
problem_x_games
# Out:
#                                        0              1              2   \
# 0                                     NaN  Total Results  Total Results
# 1                        Street Fighter V     $27,981.59              7
# 2        Street Fighter V: Arcade Edition     $69,542.12             14
# 3      Street Fighter V: Champion Edition      $7,108.95              2
# 4                 Super Street Fighter IV        $164.18              1
# 5  Super Street Fighter IV Arcade Edition      $1,841.63              2
# 6                 Ultra Street Fighter IV      $5,953.81              5
#
#               3    4               5               6               7    8   \
# 0  Total Results  NaN  Online Results  Online Results  Online Results  NaN
# 1         24.85%    |           $0.00               0           0.00%    |
# 2         61.76%    |           $0.00               0           0.00%    |
# 3          6.31%    |           $0.00               0           0.00%    |
# ...

# %%
problem_x_games.columns = problem_x_games.iloc[0]

# %%
problem_x_games = problem_x_games.drop([0])

# %%
problem_x_games['Player ID'] = 'Problem X'
problem_x_games
# Out:
# 0                                     NaN Total Results Total Results  \
# 1                        Street Fighter V    $27,981.59             7
# 2        Street Fighter V: Arcade Edition    $69,542.12            14
# 3      Street Fighter V: Champion Edition     $7,108.95             2
# 4                 Super Street Fighter IV       $164.18             1
# 5  Super Street Fighter IV Arcade Edition     $1,841.63             2
# 6                 Ultra Street Fighter IV     $5,953.81             5
#
# 0 Total Results NaN Online Results Online Results Online Results NaN  \
# 1        24.85%   |          $0.00              0          0.00%   |
# 2        61.76%   |          $0.00              0          0.00%   |
# 3         6.31%   |          $0.00              0          0.00%   |
# 4         0.15%   |          $0.00              0          0.00%   |
# 5         1.64%   |          $0.00              0          0.00%   |
# ...

# %%
problem_x_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
problem_x_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                        Street Fighter V   $27,981.59            7
# 2        Street Fighter V: Arcade Edition   $69,542.12           14
# 3      Street Fighter V: Champion Edition    $7,108.95            2
# 4                 Super Street Fighter IV      $164.18            1
# 5  Super Street Fighter IV Arcade Edition    $1,841.63            2
# 6                 Ultra Street Fighter IV    $5,953.81            5
#
#   Total Percent blank Online Prizes Online Placed Online Percent blank1  \
# 1        24.85%     |         $0.00             0          0.00%      |
# 2        61.76%     |         $0.00             0          0.00%      |
# 3         6.31%     |         $0.00             0          0.00%      |
# 4         0.15%     |         $0.00             0          0.00%      |
# 5         1.64%     |         $0.00             0          0.00%      |
# ...

# %%
problem_x_games = problem_x_games.drop(columns=['blank', 'blank1'])
problem_x_games
# Out:
#                                      Game Total Prizes Total Placed  \
# 1                        Street Fighter V   $27,981.59            7
# 2        Street Fighter V: Arcade Edition   $69,542.12           14
# 3      Street Fighter V: Champion Edition    $7,108.95            2
# 4                 Super Street Fighter IV      $164.18            1
# 5  Super Street Fighter IV Arcade Edition    $1,841.63            2
# 6                 Ultra Street Fighter IV    $5,953.81            5
#
#   Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1        24.85%         $0.00             0          0.00%     $27,981.59
# 2        61.76%         $0.00             0          0.00%     $69,542.12
# 3         6.31%         $0.00             0          0.00%      $7,108.95
# 4         0.15%         $0.00             0          0.00%        $164.18
# 5         1.64%         $0.00             0          0.00%      $1,841.63
# ...

# %% [markdown]
# ## NOBI

# %%
nobi_url = 'https://www.esportsearnings.com/players/1502-nobi-daichi-nakayama'
response = requests.get(nobi_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
nobi = pd.read_html(str(tables), skiprows=1)

# %%
nobi = nobi[0]
nobi.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0        $273.53              1          0.25%    |           $0.00
# 2  2020.0        $473.52              1          0.43%    |           $0.00
# 3  2019.0     $29,971.98             11         27.51%    |           $0.00
# 4  2018.0     $20,258.00              8         18.59%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |              $273.53
# 2               0           0.00%    |              $473.52
# 3               0           0.00%    |           $29,971.98
# 4               0           0.00%    |           $20,258.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                0.25%
# ...

# %%
nobi.columns = nobi.iloc[0]

# %%
nobi = nobi.drop([0])

# %%
nobi['Player ID'] = 'NOBI'
nobi.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0       $273.53             1         0.25%   |          $0.00
# 2  2020.0       $473.52             1         0.43%   |          $0.00
# 3  2019.0    $29,971.98            11        27.51%   |          $0.00
# 4  2018.0    $20,258.00             8        18.59%   |          $0.00
# 5  2017.0     $2,327.32             4         2.14%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |             $273.53                   1
# 2              0          0.00%   |             $473.52                   1
# 3              0          0.00%   |          $29,971.98                  11
# 4              0          0.00%   |          $20,258.00                   8
# 5              0          0.00%   |           $2,327.32                   4
#
# 0 Offline/LAN Results Player ID
# 1               0.25%      NOBI
# ...

# %%
nobi.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed', 
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
nobi.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0      $273.53            1         0.25%     |         $0.00
# 2  2020.0      $473.52            1         0.43%     |         $0.00
# 3  2019.0   $29,971.98           11        27.51%     |         $0.00
# 4  2018.0   $20,258.00            8        18.59%     |         $0.00
# 5  2017.0    $2,327.32            4         2.14%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |        $273.53              1
# 2             0          0.00%      |        $473.52              1
# 3             0          0.00%      |     $29,971.98             11
# 4             0          0.00%      |     $20,258.00              8
# 5             0          0.00%      |      $2,327.32              4
#
#   Offline Percent Player ID
# 1           0.25%      NOBI
# 2           0.43%      NOBI
# 3          27.51%      NOBI
# ...

# %%
nobi['Year'] = nobi['Year'].round().astype(int)

# %%
nobi = nobi.drop(columns=['blank', 'blank1'])
nobi.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021      $273.53            1         0.25%         $0.00             0
# 2  2020      $473.52            1         0.43%         $0.00             0
# 3  2019   $29,971.98           11        27.51%         $0.00             0
# 4  2018   $20,258.00            8        18.59%         $0.00             0
# 5  2017    $2,327.32            4         2.14%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.00%        $273.53              1           0.25%      NOBI
# 2          0.00%        $473.52              1           0.43%      NOBI
# 3          0.00%     $29,971.98             11          27.51%      NOBI
# 4          0.00%     $20,258.00              8          18.59%      NOBI
# 5          0.00%      $2,327.32              4           2.14%      NOBI

# %%
nobi_games = pd.read_html(str(tables), skiprows=1)

# %%
nobi_games = nobi_games[2]
nobi_games
# Out:
#          0              1              2              3    4               5   \
# 0       NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  Tekken 6     $10,000.00              1          9.18%    |           $0.00
# 2  Tekken 7     $98,962.71             28         90.82%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               0           0.00%    |           $10,000.00
# 2               0           0.00%    |           $98,962.71
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    1                9.18%
# 2                   28               90.82%

# %%
nobi_games.columns = nobi_games.iloc[0]

# %%
nobi_games = nobi_games.drop([0])

# %%
nobi_games['Player ID'] = 'NOBI'
nobi_games
# Out:
# 0       NaN Total Results Total Results Total Results NaN Online Results  \
# 1  Tekken 6    $10,000.00             1         9.18%   |          $0.00
# 2  Tekken 7    $98,962.71            28        90.82%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              0          0.00%   |          $10,000.00                   1
# 2              0          0.00%   |          $98,962.71                  28
#
# 0 Offline/LAN Results Player ID
# 1               9.18%      NOBI
# 2              90.82%      NOBI

# %%
nobi_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
nobi_games
# Out:
#        Game Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  Tekken 6   $10,000.00            1         9.18%     |         $0.00
# 2  Tekken 7   $98,962.71           28        90.82%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             0          0.00%      |     $10,000.00              1
# 2             0          0.00%      |     $98,962.71             28
#
#   Offline Percent Player ID
# 1           9.18%      NOBI
# 2          90.82%      NOBI

# %%
nobi_games = nobi_games.drop(columns=['blank', 'blank1'])
nobi_games
# Out:
#        Game Total Prizes Total Placed Total Percent Online Prizes  \
# 1  Tekken 6   $10,000.00            1         9.18%         $0.00
# 2  Tekken 7   $98,962.71           28        90.82%         $0.00
#
#   Online Placed Online Percent Offline Prizes Offline Placed Offline Percent  \
# 1             0          0.00%     $10,000.00              1           9.18%
# 2             0          0.00%     $98,962.71             28          90.82%
#
#   Player ID
# 1      NOBI
# 2      NOBI

# %% [markdown]
# ## Mago

# %%
mago_url = 'https://www.esportsearnings.com/players/2023-mago-hayashi-kenryo'
response = requests.get(mago_url)
soup = BeautifulSoup(response.content, 'lxml')
tables = soup.find_all('table')
len(tables)
# Out:
# 6

# %%
mago = pd.read_html(str(tables), skiprows=1)

# %%
mago = mago[0]
mago.head()
# Out:
#        0              1              2              3    4               5   \
# 0     NaN  Total Results  Total Results  Total Results  NaN  Online Results
# 1  2021.0        $480.00              1          0.46%    |         $480.00
# 2  2020.0     $12,605.35              4         12.03%    |       $1,900.00
# 3  2019.0     $32,548.50              4         31.07%    |           $0.00
# 4  2018.0      $9,250.00              7          8.83%    |           $0.00
#
#                6               7    8                    9   \
# 0  Online Results  Online Results  NaN  Offline/LAN Results
# 1               1           0.46%    |                $0.00
# 2               1           1.81%    |           $10,705.35
# 3               0           0.00%    |           $32,548.50
# 4               0           0.00%    |            $9,250.00
#
#                     10                   11
# 0  Offline/LAN Results  Offline/LAN Results
# 1                    0                0.00%
# ...

# %%
mago.columns = mago.iloc[0]

# %%
mago = mago.drop([0])

# %%
mago['Player ID'] = 'Mago'
mago.head()
# Out:
# 0     NaN Total Results Total Results Total Results NaN Online Results  \
# 1  2021.0       $480.00             1         0.46%   |        $480.00
# 2  2020.0    $12,605.35             4        12.03%   |      $1,900.00
# 3  2019.0    $32,548.50             4        31.07%   |          $0.00
# 4  2018.0     $9,250.00             7         8.83%   |          $0.00
# 5  2017.0     $4,824.23             6         4.61%   |          $0.00
#
# 0 Online Results Online Results NaN Offline/LAN Results Offline/LAN Results  \
# 1              1          0.46%   |               $0.00                   0
# 2              1          1.81%   |          $10,705.35                   3
# 3              0          0.00%   |          $32,548.50                   4
# 4              0          0.00%   |           $9,250.00                   7
# 5              0          0.00%   |           $4,824.23                   6
#
# 0 Offline/LAN Results Player ID
# 1               0.00%      Mago
# ...

# %%
mago.columns = ['Year', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mago.head()
# Out:
#      Year Total Prizes Total Placed Total Percent blank Online Prizes  \
# 1  2021.0      $480.00            1         0.46%     |       $480.00
# 2  2020.0   $12,605.35            4        12.03%     |     $1,900.00
# 3  2019.0   $32,548.50            4        31.07%     |         $0.00
# 4  2018.0    $9,250.00            7         8.83%     |         $0.00
# 5  2017.0    $4,824.23            6         4.61%     |         $0.00
#
#   Online Placed Online Percent blank1 Offline Prizes Offline Placed  \
# 1             1          0.46%      |          $0.00              0
# 2             1          1.81%      |     $10,705.35              3
# 3             0          0.00%      |     $32,548.50              4
# 4             0          0.00%      |      $9,250.00              7
# 5             0          0.00%      |      $4,824.23              6
#
#   Offline Percent Player ID
# 1           0.00%      Mago
# 2          10.22%      Mago
# 3          31.07%      Mago
# ...

# %%
mago['Year'] = mago['Year'].round().astype(int)

# %%
mago = mago.drop(columns=['blank', 'blank1'])
mago.head()
# Out:
#    Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 1  2021      $480.00            1         0.46%       $480.00             1
# 2  2020   $12,605.35            4        12.03%     $1,900.00             1
# 3  2019   $32,548.50            4        31.07%         $0.00             0
# 4  2018    $9,250.00            7         8.83%         $0.00             0
# 5  2017    $4,824.23            6         4.61%         $0.00             0
#
#   Online Percent Offline Prizes Offline Placed Offline Percent Player ID
# 1          0.46%          $0.00              0           0.00%      Mago
# 2          1.81%     $10,705.35              3          10.22%      Mago
# 3          0.00%     $32,548.50              4          31.07%      Mago
# 4          0.00%      $9,250.00              7           8.83%      Mago
# 5          0.00%      $4,824.23              6           4.61%      Mago

# %%
mago_games = pd.read_html(str(tables), skiprows=1)

# %%
mago_games = mago_games[2]
mago_games.head()
# Out:
#                            0              1              2              3   \
# 0                         NaN  Total Results  Total Results  Total Results
# 1            Capcom vs. SNK 2          $0.00              2          0.00%
# 2  Guilty Gear XX Accent Core         $83.33              1          0.08%
# 3       King of Fighters XIII          $0.00              2          0.00%
# 4           Street Fighter IV      $1,025.75              1          0.98%
#
#     4               5               6               7    8   \
# 0  NaN  Online Results  Online Results  Online Results  NaN
# 1    |           $0.00               0           0.00%    |
# 2    |           $0.00               0           0.00%    |
# 3    |           $0.00               0           0.00%    |
# 4    |           $0.00               0           0.00%    |
#
#                     9                    10                   11
# 0  Offline/LAN Results  Offline/LAN Results  Offline/LAN Results
# ...

# %%
mago_games.columns = mago_games.iloc[0]

# %%
mago_games = mago_games.drop([0])

# %%
mago_games['Player ID'] = 'Mago'
mago_games.head()
# Out:
# 0                         NaN Total Results Total Results Total Results NaN  \
# 1            Capcom vs. SNK 2         $0.00             2         0.00%   |
# 2  Guilty Gear XX Accent Core        $83.33             1         0.08%   |
# 3       King of Fighters XIII         $0.00             2         0.00%   |
# 4           Street Fighter IV     $1,025.75             1         0.98%   |
# 5            Street Fighter V    $20,615.68            15        19.68%   |
#
# 0 Online Results Online Results Online Results NaN Offline/LAN Results  \
# 1          $0.00              0          0.00%   |               $0.00
# 2          $0.00              0          0.00%   |              $83.33
# 3          $0.00              0          0.00%   |               $0.00
# 4          $0.00              0          0.00%   |           $1,025.75
# 5          $0.00              0          0.00%   |          $20,615.68
#
# 0 Offline/LAN Results Offline/LAN Results Player ID
# ...

# %%
mago_games.columns = ['Game', 'Total Prizes', 'Total Placed', 'Total Percent', 'blank', 'Online Prizes', 'Online Placed',
'Online Percent', 'blank1', 'Offline Prizes', 'Offline Placed', 'Offline Percent', 'Player ID']
mago_games.head()
# Out:
#                          Game Total Prizes Total Placed Total Percent blank  \
# 1            Capcom vs. SNK 2        $0.00            2         0.00%     |
# 2  Guilty Gear XX Accent Core       $83.33            1         0.08%     |
# 3       King of Fighters XIII        $0.00            2         0.00%     |
# 4           Street Fighter IV    $1,025.75            1         0.98%     |
# 5            Street Fighter V   $20,615.68           15        19.68%     |
#
#   Online Prizes Online Placed Online Percent blank1 Offline Prizes  \
# 1         $0.00             0          0.00%      |          $0.00
# 2         $0.00             0          0.00%      |         $83.33
# 3         $0.00             0          0.00%      |          $0.00
# 4         $0.00             0          0.00%      |      $1,025.75
# 5         $0.00             0          0.00%      |     $20,615.68
#
#   Offline Placed Offline Percent Player ID
# 1              2           0.00%      Mago
# ...

# %%
mago_games = mago_games.drop(columns=['blank', 'blank1'])
mago_games
# Out:
#                                       Game Total Prizes Total Placed  \
# 1                         Capcom vs. SNK 2        $0.00            2
# 2               Guilty Gear XX Accent Core       $83.33            1
# 3                    King of Fighters XIII        $0.00            2
# 4                        Street Fighter IV    $1,025.75            1
# 5                         Street Fighter V   $20,615.68           15
# 6         Street Fighter V: Arcade Edition   $43,949.86           11
# 7       Street Fighter V: Champion Edition    $9,433.99            4
# 8                  Super Street Fighter IV    $6,200.00            1
# 9   Super Street Fighter IV Arcade Edition    $9,161.89           12
# 10                 Ultra Street Fighter IV   $14,286.20            3
#
#    Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# 1          0.00%         $0.00             0          0.00%          $0.00
# ...

# %%
players_years = pd.concat([sonic_fox, punk, tokido, hungrybox, nuckledu, gachikun, armada, idom, mew2king, dragon, mena, daigo, mango, mkleo, knee, kazunoko, infiltration, fuudo, momochi, zero, sandstorm, afoxygrandpa, leffen, fujimura, itabashi, boomie, dabuz, nairo, jwong, xian, jdcr, plup, tweek, bonchan, phenom, ally, qudans, problem_x, nobi, mago])

# %%
players_years.reset_index(drop=True)
# Out:
#      Year Total Prizes Total Placed Total Percent Online Prizes Online Placed  \
# 0    2021   $18,694.21            9         2.67%     $1,826.37             2
# 1    2020   $40,800.00            2         5.82%         $0.00             0
# 2    2019   $64,925.00           22         9.27%       $200.00             1
# 3    2018   $84,201.28           23        12.02%         $0.00             0
# 4    2017  $184,820.53           19        26.38%         $0.00             0
# ..    ...          ...          ...           ...           ...           ...
# 393  2010    $6,200.00            1         5.92%     $6,200.00             1
# 394  2009    $1,025.75            1         0.98%         $0.00             0
# 395  2007       $83.33            1         0.08%         $0.00             0
# 396  2005        $0.00            1         0.00%         $0.00             0
# 397  2003        $0.00            1         0.00%         $0.00             0
#
# ...

# %%
players_years.to_csv('../data/players_years.csv')

# %%
players_games = pd.concat([sonic_fox_games, punk_games, tokido_games, hungrybox_games, nuckledu_games, gachikun_games, armada_games, idom_games, mew2king_games, dragon_games, mena_games, daigo_games, mango_games, mkleo_games, knee_games, kazunoko_games, infiltration_games, fuudo_games, momochi_games, zero_games, sandstorm_games, afoxygrandpa_games, leffen_games, fujimura_games, itabashi_games, boomie_games, dabuz_games, nairo_games, jwong_games, xian_games, jdcr_games, plup_games, tweek_games, bonchan_games, phenom_games, ally_games, qudans_games, problem_x_games, nobi_games, mago_games])

# %%
players_games
# Out:
#                                       Game Total Prizes Total Placed  \
# 1                 Dead or Alive 5 Ultimate        $0.00            4
# 2              Dead or Alive 5: Last Round      $504.00            6
# 3                     Dragon Ball FighterZ   $43,872.21           22
# 4                     Guilty Gear -STRIVE-    $2,647.10            4
# 5                              Injustice 2  $223,245.53           16
# ..                                     ...          ...          ...
# 6         Street Fighter V: Arcade Edition   $43,949.86           11
# 7       Street Fighter V: Champion Edition    $9,433.99            4
# 8                  Super Street Fighter IV    $6,200.00            1
# 9   Super Street Fighter IV Arcade Edition    $9,161.89           12
# 10                 Ultra Street Fighter IV   $14,286.20            3
#
#    Total Percent Online Prizes Online Placed Online Percent Offline Prizes  \
# ...

# %%
players_games.to_csv('../data/players_games.csv')

# %%
#pd.concat([punk, sonic_fox, tokido])

# %%
#three.to_csv('../data/three.csv')
